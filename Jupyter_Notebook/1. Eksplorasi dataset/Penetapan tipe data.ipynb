# %% [markdown]
# # Penetapan tipe data

# %% [markdown]
# ### Import Library

# %%
import numpy as np 
import pandas as pd 
import time

import warnings
warnings.filterwarnings('ignore')

# menampilkan lebih banyak kolom dan baris pada Dataset
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %%
# fungsi rekomendasi tipe data
def rekomendasi_tipe_data(kolom):
    mn = kolom.min()
    mx = kolom.max()
    dtype_lama = kolom.dtype
    if mn >= 0:
        if mx <= 255:
            return 'uint8', dtype_lama
        elif mx <= 65535:
            return 'uint16', dtype_lama
        elif mx <= 4294967295:
            return 'uint32', dtype_lama
        elif mx <= 18446744073709551615:
            return 'uint64', dtype_lama
        else:
            return 'float64', dtype_lama
    else:
        if mn >= -128 and mx <= 127:
            return 'int8', dtype_lama
        elif mn >= -32768 and mx <= 32767:
            return 'int16', dtype_lama
        elif mn >= -2147483648 and mx <= 2147483647:
            return 'int32', dtype_lama
        elif mn >= -9223372036854775808 and mx <= 9223372036854775807:
            return 'int64', dtype_lama
        else:
            return 'float64', dtype_lama
    
def rekomendasi_objek_dtype(kolom):
    unique_values = kolom.unique()
    if len(unique_values) / len(kolom) < 0.5:
        return pd.Categorical(kolom).as_ordered().dtype, kolom.dtype
    else:
        return 'object', kolom.dtype

# %% [markdown]
# ### Load dataset

# %%
# Load Dataset CIC-IDS2018 #
# ======================== #

m_load = time.time()
#dataset_cic2018 = pd.read_csv("G:\\Universitas Indonesia\\Rancangan Paper\\Dataset CSE-CIC-IDS2018-AWS\\CIC2018\\CSE_CIC_IDS2018_Praproses.csv")
#dataset_cic2018 = pd.read_csv("G:\\Universitas Indonesia\\Rancangan Paper\\Dataset CSE-CIC-IDS2018-AWS\\CIC2018\\CIC2018.csv")
dataset_cic2018 = pd.read_csv("D:\\Fando\\Universitas Indonesia\\Semester 4\\Thesis\\Dataset CSE-CIC-IDS2018-AWS\\CIC2018.csv")

s_load = time.time()
print ('Lama waktu memuat dataset : ', s_load - m_load)
# Out:
# Lama waktu memuat dataset :  144.04777121543884

# %%
# total penggunaan memori pada tipe data lama
dataset_cic2018.info(memory_usage = 'deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16232943 entries, 0 to 16232942
# Data columns (total 84 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   Dst Port           int64
#  1   Protocol           int64
#  2   Timestamp          object
#  3   Flow Duration      int64
#  4   Tot Fwd Pkts       int64
#  5   Tot Bwd Pkts       int64
#  6   TotLen Fwd Pkts    int64
#  7   TotLen Bwd Pkts    int64
#  8   Fwd Pkt Len Max    int64
#  9   Fwd Pkt Len Min    int64
#  10  Fwd Pkt Len Mean   float64
#  11  Fwd Pkt Len Std    float64
#  12  Bwd Pkt Len Max    int64
#  13  Bwd Pkt Len Min    int64
#  14  Bwd Pkt Len Mean   float64
#  15  Bwd Pkt Len Std    float64
#  16  Flow Byts/s        float64
#  17  Flow Pkts/s        float64
#  18  Flow IAT Mean      float64
#  19  Flow IAT Std       float64
#  20  Flow IAT Max       int64
#  21  Flow IAT Min       int64
#  22  Fwd IAT Tot        int64
#  23  Fwd IAT Mean       float64
#  24  Fwd IAT Std        float64
#  25  Fwd IAT Max        int64
#  26  Fwd IAT Min        int64
#  27  Bwd IAT Tot        int64
#  28  Bwd IAT Mean       float64
#  29  Bwd IAT Std        float64
#  30  Bwd IAT Max        int64
#  31  Bwd IAT Min        int64
#  32  Fwd PSH Flags      int64
#  33  Bwd PSH Flags      int64
#  34  Fwd URG Flags      int64
#  35  Bwd URG Flags      int64
#  36  Fwd Header Len     int64
#  37  Bwd Header Len     int64
#  38  Fwd Pkts/s         float64
#  39  Bwd Pkts/s         float64
#  40  Pkt Len Min        int64
#  41  Pkt Len Max        int64
#  42  Pkt Len Mean       float64
#  43  Pkt Len Std        float64
#  44  Pkt Len Var        float64
#  45  FIN Flag Cnt       int64
#  46  SYN Flag Cnt       int64
#  47  RST Flag Cnt       int64
#  48  PSH Flag Cnt       int64
#  49  ACK Flag Cnt       int64
#  50  URG Flag Cnt       int64
#  51  CWE Flag Count     int64
#  52  ECE Flag Cnt       int64
#  53  Down/Up Ratio      int64
#  54  Pkt Size Avg       float64
#  55  Fwd Seg Size Avg   float64
#  56  Bwd Seg Size Avg   float64
#  57  Fwd Byts/b Avg     int64
#  58  Fwd Pkts/b Avg     int64
#  59  Fwd Blk Rate Avg   int64
#  60  Bwd Byts/b Avg     int64
#  61  Bwd Pkts/b Avg     int64
#  62  Bwd Blk Rate Avg   int64
#  63  Subflow Fwd Pkts   int64
#  64  Subflow Fwd Byts   int64
#  65  Subflow Bwd Pkts   int64
#  66  Subflow Bwd Byts   int64
#  67  Init Fwd Win Byts  int64
#  68  Init Bwd Win Byts  int64
#  69  Fwd Act Data Pkts  int64
#  70  Fwd Seg Size Min   int64
#  71  Active Mean        float64
#  72  Active Std         float64
#  73  Active Max         int64
#  74  Active Min         int64
#  75  Idle Mean          float64
#  76  Idle Std           float64
#  77  Idle Max           int64
#  78  Idle Min           int64
#  79  Label              object
#  80  Flow ID            object
#  81  Src IP             object
#  82  Src Port           float64
#  83  Dst IP             object
# dtypes: float64(25), int64(54), object(5)
# memory usage: 14.1 GB

# %%
# kolom/fitur yang memiliki NaN >50%
data_2_kolom = ['Timestamp', 'Flow ID', 'Src IP', 'Src Port', 'Dst IP']

# data 1 tanpa NaN
data_1 = dataset_cic2018.drop(columns=data_2_kolom)

# data 2
data_2 = dataset_cic2018[data_2_kolom]

# %%
memori_ori = data_1.memory_usage(deep=True) / 1000**2
hasil = pd.DataFrame({'Penggunaan memori lama (MB)': memori_ori})

# rekomendasi tipe data
tipe_data={}
for kolom in data_1.columns:
    if data_1[kolom].dtype == 'object':
        dtype, dtype_lama = rekomendasi_objek_dtype(data_1[kolom])
    else:
        dtype, dtype_lama = rekomendasi_tipe_data(data_1[kolom])
    tipe_data[kolom] = dtype
    
    # konversi kolom ke tipe data yang sesuai
    data_1[kolom] = data_1[kolom].astype(dtype)

    # hitung penggunaan memori setelah konversi
    memori_baru = data_1[kolom].memory_usage(deep=True) / 1000**2

    # Calculate memory reduction
    reduksi = memori_ori[kolom] - memori_baru

    # Add column information to result dataframe
    hasil.loc[kolom, 'Penggunaan memori baru (MB)'] = memori_baru
    hasil.loc[kolom, 'Tipe Data Baru'] = dtype
    hasil.loc[kolom, 'Tipe Data Lama'] = dtype_lama
    hasil.loc[kolom, 'Min'] = data_1[kolom].min()
    hasil.loc[kolom, 'Max'] = data_1[kolom].max()
    hasil.loc[kolom, 'Pengurangan Memori (MB)'] = reduksi
    
# print tipe data baru
print(tipe_data)
# Out:
# {'Dst Port': 'uint16', 'Protocol': 'uint8', 'Flow Duration': 'int64', 'Tot Fwd Pkts': 'uint32', 'Tot Bwd Pkts': 'uint32', 'TotLen Fwd Pkts': 'uint32', 'TotLen Bwd Pkts': 'uint32', 'Fwd Pkt Len Max': 'uint16', 'Fwd Pkt Len Min': 'uint16', 'Fwd Pkt Len Mean': 'uint16', 'Fwd Pkt Len Std': 'uint16', 'Bwd Pkt Len Max': 'uint16', 'Bwd Pkt Len Min': 'uint16', 'Bwd Pkt Len Mean': 'uint16', 'Bwd Pkt Len Std': 'uint16', 'Flow Byts/s': 'float64', 'Flow Pkts/s': 'float64', 'Flow IAT Mean': 'int64', 'Flow IAT Std': 'uint64', 'Flow IAT Max': 'int64', 'Flow IAT Min': 'int64', 'Fwd IAT Tot': 'int64', 'Fwd IAT Mean': 'int64', 'Fwd IAT Std': 'uint64', 'Fwd IAT Max': 'int64', 'Fwd IAT Min': 'int64', 'Bwd IAT Tot': 'uint32', 'Bwd IAT Mean': 'uint32', 'Bwd IAT Std': 'uint32', 'Bwd IAT Max': 'uint32', 'Bwd IAT Min': 'uint32', 'Fwd PSH Flags': 'uint8', 'Bwd PSH Flags': 'uint8', 'Fwd URG Flags': 'uint8', 'Bwd URG Flags': 'uint8', 'Fwd Header Len': 'uint32', 'Bwd Header Len': 'uint32', 'Fwd Pkts/s': 'uint32', 'Bwd Pkts/s': 'uint32', 'Pkt Len Min': 'uint16', 'Pkt Len Max': 'uint16', 'Pkt Len Mean': 'uint16', 'Pkt Len Std': 'uint16', 'Pkt Len Var': 'uint32', 'FIN Flag Cnt': 'uint8', 'SYN Flag Cnt': 'uint8', 'RST Flag Cnt': 'uint8', 'PSH Flag Cnt': 'uint8', 'ACK Flag Cnt': 'uint8', 'URG Flag Cnt': 'uint8', 'CWE Flag Count': 'uint8', 'ECE Flag Cnt': 'uint8', 'Down/Up Ratio': 'uint16', 'Pkt Size Avg': 'uint16', 'Fwd Seg Size Avg': 'uint16', 'Bwd Seg Size Avg': 'uint16', 'Fwd Byts/b Avg': 'uint8', 'Fwd Pkts/b Avg': 'uint8', 'Fwd Blk Rate Avg': 'uint8', 'Bwd Byts/b Avg': 'uint8', 'Bwd Pkts/b Avg': 'uint8', 'Bwd Blk Rate Avg': 'uint8', 'Subflow Fwd Pkts': 'uint32', 'Subflow Fwd Byts': 'uint32', 'Subflow Bwd Pkts': 'uint32', 'Subflow Bwd Byts': 'uint32', 'Init Fwd Win Byts': 'int32', 'Init Bwd Win Byts': 'int32', 'Fwd Act Data Pkts': 'uint32', 'Fwd Seg Size Min': 'uint8', 'Active Mean': 'uint32', 'Active Std': 'uint32', 'Active Max': 'uint32', 'Active Min': 'uint32', 'Idle Mean': 'uint64', 'Idle Std': 'uint64', 'Idle Max': 'uint64', 'Idle Min': 'uint64', 'Label': CategoricalDtype(categories=['Benign', 'Bot', 'Brute Force -Web', 'Brute Force -XSS',
#                   'DDOS attack-HOIC', 'DDOS attack-LOIC-UDP',
#                   'DDoS attacks-LOIC-HTTP', 'DoS attacks-GoldenEye',
#                   'DoS attacks-Hulk', 'DoS attacks-SlowHTTPTest',
#                   'DoS attacks-Slowloris', 'FTP-BruteForce', 'Infilteration',
#                   'SQL Injection', 'SSH-Bruteforce'],
# , ordered=True)}

# %%
hasil
# Out:
#                    Penggunaan memori lama (MB)  Penggunaan memori baru (MB)  \
# Index                                 0.000128                          NaN
# Dst Port                            129.863544                    32.466014
# Protocol                            129.863544                    16.233071
# Flow Duration                       129.863544                   129.863672
# Tot Fwd Pkts                        129.863544                    64.931900
# Tot Bwd Pkts                        129.863544                    64.931900
# TotLen Fwd Pkts                     129.863544                    64.931900
# TotLen Bwd Pkts                     129.863544                    64.931900
# Fwd Pkt Len Max                     129.863544                    32.466014
# Fwd Pkt Len Min                     129.863544                    32.466014
# Fwd Pkt Len Mean                    129.863544                    32.466014
# Fwd Pkt Len Std                     129.863544                    32.466014
# Bwd Pkt Len Max                     129.863544                    32.466014
# Bwd Pkt Len Min                     129.863544                    32.466014
# Bwd Pkt Len Mean                    129.863544                    32.466014
# Bwd Pkt Len Std                     129.863544                    32.466014
# Flow Byts/s                         129.863544                   129.863672
# Flow Pkts/s                         129.863544                   129.863672
# Flow IAT Mean                       129.863544                   129.863672
# Flow IAT Std                        129.863544                   129.863672
# Flow IAT Max                        129.863544                   129.863672
# Flow IAT Min                        129.863544                   129.863672
# Fwd IAT Tot                         129.863544                   129.863672
# Fwd IAT Mean                        129.863544                   129.863672
# Fwd IAT Std                         129.863544                   129.863672
# Fwd IAT Max                         129.863544                   129.863672
# Fwd IAT Min                         129.863544                   129.863672
# Bwd IAT Tot                         129.863544                    64.931900
# Bwd IAT Mean                        129.863544                    64.931900
# Bwd IAT Std                         129.863544                    64.931900
# Bwd IAT Max                         129.863544                    64.931900
# Bwd IAT Min                         129.863544                    64.931900
# Fwd PSH Flags                       129.863544                    16.233071
# Bwd PSH Flags                       129.863544                    16.233071
# Fwd URG Flags                       129.863544                    16.233071
# Bwd URG Flags                       129.863544                    16.233071
# Fwd Header Len                      129.863544                    64.931900
# Bwd Header Len                      129.863544                    64.931900
# Fwd Pkts/s                          129.863544                    64.931900
# Bwd Pkts/s                          129.863544                    64.931900
# Pkt Len Min                         129.863544                    32.466014
# Pkt Len Max                         129.863544                    32.466014
# Pkt Len Mean                        129.863544                    32.466014
# Pkt Len Std                         129.863544                    32.466014
# Pkt Len Var                         129.863544                    64.931900
# FIN Flag Cnt                        129.863544                    16.233071
# SYN Flag Cnt                        129.863544                    16.233071
# RST Flag Cnt                        129.863544                    16.233071
# PSH Flag Cnt                        129.863544                    16.233071
# ACK Flag Cnt                        129.863544                    16.233071
# URG Flag Cnt                        129.863544                    16.233071
# CWE Flag Count                      129.863544                    16.233071
# ECE Flag Cnt                        129.863544                    16.233071
# Down/Up Ratio                       129.863544                    32.466014
# Pkt Size Avg                        129.863544                    32.466014
# Fwd Seg Size Avg                    129.863544                    32.466014
# Bwd Seg Size Avg                    129.863544                    32.466014
# Fwd Byts/b Avg                      129.863544                    16.233071
# Fwd Pkts/b Avg                      129.863544                    16.233071
# Fwd Blk Rate Avg                    129.863544                    16.233071
# Bwd Byts/b Avg                      129.863544                    16.233071
# Bwd Pkts/b Avg                      129.863544                    16.233071
# Bwd Blk Rate Avg                    129.863544                    16.233071
# Subflow Fwd Pkts                    129.863544                    64.931900
# Subflow Fwd Byts                    129.863544                    64.931900
# Subflow Bwd Pkts                    129.863544                    64.931900
# Subflow Bwd Byts                    129.863544                    64.931900
# Init Fwd Win Byts                   129.863544                    64.931900
# Init Bwd Win Byts                   129.863544                    64.931900
# Fwd Act Data Pkts                   129.863544                    64.931900
# Fwd Seg Size Min                    129.863544                    16.233071
# Active Mean                         129.863544                    64.931900
# Active Std                          129.863544                    64.931900
# Active Max                          129.863544                    64.931900
# Active Min                          129.863544                    64.931900
# Idle Mean                           129.863544                   129.863672
# Idle Std                            129.863544                   129.863672
# Idle Max                            129.863544                   129.863672
# Idle Min                            129.863544                   129.863672
# Label                              1050.034991                    16.234717
#
#                   Tipe Data Baru Tipe Data Lama             Min  \
# Index                        NaN            NaN             NaN
# Dst Port                  uint16          int64             0.0
# Protocol                   uint8          int64             0.0
# Flow Duration              int64          int64 -919011000000.0
# Tot Fwd Pkts              uint32          int64             1.0
# Tot Bwd Pkts              uint32          int64             0.0
# TotLen Fwd Pkts           uint32          int64             0.0
# TotLen Bwd Pkts           uint32          int64             0.0
# Fwd Pkt Len Max           uint16          int64             0.0
# Fwd Pkt Len Min           uint16          int64             0.0
# Fwd Pkt Len Mean          uint16        float64             0.0
# Fwd Pkt Len Std           uint16        float64             0.0
# Bwd Pkt Len Max           uint16          int64             0.0
# Bwd Pkt Len Min           uint16          int64             0.0
# Bwd Pkt Len Mean          uint16        float64             0.0
# Bwd Pkt Len Std           uint16        float64             0.0
# Flow Byts/s              float64        float64             0.0
# Flow Pkts/s              float64        float64       -0.008895
# Flow IAT Mean              int64        float64 -828220000000.0
# Flow IAT Std              uint64        float64             0.0
# Flow IAT Max               int64          int64 -828220000000.0
# Flow IAT Min               int64          int64 -947405000000.0
# Fwd IAT Tot                int64          int64 -919011000000.0
# Fwd IAT Mean               int64        float64 -828220000000.0
# Fwd IAT Std               uint64        float64             0.0
# Fwd IAT Max                int64          int64 -828220000000.0
# Fwd IAT Min                int64          int64 -947405000000.0
# Bwd IAT Tot               uint32          int64             0.0
# Bwd IAT Mean              uint32        float64             0.0
# Bwd IAT Std               uint32        float64             0.0
# Bwd IAT Max               uint32          int64             0.0
# Bwd IAT Min               uint32          int64             0.0
# Fwd PSH Flags              uint8          int64             0.0
# Bwd PSH Flags              uint8          int64             0.0
# Fwd URG Flags              uint8          int64             0.0
# Bwd URG Flags              uint8          int64             0.0
# Fwd Header Len            uint32          int64             0.0
# Bwd Header Len            uint32          int64             0.0
# Fwd Pkts/s                uint32        float64             0.0
# Bwd Pkts/s                uint32        float64             0.0
# Pkt Len Min               uint16          int64             0.0
# Pkt Len Max               uint16          int64             0.0
# Pkt Len Mean              uint16        float64             0.0
# Pkt Len Std               uint16        float64             0.0
# Pkt Len Var               uint32        float64             0.0
# FIN Flag Cnt               uint8          int64             0.0
# SYN Flag Cnt               uint8          int64             0.0
# RST Flag Cnt               uint8          int64             0.0
# PSH Flag Cnt               uint8          int64             0.0
# ACK Flag Cnt               uint8          int64             0.0
# URG Flag Cnt               uint8          int64             0.0
# CWE Flag Count             uint8          int64             0.0
# ECE Flag Cnt               uint8          int64             0.0
# Down/Up Ratio             uint16          int64             0.0
# Pkt Size Avg              uint16        float64             0.0
# Fwd Seg Size Avg          uint16        float64             0.0
# Bwd Seg Size Avg          uint16        float64             0.0
# Fwd Byts/b Avg             uint8          int64             0.0
# Fwd Pkts/b Avg             uint8          int64             0.0
# Fwd Blk Rate Avg           uint8          int64             0.0
# Bwd Byts/b Avg             uint8          int64             0.0
# Bwd Pkts/b Avg             uint8          int64             0.0
# Bwd Blk Rate Avg           uint8          int64             0.0
# Subflow Fwd Pkts          uint32          int64             1.0
# Subflow Fwd Byts          uint32          int64             0.0
# Subflow Bwd Pkts          uint32          int64             0.0
# Subflow Bwd Byts          uint32          int64             0.0
# Init Fwd Win Byts          int32          int64            -1.0
# Init Bwd Win Byts          int32          int64            -1.0
# Fwd Act Data Pkts         uint32          int64             0.0
# Fwd Seg Size Min           uint8          int64             0.0
# Active Mean               uint32        float64             0.0
# Active Std                uint32        float64             0.0
# Active Max                uint32          int64             0.0
# Active Min                uint32          int64             0.0
# Idle Mean                 uint64        float64             0.0
# Idle Std                  uint64        float64             0.0
# Idle Max                  uint64          int64             0.0
# Idle Min                  uint64          int64             0.0
# Label                   category         object          Benign
#
#                               Max  Pengurangan Memori (MB)
# Index                         NaN                      NaN
# Dst Port                  65535.0                97.397530
# Protocol                     17.0               113.630473
# Flow Duration         120000000.0                -0.000128
# Tot Fwd Pkts             309629.0                64.931644
# Tot Bwd Pkts             123118.0                64.931644
# TotLen Fwd Pkts       144391846.0                64.931644
# TotLen Bwd Pkts       156360426.0                64.931644
# Fwd Pkt Len Max           64440.0                97.397530
# Fwd Pkt Len Min            1460.0                97.397530
# Fwd Pkt Len Mean          16529.0                97.397530
# Fwd Pkt Len Std           18401.0                97.397530
# Bwd Pkt Len Max           65160.0                97.397530
# Bwd Pkt Len Min            1460.0                97.397530
# Bwd Pkt Len Mean          33879.0                97.397530
# Bwd Pkt Len Std           22448.0                97.397530
# Flow Byts/s                   inf                -0.000128
# Flow Pkts/s                   inf                -0.000128
# Flow IAT Mean         120000000.0                -0.000128
# Flow IAT Std       474354480000.0                -0.000128
# Flow IAT Max       979781000000.0                -0.000128
# Flow IAT Min          120000000.0                -0.000128
# Fwd IAT Tot           120000000.0                -0.000128
# Fwd IAT Mean          120000000.0                -0.000128
# Fwd IAT Std        474354480000.0                -0.000128
# Fwd IAT Max        979781000000.0                -0.000128
# Fwd IAT Min           120000000.0                -0.000128
# Bwd IAT Tot           120000000.0                64.931644
# Bwd IAT Mean          120000000.0                64.931644
# Bwd IAT Std            84837190.0                64.931644
# Bwd IAT Max           120000000.0                64.931644
# Bwd IAT Min           120000000.0                64.931644
# Fwd PSH Flags                 1.0               113.630473
# Bwd PSH Flags                 0.0               113.630473
# Fwd URG Flags                 1.0               113.630473
# Bwd URG Flags                 0.0               113.630473
# Fwd Header Len          2477032.0                64.931644
# Bwd Header Len          2462372.0                64.931644
# Fwd Pkts/s              6000000.0                64.931644
# Bwd Pkts/s              2000000.0                64.931644
# Pkt Len Min                1460.0                97.397530
# Pkt Len Max               65160.0                97.397530
# Pkt Len Mean              17344.0                97.397530
# Pkt Len Std               22788.0                97.397530
# Pkt Len Var           519000000.0                64.931644
# FIN Flag Cnt                  1.0               113.630473
# SYN Flag Cnt                  1.0               113.630473
# RST Flag Cnt                  1.0               113.630473
# PSH Flag Cnt                  1.0               113.630473
# ACK Flag Cnt                  1.0               113.630473
# URG Flag Cnt                  1.0               113.630473
# CWE Flag Count                1.0               113.630473
# ECE Flag Cnt                  1.0               113.630473
# Down/Up Ratio               311.0                97.397530
# Pkt Size Avg              17478.0                97.397530
# Fwd Seg Size Avg          16529.0                97.397530
# Bwd Seg Size Avg          33879.0                97.397530
# Fwd Byts/b Avg                0.0               113.630473
# Fwd Pkts/b Avg                0.0               113.630473
# Fwd Blk Rate Avg              0.0               113.630473
# Bwd Byts/b Avg                0.0               113.630473
# Bwd Pkts/b Avg                0.0               113.630473
# Bwd Blk Rate Avg              0.0               113.630473
# Subflow Fwd Pkts         309629.0                64.931644
# Subflow Fwd Byts      144391846.0                64.931644
# Subflow Bwd Pkts         123118.0                64.931644
# Subflow Bwd Byts      156360426.0                64.931644
# Init Fwd Win Byts         65535.0                64.931644
# Init Bwd Win Byts         65535.0                64.931644
# Fwd Act Data Pkts        309628.0                64.931644
# Fwd Seg Size Min             56.0               113.630473
# Active Mean           114000000.0                64.931644
# Active Std             75232420.0                64.931644
# Active Max            114000000.0                64.931644
# Active Min            114000000.0                64.931644
# Idle Mean          395571430000.0                -0.000128
# Idle Std           262247860000.0                -0.000128
# Idle Max           979781000000.0                -0.000128
# Idle Min           239934000000.0                -0.000128
# Label              SSH-Bruteforce              1033.800274

# %%
# dataframe dengan tipe data baru 
dataset_baru = pd.concat([data_1, data_2], axis=1)

# total penggunaan memori pada tipe data baru
dataset_baru.info(memory_usage = 'deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16232943 entries, 0 to 16232942
# Data columns (total 84 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   Dst Port           uint16
#  1   Protocol           uint8
#  2   Flow Duration      int64
#  3   Tot Fwd Pkts       uint32
#  4   Tot Bwd Pkts       uint32
#  5   TotLen Fwd Pkts    uint32
#  6   TotLen Bwd Pkts    uint32
#  7   Fwd Pkt Len Max    uint16
#  8   Fwd Pkt Len Min    uint16
#  9   Fwd Pkt Len Mean   uint16
#  10  Fwd Pkt Len Std    uint16
#  11  Bwd Pkt Len Max    uint16
#  12  Bwd Pkt Len Min    uint16
#  13  Bwd Pkt Len Mean   uint16
#  14  Bwd Pkt Len Std    uint16
#  15  Flow Byts/s        float64
#  16  Flow Pkts/s        float64
#  17  Flow IAT Mean      int64
#  18  Flow IAT Std       uint64
#  19  Flow IAT Max       int64
#  20  Flow IAT Min       int64
#  21  Fwd IAT Tot        int64
#  22  Fwd IAT Mean       int64
#  23  Fwd IAT Std        uint64
#  24  Fwd IAT Max        int64
#  25  Fwd IAT Min        int64
#  26  Bwd IAT Tot        uint32
#  27  Bwd IAT Mean       uint32
#  28  Bwd IAT Std        uint32
#  29  Bwd IAT Max        uint32
#  30  Bwd IAT Min        uint32
#  31  Fwd PSH Flags      uint8
#  32  Bwd PSH Flags      uint8
#  33  Fwd URG Flags      uint8
#  34  Bwd URG Flags      uint8
#  35  Fwd Header Len     uint32
#  36  Bwd Header Len     uint32
#  37  Fwd Pkts/s         uint32
#  38  Bwd Pkts/s         uint32
#  39  Pkt Len Min        uint16
#  40  Pkt Len Max        uint16
#  41  Pkt Len Mean       uint16
#  42  Pkt Len Std        uint16
#  43  Pkt Len Var        uint32
#  44  FIN Flag Cnt       uint8
#  45  SYN Flag Cnt       uint8
#  46  RST Flag Cnt       uint8
#  47  PSH Flag Cnt       uint8
#  48  ACK Flag Cnt       uint8
#  49  URG Flag Cnt       uint8
#  50  CWE Flag Count     uint8
#  51  ECE Flag Cnt       uint8
#  52  Down/Up Ratio      uint16
#  53  Pkt Size Avg       uint16
#  54  Fwd Seg Size Avg   uint16
#  55  Bwd Seg Size Avg   uint16
#  56  Fwd Byts/b Avg     uint8
#  57  Fwd Pkts/b Avg     uint8
#  58  Fwd Blk Rate Avg   uint8
#  59  Bwd Byts/b Avg     uint8
#  60  Bwd Pkts/b Avg     uint8
#  61  Bwd Blk Rate Avg   uint8
#  62  Subflow Fwd Pkts   uint32
#  63  Subflow Fwd Byts   uint32
#  64  Subflow Bwd Pkts   uint32
#  65  Subflow Bwd Byts   uint32
#  66  Init Fwd Win Byts  int32
#  67  Init Bwd Win Byts  int32
#  68  Fwd Act Data Pkts  uint32
#  69  Fwd Seg Size Min   uint8
#  70  Active Mean        uint32
#  71  Active Std         uint32
#  72  Active Max         uint32
#  73  Active Min         uint32
#  74  Idle Mean          uint64
#  75  Idle Std           uint64
#  76  Idle Max           uint64
#  77  Idle Min           uint64
#  78  Label              category
#  79  Timestamp          object
#  80  Flow ID            object
#  81  Src IP             object
#  82  Src Port           float64
#  83  Dst IP             object
# dtypes: category(1), float64(3), int32(2), int64(8), object(4), uint16(17), uint32(23), uint64(6), uint8(20)
# memory usage: 8.0 GB

# %%
# simpan hasil
hasil.to_csv("G:\\Universitas Indonesia\\Rancangan Paper\\Dataset CSE-CIC-IDS2018-AWS\\CIC2018\\hasil_datatype.txt", index=False)
