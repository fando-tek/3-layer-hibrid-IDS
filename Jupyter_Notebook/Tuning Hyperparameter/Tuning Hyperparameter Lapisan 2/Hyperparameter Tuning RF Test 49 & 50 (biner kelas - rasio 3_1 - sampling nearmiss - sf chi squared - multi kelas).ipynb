# %% [markdown]
# ## Hyperparameter Tuning RF Test 49 & 50

# %% [markdown]
# ### Import library

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import time

### Pra proses
from sklearn.preprocessing import MinMaxScaler

### Near Miss under sampling
from imblearn.under_sampling import NearMiss 

### Bagi data
from sklearn.model_selection import train_test_split

### Seleksi fitur
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

### Random forest (RF)
from sklearn.ensemble import RandomForestClassifier

### metrik pengukuran
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_recall_fscore_support as score
from sklearn.metrics import make_scorer, f1_score

### Tuning Hyperparameter
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import RepeatedStratifiedKFold

### save model
import joblib

import warnings
warnings.filterwarnings('ignore')

# menampilkan lebih banyak kolom dan baris pada Dataset
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %%
# Tipe Dataset #
# ============ #

tipe_dataset = {'dst_port':'uint32','protocol':'uint8','timestamp':'uint64','flow_duration':'int64','tot_fwd_pkts':'uint32','tot_bwd_pkts':'uint32','totlen_fwd_pkts':'uint32','totlen_bwd_pkts':'uint32','fwd_pkt_len_max':'uint16','fwd_pkt_len_min':'uint16',
'fwd_pkt_len_mean':'float32','fwd_pkt_len_std':'float32','bwd_pkt_len_max':'uint16','bwd_pkt_len_min':'uint16','bwd_pkt_len_mean':'float32','bwd_pkt_len_std':'float32','flow_byts_s':'float64','flow_pkts_s':'float64','flow_iat_mean':'float32','flow_iat_std':'float32',
'flow_iat_max':'int64','flow_iat_min':'int64','fwd_iat_tot':'int64','fwd_iat_mean':'float32','fwd_iat_std':'float32','fwd_iat_max':'int64','fwd_iat_min':'int64','bwd_iat_tot':'uint32','bwd_iat_mean':'float32','bwd_iat_std':'float32',
'bwd_iat_max':'uint32','bwd_iat_min':'uint32','fwd_psh_flags':'uint8','bwd_psh_flags':'uint8','fwd_urg_flags':'uint8','bwd_urg_flags':'uint8','fwd_header_len':'uint32','bwd_header_len':'uint32','fwd_pkts_s':'float32','bwd_pkts_s':'float32',
'pkt_len_min':'uint16','pkt_len_max':'uint16','pkt_len_mean':'float32','pkt_len_std':'float32','pkt_len_var':'float32','fin_flag_cnt':'uint8','syn_flag_cnt':'uint8','rst_flag_cnt':'uint8','psh_flag_cnt':'uint8','ack_flag_cnt':'uint8',
'urg_flag_cnt':'uint8','cwe_flag_count':'uint8','ece_flag_cnt':'uint8','down_up_ratio':'uint16','pkt_size_avg':'float32','fwd_seg_size_avg':'float32','bwd_seg_size_avg':'float32','fwd_byts_b_avg':'uint8','fwd_pkts_b_avg':'uint8','fwd_blk_rate_avg':'uint8',
'bwd_byts_b_avg':'uint8','bwd_pkts_b_avg':'uint8','bwd_blk_rate_avg':'uint8','subflow_fwd_pkts':'uint32','subflow_fwd_byts':'uint32','subflow_bwd_pkts':'uint32','subflow_bwd_byts':'uint32','init_fwd_win_byts':'int32','init_bwd_win_byts':'int32','fwd_act_data_pkts':'uint32',
'fwd_seg_size_min':'uint8','active_mean':'float32','active_std':'float32','active_max':'uint32','active_min':'uint32','idle_mean':'float32','idle_std':'float32','idle_max':'uint64','idle_min':'uint64','label':'category',
'flow_id':'object','src_ip':'object','src_port':'float64','dst_ip':'object'}

# %%
# Fungsi #
# ====== #

# bagi dataset menjadi variabel input X dan variabel output y
def variabel_input_output(dataset, n, variabel_output):
    X = dataset.iloc[:,:-n]
    y = dataset[variabel_output]
    return X, y

# seleksi fitur metode Chi-squared
def seleksi_fitur(metode, X, y):
    chi2 = SelectKBest(score_func= metode , k=X.shape[1])
    fit = chi2.fit(X, y) 
    return fit

# pemilihan fitur terbaik
def fitur_terbaik(klf, persentase_skor, X, tipe):
    if tipe == 'rf' :
        importances = klf.feature_importances_
        sorted_indices = np.argsort(importances)[::-1]
        labels = X.columns
    
        # mengurutkan fitur berdasarkan skor tertinggi
        skor_fitur = zip(labels, importances)
        skor_fitur_diurutkan = sorted(skor_fitur, key = lambda x: x[1], reverse = True)
        skor_diurutkan = [skor[1] for skor in skor_fitur_diurutkan]
        fitur_diurutkan = [skor[0] for skor in skor_fitur_diurutkan]

        # Fitur dengan persentase skor 1% atau 5% dihapus
        # pilih fitur dengan persentase skor 95% atau 99%
        fitur_skor_rendah = []
        total_skor = 0 
        jumlah_persentase = []
        for skor in skor_fitur_diurutkan:
            total_skor = total_skor + skor[1]
            if total_skor >= sum(skor_diurutkan)*(persentase_skor/100):
                fitur_skor_rendah.append(skor[0])
                 
        # menampilkan fitur terpilih dengan persentase skor 95% atau 99%
        fitur_terpilih = pd.DataFrame({'Fitur':fitur_diurutkan, 
                                       'Persentase skor': skor_diurutkan/sum(importances)*100,
                                       'jumlah persentase': jumlah_persentase/sum(importances)*100})
                                        
        fitur_terpilih = fitur_terpilih[~fitur_terpilih['Fitur'].isin(fitur_skor_rendah)]
    
        # plot skor dengan setiap fitur
        plt.figure(figsize=(11, 5))
        plt.title('Bobot Fitur')
        plt.bar([i for i in range(len(importances))], importances)
        plt.xticks([i for i in range(len(importances))], X.columns)
        plt.xticks(rotation=80, fontsize=10)
        plt.tight_layout()
        #plt.savefig('features.png', dpi=300)
        
    else :
        # mengurutkan fitur berdasarkan bobot tertinggi
        skor_fitur = zip(X.columns, klf.scores_)
        skor_fitur_diurutkan = sorted(skor_fitur, key = lambda x: x[1], reverse = True)
        skor_diurutkan = [skor[1] for skor in skor_fitur_diurutkan]
        fitur_diurutkan = [skor[0] for skor in skor_fitur_diurutkan]
    
        # Fitur dengan persentase skor 1% atau 5% dihapus
        # pilih fitur dengan persentase skor 95% atau 99%
        fitur_skor_rendah = []
        total_skor = 0 
        jumlah_persentase = []
        for skor in skor_fitur_diurutkan:
            total_skor = total_skor + skor[1]
            jumlah_persentase.append(total_skor)
            if total_skor >= sum(skor_diurutkan)*(persentase_skor/100):
                fitur_skor_rendah.append(skor[0])
  
        # menampilkan fitur terpilih dengan persentase skor 95% atau 99%
        fitur_terpilih = pd.DataFrame({'Skor Chi-kuadrat':skor_diurutkan, 'Fitur':fitur_diurutkan, 
                                       'Persentase skor': skor_diurutkan/sum(klf.scores_)*100,
                                       'jumlah persentase': jumlah_persentase/sum(klf.scores_)*100})
        fitur_terpilih.index = np.arange(1,len(fitur_terpilih)+1)
        fitur_terpilih = fitur_terpilih[~fitur_terpilih['Fitur'].isin(fitur_skor_rendah)]
    
        # plot skor dengan setiap fitur
        plt.figure(figsize=(11, 5))
        plt.title('Bobot Fitur')
        plt.bar([i for i in range(len(klf.scores_))], klf.scores_)
        plt.xticks([i for i in range(len(klf.scores_))], X.columns)
        plt.xticks(rotation=80, fontsize=10)
        plt.tight_layout()
        #plt.savefig('features.png', dpi=300)
    
    # skor kumulatif
    skor_kumulatif = np.cumsum(skor_diurutkan)
    plt.figure(figsize=(13,5))
    x_values = range(len(skor_fitur_diurutkan))
    plt.plot(x_values, skor_kumulatif)

    # menampilkan garis batas persentase skor
    garis_batas = skor_kumulatif[-1]*(persentase_skor/100)
    plt.hlines(y = garis_batas, xmin=0, xmax=len(skor_diurutkan), color = 'r', linestyles = 'dashed')
    plt.xticks(x_values, fitur_diurutkan, rotation = 80, fontsize=10)
    plt.yticks([], [])
    plt.xlabel('Fitur', fontsize=12)
    plt.title('Skor Fitur', fontsize=12)
    plt.tight_layout()
    #plt.savefig('cum_features.png', dpi=300)
    print ("Fitur yang dihapus")
    print ('==================')
    print(fitur_skor_rendah)
    print ('\n')
    print ('Fitur dengan skor terbaik')
    print ('=========================')
    print (fitur_terpilih)
    
    return fitur_skor_rendah, fitur_terpilih

# misklasifikasi
def misklasifikasi(y_aktual, y_prediksi):
    print('misklasifikasi kelas target:')
    print('============================')
    
    misklasifikasi = y_aktual[y_aktual != y_prediksi]

    mk_df = pd.merge(pd.DataFrame({'misklasifikasi': misklasifikasi.value_counts()}),
                     pd.DataFrame({'total': y_aktual.value_counts()}),
                     how='left', left_index=True, right_index=True)
    mk_df['persentase_misklasifikasi(%)'] = mk_df.apply(lambda x: x[0] / x[1], axis=1)*100
    print (mk_df.sort_values('persentase_misklasifikasi(%)', ascending=False))

# metrik evaluasi
def metrik(clf, figsize, y_aktual, y_prediksi):
    print('')
    print('Accuracy, Precision, Recall dan F1-score :')
    print('==========================================')
    accuracy = accuracy_score(y_aktual, y_prediksi) 
    precision_rfc, recall_rfc, fscore_rfc, none = score(y_aktual, y_prediksi, average='macro')    
    print('Accuracy  : '+(str(accuracy)))
    print('Precision : '+(str(precision_rfc)))
    print('Recall    : '+(str(recall_rfc)))
    print('F1-score  : '+(str(fscore_rfc)))
        
    print('')
    print('metrik evaluasi :')
    print('=================')
    print(classification_report(y_aktual, y_prediksi, digits=6))
    
    print('')
    print('matriks "confusion" :')
    print('=====================')
    f,ax = plt.subplots(figsize=(7.5*figsize,5*figsize))
    cm = confusion_matrix(y_aktual, y_prediksi)
    if figsize == 1 :
        #if clf == None :
            #group_names = ['True Neg','False Pos','False Neg','True Pos']
        
        #else :
            #group_names = ['True','False','False ','True ']
            #group_names = ['True Pos','False Neg','False Pos','True Neg']
        
        group_counts = ['{0:0.0f}'.format(value) for value in cm.flatten()]
        group_percentages = ['{0:.2%}'.format(value) for value in (cm/np.sum(cm,axis=1)).flatten()]
        #labels = [f'{v1}\n{v2}\n{v3}' for v1, v2, v3 in zip(group_names,group_counts,group_percentages)]
        labels = [f'{v1}\n{v2}' for v1, v2 in zip(group_counts,group_percentages)]
        labels = np.asarray(labels).reshape(2,2)
        ax = sns.heatmap(cm, annot=labels, linewidth=3, linecolor="black", fmt='', cmap='Blues')
    
    else :
        ax = sns.heatmap(cm, annot=True, linewidth=3, linecolor="black", fmt=".0f", cmap='Greens')
        
    ax.set_xlabel('Label Prediksi', fontsize=12)
    ax.set_ylabel('Label Aktual', fontsize=12)
    ax.set_title('matriks "confusion"')

    if clf == None:
        Label = None
        plt.yticks(rotation=0, ha="right")
        plt.show() 
    else :
        Label = clf.classes_
        #if len(Label) < 15:
            #Label = Label
            #Label = np.append(['benign'],Label)
        #else :
            #Label = Label  
        ax.xaxis.set_ticklabels(Label)
        ax.yaxis.set_ticklabels(Label)
        plt.yticks(rotation=0, ha="right")
        plt.xticks(rotation=40, ha="right")
        plt.show() 
        
def param_terbaik_ke(param_ke):
    print ('Hyperparameter ke 1')
    print ('===================')
    return [param_rf[param_ke-1]]

def latih_eval_rf (params, jlh_est, y_aktual):
    global param_ke,hasil_akurasi,hasil_p_macro,hasil_p_weight,hasil_r_macro,hasil_r_weight,hasil_f1_macro,hasil_f1_weight,hasil_waktu_latih, hasil_waktu_pred,jumlah_estimator,hasil_y_pred
    hasil_akurasi=[]; hasil_p_macro=[]; hasil_p_weight=[]
    hasil_r_macro=[]; hasil_r_weight=[]; hasil_f1_macro=[]
    hasil_f1_weight=[]; hasil_waktu_latih=[]; hasil_waktu_pred=[];
    jumlah_estimator=[];hasil_y_pred=[]
      
    for m in jlh_est: 
        if len(jlh_est) > 1 : 
            print("jumlah 'trees' :",m)
            print('===================')
        param_ke = 0
        for n in params:
            # fit model dengan parameter jlh_estimator 
            param_ke += 1
            if len(params) > 1 :
                print('hyperparameter ke 1')
                print('===================')
            print('hyperparameter :',n)
            m_latih = time.time()
            if len(jlh_est) > 1 : 
                klasifikasi = RandomForestClassifier(**n, n_estimators= m)
            else :
                klasifikasi = RandomForestClassifier(**n, random_state=42, n_jobs=-1)            
            klasifikasi.fit(X_train_chi, y_train['label_binary'])
            s_latih = time.time()
            waktu_latih = s_latih-m_latih
            print ('Lama waktu latih    :', waktu_latih)
    
            # prediksi
            m_pred = time.time()
            y_pred = klasifikasi.predict(X_test_chi)
            s_pred = time.time()
            print ('Lama waktu prediksi :', s_pred-m_pred)
    
            # metrik evaluasi
            akurasi = accuracy_score(y_aktual, y_pred)
            p_macro,r_macro,f1_macro,n = score(y_aktual, y_pred, average='macro')
            p_weight,r_weight,f1_weight,n = score(y_aktual, y_pred, average='weighted')
    
            # tambahkan hasil
            hasil_akurasi.append(akurasi); hasil_p_macro.append(p_macro); hasil_p_weight.append(p_weight)
            hasil_r_macro.append(r_macro); hasil_r_weight.append(r_weight); hasil_f1_macro.append(f1_macro)
            hasil_f1_weight.append(f1_weight); hasil_waktu_latih.append(waktu_latih); hasil_waktu_pred.append(s_pred-m_pred)
            hasil_y_pred.append(y_pred); jumlah_estimator.append(m)
            print ("hasil 'Accuracy'    :", akurasi)
            print ("hasil 'f1-score'    :", f1_macro)
            print ('')
    param_ke=[i+1 for i in range(len(hasil_akurasi))]
    
    return klasifikasi, y_pred

def plot_eval(hasil_1, hasil_2, jlh_estimator, xlabel, ylabel1, ylabel2):
    print("") 
    pjg = len(ylabel1)+7
    print(' PLOT '+ylabel1.upper())
    print("".center(pjg, '='))    
    hasil_2 = np.around(np.array(hasil_2),8)
    
    if hasil_1 == None :
        fig,ax = plt.subplots(figsize=(15,7))
        ax.bar(jlh_estimator, hasil_2, width=2, label = ylabel1)
               #marker='o',linestyle='dashed', markersize=10, 
               #markerfacecolor = 'b', color='orange', label = ylabel1) 
                
        # batas tampilan sumbu y
        y1 = hasil_2
        y2 = (max(y1)-min(y1))
        ymax = max(y1)+(y2*10/100)
        ymin = min(y1)-(y2*10/100)
        ax.set_ylim([ymin,ymax])
        
        ax.set_xlabel(xlabel,fontsize=12)
        ax.set_ylabel(ylabel1, fontsize=12,)
        ax.tick_params(labelsize=12)
        ax.grid(linestyle = 'dashdot')
        
        for i,j in zip(jlh_estimator,hasil_2):
            ax.annotate(j,xy=(i,j),ha="right", va="bottom",fontsize=12)
        ax.legend(fontsize = 14,loc='center', bbox_to_anchor=(0.5,1.04))
        xy = pd.DataFrame({xlabel : jlh_estimator, ylabel1 : hasil_2})
        colors = [["orange", "mediumslateblue"]]*len(jlh_estimator)         
        ytabel = ax.table(cellText=xy.values, colLabels=xy.columns, loc=14,colLoc ='center',
                          cellLoc ='center',fontsize=12,visible=True,
                          colWidths =(0.15,0.15),cellColours=colors)
        ytabel.set_fontsize(12)
        ytabel.scale(0.8, 1.5)
        ytabel.set_zorder(100)

    else :
        plot=2
        n_plot = np.arange(plot)
        hasil_1 = np.around(np.array(hasil_1),8)
        fig,ax = plt.subplots(1,plot,figsize=(15,7))      
        colors = [["orange", "mediumslateblue"]]*len(jlh_estimator)
        
        ax[0].plot(jlh_estimator, hasil_1, marker='o',linestyle='dashed', markersize=10, 
                   markerfacecolor = 'mediumslateblue', color='orange', label = ylabel1)
        ax[1].plot(jlh_estimator, hasil_2,  marker='o',linestyle='dashed',markersize=10,
                    markerfacecolor = 'orange', color='mediumslateblue', label = ylabel2)       
   
        for i,j,k in zip(jlh_estimator,hasil_1,hasil_2):
            ax[0].annotate(j,xy=(i,j),ha="right", va="bottom",fontsize=12)
            ax[1].annotate(k,xy=(i,k),ha="left", va="bottom",fontsize=12)
        for n in n_plot:
            #xy = pd.DataFrame({xlabel : jlh_estimator, ylabel1 : locals()[f'hasil_{n+1}']})
            ax[n].set_xlabel(xlabel,fontsize=12)
            #ax[n].set_ylabel(ylabel1, fontsize=12)
            ax[0].set_ylabel(ylabel1, fontsize=12)
            ax[1].set_ylabel(ylabel2, fontsize=12)
            ax[n].grid(linestyle = 'dashdot')
            ax[n].tick_params(labelsize=12)
            #ytabel = ax[n].table(cellText=xy.values, colLabels=xy.columns, loc=6,
            #              colLoc ='center',cellLoc ='center',fontsize=20,visible=True,
            #              colWidths =(0.3,0.3),cellColours=colors)
            #ytabel.set_fontsize(20)
            #ytabel.scale(0.8, 1.5)
            #ytabel.set_zorder(100)
            ax[n].legend(fontsize = 14,loc='center',bbox_to_anchor=(0.5,1.04))
            
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Load dataset

# %%
# Load Dataset CIC-IDS2018 #
# ======================== #

m_load = time.time()
dataset_cic2018 = pd.read_csv("G:\\Universitas Indonesia\\Rancangan Paper\\Dataset CSE-CIC-IDS2018-AWS\\CIC2018\\CSE_CIC_IDS2018_Praproses.csv", dtype = tipe_dataset)
s_load = time.time()
print ('Lama waktu memuat dataset : ', s_load - m_load)
# Out:
# Lama waktu memuat dataset :  99.67433738708496

# %%
# Rasio kelas normal dan serangan sebelum 'under sampling' #
# ======================================================== #

jlh_target   = dataset_cic2018['label'].value_counts()
jlh_normal   = jlh_target[0]
jlh_serangan = sum(jlh_target[1:15])
print ("Rasio kelas normal dan serangan sebelum 'under sampling'")
print ('=======================================================')
print (f'jumlah sampel kelas normal dan serangan = {jlh_normal} : {jlh_serangan}' )
print (f'Rasio kelas normal dan serangan         = {round(jlh_normal/jlh_serangan,2)} : 1')
# Out:
# Rasio kelas normal dan serangan sebelum 'under sampling'
# =======================================================
# jumlah sampel kelas normal dan serangan = 13154471 : 2744400
# Rasio kelas normal dan serangan         = 4.79 : 1

# %% [markdown]
# ### Under sampling

# %%
# Near Miss undersampling #
# ======================= #

# bagi dataset CIC-IDS2018 menjadi X dan y
X_layer, y_layer = variabel_input_output(dataset_cic2018, 1, ['label'])

# rasio 3:1 kelas normal dan serangan
jlh_sampel = dataset_cic2018['label'].value_counts()
jlh_serangan = sum(jlh_sampel[1:15])
jlh_norm = jlh_serangan*3

# nearmiss under sampling rasio 3:1
m_under = time.time()
nm = NearMiss(version=2, n_jobs = -1, sampling_strategy={'benign' : jlh_norm})
X_layer, y_layer = nm.fit_resample(X_layer,y_layer)
s_under = time.time()
print ("Lama waktu 'under sampling' : ", s_under - m_under)
# Out:
# Lama waktu 'under sampling' :  340.28872418403625

# %% [markdown]
# # =============================

# %% [markdown]
# ### Load Dataset CIC-IDS2018 3:1

# %%
# Load Dataset CIC-IDS2018 #
# ======================== #

m_load = time.time()
dataset_cic2018 = pd.read_csv("G:\\Universitas Indonesia\\Rancangan Paper\\Dataset CSE-CIC-IDS2018-AWS\\CIC2018\\CSE_CIC_IDS2018_Praproses_3_1.csv", dtype = tipe_dataset)
s_load = time.time()
print ('Lama waktu memuat dataset : ', s_load - m_load)
# Out:
# Lama waktu memuat dataset :  67.40992975234985

# %%
# bagi dataset CIC-IDS2018 menjadi X dan y
X_layer, y_layer = variabel_input_output(dataset_cic2018, 1, ['label'])

# %% [markdown]
# # =============================

# %%
# Rasio kelas normal dan serangan setelah 'under sampling' #
# ======================================================== #

jlh_sampel = y_layer.value_counts()
jlh_serangan = sum(jlh_sampel[1:15])
jlh_normal = jlh_sampel[0]
print ("Rasio kelas normal dan serangan setelah 'under sampling'")
print ('========================================================')
print (f'jumlah sampel kelas normal dan serangan = {jlh_normal} : {jlh_serangan}' )
print (f'Rasio kelas normal dan serangan         = {jlh_normal/jlh_serangan} : 1')
# Out:
# Rasio kelas normal dan serangan setelah 'under sampling'
# ========================================================
# jumlah sampel kelas normal dan serangan = 8233200 : 2744400
# Rasio kelas normal dan serangan         = 3.0 : 1

# %% [markdown]
# ### Bagi data

# %%
# Bagi data latih dan uji 80%:20% #
# =============================== #

m_bagi = time.time()
X_train, X_test, y_train, y_test = train_test_split(X_layer, y_layer, train_size = 0.8, test_size = 0.2, random_state = 42, stratify = y_layer)
s_bagi = time.time()
print ('Lama waktu bagi data : ', s_bagi - m_bagi)
# Out:
# Lama waktu bagi data :  63.53369426727295

# %% [markdown]
# ### Penambahan label

# %%
# Penambahan label #
# ================ #

# konversi tipe data label menjadi 'category'
y_train = y_train.astype('category')
y_test = y_test.astype('category')

# penambahan label pada data latih
y_train = pd.DataFrame(y_train)
y_train['label_binary'] = np.where(y_train['label'] == 'benign', 'benign', 'attack')
y_train['label_binary_code'] = np.where(y_train['label'] == 'benign', 0, 1)

# penambahan label pada data uji
y_test = pd.DataFrame(y_test)
y_test['label_binary'] = np.where(y_test['label'] == 'benign', 'benign', 'attack')
y_test['label_binary_code'] = np.where(y_test['label'] == 'benign', 0, 1)

# %% [markdown]
# ### Normalisasi

# %%
# Normalisasi data #
# ================ #

m_norm = time.time()

# menskalakan nilai setiap fitur ke rentang 0 sampai 1 dengan 'MinMaxscaler'.
scaler = MinMaxScaler().fit(X_train)

# terapkan normalisasi
X_train_norm = scaler.transform(X_train)
X_test_norm = scaler.transform(X_test)

X_train_norm = pd.DataFrame(X_train_norm)
X_train_norm.columns = X_train.columns
X_test_norm = pd.DataFrame(X_test_norm)
X_test_norm.columns = X_train.columns

s_norm = time.time()
print ('Lama waktu min-max normalisasi : ', s_norm - m_norm)
# Out:
# Lama waktu min-max normalisasi :  7.692509412765503

# %% [markdown]
# # =========================================

# %% [markdown]
# ## Test 49

# %% [markdown]
# ### 49.1. Seleksi fitur chi squared - 95%

# %%
# Seleksi fitur dengan 'chi squared' #
# ================================== #

m_sf = time.time()

# ambang batas persentase skor
persentase_skor = 95

# vektor target
vektor_target = y_train['label']

# fitur terpilih dan fitur dihapus
fit_chi = seleksi_fitur(chi2, X_train_norm, vektor_target)
fitur_dihapus_chi,fitur_terpilih_chi = fitur_terbaik (fit_chi, persentase_skor, X_train_norm, 'chi')

# hapus fitur dengan skor terendah
X_train_chi = X_train_norm.drop(fitur_dihapus_chi, axis=1)
X_test_chi = X_test_norm.drop(fitur_dihapus_chi, axis=1)

s_sf = time.time()
print ('')
print ("Lama waktu seleksi fitur 'chi squared' : ", s_sf - m_sf)
# Out:
# Fitur yang dihapus
# ==================
# ['dst_port', 'flow_iat_std', 'bwd_iat_std', 'fwd_pkt_len_max', 'fwd_psh_flags', 'active_max', 'active_mean', 'fwd_pkt_len_std', 'active_std', 'bwd_pkt_len_std', 'pkt_len_std', 'timestamp', 'fwd_pkt_len_mean', 'active_min', 'bwd_pkt_len_min', 'pkt_len_mean', 'pkt_size_avg', 'bwd_pkt_len_mean', 'fwd_iat_std', 'fwd_urg_flags', 'pkt_len_min', 'fwd_pkt_len_min', 'pkt_len_max', 'bwd_pkt_len_max', 'pkt_len_var', 'fin_flag_cnt', 'bwd_header_len', 'down_up_ratio', 'flow_byts_s', 'tot_bwd_pkts', 'totlen_bwd_pkts']
#
#
# Fitur dengan skor terbaik
# =========================
#     Skor Chi-kuadrat              Fitur  Persentase skor  jumlah persentase
# 1       2.409937e+06  fwd_act_data_pkts         7.434345           7.434345
# 2       2.296485e+06       tot_fwd_pkts         7.084360          14.518704
# 3       2.215494e+06        flow_pkts_s         6.834514          21.353218
# 4       1.862728e+06     fwd_header_len         5.746274          27.099492
# 5       1.811408e+06         bwd_pkts_s         5.587960          32.687452
# 6       1.673186e+06    totlen_fwd_pkts         5.161564          37.849016
# 7       1.331233e+06  init_fwd_win_byts         4.106681          41.955697
# 8       1.327604e+06        bwd_iat_min         4.095486          46.051183
# 9       1.184807e+06           idle_std         3.654976          49.706159
# 10      1.022994e+06         fwd_pkts_s         3.155805          52.861964
# 11      1.006798e+06       ack_flag_cnt         3.105840          55.967804
# 12      7.796834e+05       bwd_iat_mean         2.405223          58.373027
# 13      7.791878e+05           idle_max         2.403694          60.776720
# 14      7.674690e+05       urg_flag_cnt         2.367543          63.144263
# 15      7.431888e+05        fwd_iat_min         2.292642          65.436904
# 16      7.225461e+05       flow_iat_min         2.228962          67.665866
# 17      6.989168e+05          idle_mean         2.156068          69.821934
# 18      6.798157e+05           protocol         2.097144          71.919078
# 19      6.643303e+05           idle_min         2.049373          73.968451
# 20      6.234639e+05      flow_iat_mean         1.923305          75.891756
# 21      6.161725e+05       fwd_iat_mean         1.900813          77.792569
# 22      6.040468e+05        fwd_iat_tot         1.863406          79.655975
# 23      5.763463e+05      flow_duration         1.777954          81.433929
# 24      5.006695e+05       rst_flag_cnt         1.544501          82.978430
# 25      5.006693e+05       ece_flag_cnt         1.544500          84.522930
# 26      4.944611e+05        bwd_iat_tot         1.525349          86.048279
# 27      4.781651e+05        bwd_iat_max         1.475078          87.523357
# 28      4.762831e+05        fwd_iat_max         1.469272          88.992628
# 29      4.656907e+05       flow_iat_max         1.436596          90.429224
# 30      4.651505e+05   fwd_seg_size_min         1.434929          91.864153
# 31      4.644499e+05  init_bwd_win_byts         1.432768          93.296921
# 32      4.195247e+05       psh_flag_cnt         1.294179          94.591101
#
# Lama waktu seleksi fitur 'chi squared' :  29.422184467315674

# %%
# label aktual dan jumlah fitur #
# ============================= #

# label aktual biner kelas
y_aktual_biner = y_test['label_binary'].reset_index(drop=True)

# fitur dan jumlah fitur yang digunakan
print ('Fitur yang digunakan')
print ('====================')
print (list(X_train_chi.columns))
print ('')
print ('Jumlah fitur')
print ('============')
print (len(X_train_chi.columns),'fitur')
# Out:
# Fitur yang digunakan
# ====================
# ['protocol', 'flow_duration', 'tot_fwd_pkts', 'totlen_fwd_pkts', 'flow_pkts_s', 'flow_iat_mean', 'flow_iat_max', 'flow_iat_min', 'fwd_iat_tot', 'fwd_iat_mean', 'fwd_iat_max', 'fwd_iat_min', 'bwd_iat_tot', 'bwd_iat_mean', 'bwd_iat_max', 'bwd_iat_min', 'fwd_header_len', 'fwd_pkts_s', 'bwd_pkts_s', 'rst_flag_cnt', 'psh_flag_cnt', 'ack_flag_cnt', 'urg_flag_cnt', 'ece_flag_cnt', 'init_fwd_win_byts', 'init_bwd_win_byts', 'fwd_act_data_pkts', 'fwd_seg_size_min', 'idle_mean', 'idle_std', 'idle_max', 'idle_min']
#
# Jumlah fitur
# ============
# 32 fitur

# %% [markdown]
# ### 49.2. Pemilihan jumlah 'tree'

# %%
# Pemilihan jumlah 'trees' #
# ======================== #

m_jlh = time.time()

# parameter yang digunakan
param_klf = [{'random_state':42, 'n_jobs':-1}]                
jlh_estimator = [10,15,20,25,30,35,40,45,50]

# hasil pelatihan
latih_eval_rf(param_klf, jlh_estimator, y_aktual_biner)

s_jlh = time.time()
print ("Lama waktu pencarian jumlah 'tree' : ", s_jlh - m_jlh)
# Out:
# jumlah 'trees' : 10
# ===================
# hyperparameter : {'random_state': 42, 'n_jobs': -1}
# Lama waktu latih    : 145.31460881233215
# Lama waktu prediksi : 1.7121338844299316
# hasil 'Accuracy'    : 0.9897381941407958
# hasil 'f1-score'    : 0.9861753634531008
#
# jumlah 'trees' : 15
# ===================
# hyperparameter : {'random_state': 42, 'n_jobs': -1}
# Lama waktu latih    : 166.2287724018097
# Lama waktu prediksi : 2.0595169067382812
# hasil 'Accuracy'    : 0.9897800976534032
# hasil 'f1-score'    : 0.9862298250693328
#
# jumlah 'trees' : 20
# ===================
# hyperparameter : {'random_state': 42, 'n_jobs': -1}
# Lama waktu latih    : 225.1158926486969
# Lama waktu prediksi : 2.8013055324554443
# hasil 'Accuracy'    : 0.9898488740708351
# hasil 'f1-score'    : 0.9863231669509502
#
# jumlah 'trees' : 25
# ===================
# hyperparameter : {'random_state': 42, 'n_jobs': -1}
# Lama waktu latih    : 283.3132338523865
# Lama waktu prediksi : 3.4071664810180664
# hasil 'Accuracy'    : 0.9899007979886314
# hasil 'f1-score'    : 0.9863912932543717
#
# jumlah 'trees' : 30
# ===================
# hyperparameter : {'random_state': 42, 'n_jobs': -1}
# Lama waktu latih    : 306.8026385307312
# Lama waktu prediksi : 3.7944252490997314
# hasil 'Accuracy'    : 0.9898752915026964
# hasil 'f1-score'    : 0.9863571272866141
#
# jumlah 'trees' : 35
# ===================
# hyperparameter : {'random_state': 42, 'n_jobs': -1}
# Lama waktu latih    : 365.9203989505768
# Lama waktu prediksi : 4.527207851409912
# hasil 'Accuracy'    : 0.9899304037312345
# hasil 'f1-score'    : 0.9864297235438225
#
# jumlah 'trees' : 40
# ===================
# hyperparameter : {'random_state': 42, 'n_jobs': -1}
# Lama waktu latih    : 399.8773310184479
# Lama waktu prediksi : 4.863113641738892
# hasil 'Accuracy'    : 0.9899149176504882
# hasil 'f1-score'    : 0.9864097858204082
#
# jumlah 'trees' : 45
# ===================
# hyperparameter : {'random_state': 42, 'n_jobs': -1}
# Lama waktu latih    : 452.02739930152893
# Lama waktu prediksi : 5.497889518737793
# hasil 'Accuracy'    : 0.9899454343390176
# hasil 'f1-score'    : 0.9864507313846715
#
# jumlah 'trees' : 50
# ===================
# hyperparameter : {'random_state': 42, 'n_jobs': -1}
# Lama waktu latih    : 513.4398791790009
# Lama waktu prediksi : 6.305399417877197
# hasil 'Accuracy'    : 0.9899458898119807
# hasil 'f1-score'    : 0.9864524177565513
#
# Lama waktu pencarian jumlah 'tree' :  3342.6573774814606

# %%
# list hasil pelatihan
print ('List hasil pelatihan')
print ('====================')
print ('hasil_waktu_latih    =', hasil_waktu_latih)
print ('hasil_waktu_prediksi =', hasil_waktu_pred)
print ('hasil_f1_macro       =', hasil_f1_macro)
print ('hasil_akurasi        =', hasil_akurasi)
print ('jumlah_estimator     =', jlh_estimator)
# Out:
# List hasil pelatihan
# ====================
# hasil_waktu_latih    = [145.31460881233215, 166.2287724018097, 225.1158926486969, 283.3132338523865, 306.8026385307312, 365.9203989505768, 399.8773310184479, 452.02739930152893, 513.4398791790009]
# hasil_waktu_prediksi = [1.7121338844299316, 2.0595169067382812, 2.8013055324554443, 3.4071664810180664, 3.7944252490997314, 4.527207851409912, 4.863113641738892, 5.497889518737793, 6.305399417877197]
# hasil_f1_macro       = [0.9861753634531008, 0.9862298250693328, 0.9863231669509502, 0.9863912932543717, 0.9863571272866141, 0.9864297235438225, 0.9864097858204082, 0.9864507313846715, 0.9864524177565513]
# hasil_akurasi        = [0.9897381941407958, 0.9897800976534032, 0.9898488740708351, 0.9899007979886314, 0.9898752915026964, 0.9899304037312345, 0.9899149176504882, 0.9899454343390176, 0.9899458898119807]
# jumlah_estimator     = [10, 15, 20, 25, 30, 35, 40, 45, 50]

# %% [markdown]
# #### 49.2.1. Plot hasil pengukuran

# %%
# Plot hasil pengukuran #
# ===================== #

# Plot waktu latih dan akurasi
plot_eval(hasil_waktu_latih,hasil_akurasi,jumlah_estimator,'Jumlah "trees"','Waktu latih','Accuracy')

# Plot waktu prediksi dan akurasi
plot_eval(hasil_waktu_pred,hasil_akurasi,jumlah_estimator,'Jumlah "trees"','Waktu prediksi','Accuracy')

# Plot waktu pelatihan
plot_eval(None,hasil_waktu_latih,jumlah_estimator,'Jumlah trees','Waktu latih',None)

# Plot waktu prediksi
plot_eval(None,hasil_waktu_pred,jumlah_estimator,'Jumlah trees','Waktu prediksi',None)

# Plot Akurasi
plot_eval(None,hasil_akurasi,jumlah_estimator,'Jumlah trees','Accuracy',None)

# plot F1
plot_eval(None,hasil_f1_macro,jumlah_estimator,'Jumlah trees','F1-score',None)
# Out:
#  PLOT WAKTU LATIH
# ==================
#  PLOT WAKTU PREDIKSI
# =====================
#  PLOT WAKTU LATIH
# ==================
#  PLOT WAKTU PREDIKSI
# =====================
#  PLOT ACCURACY
# ===============
#  PLOT F1-SCORE
# ===============

# %% [markdown]
# ### 49.3. Hyperparameter tuning random forest

# %%
# Hyperparameter tuning random forest #
# =================================== #

m_hyper = time.time()

# hyperparameter yang digunakan untuk tuning
jlh_estimator     = [45]
max_features      = [5, 9, 12, 15, 18]
max_depth         = [None,5,10,15,20,25,30,35]
min_samples_split = [2,3,4,5,6,7,9,10,11,12,13,14,15,16,17,17,18,19,20]
min_samples_leaf  = [2,3,4,5,6,7,9,10,11,12,13,14,15,16,17,17,18,19,20]

# pembangunan model
rf = RandomForestClassifier(random_state=42, n_jobs=-1)

# jumlah acak kombinasi nilai hyperparameter
n_iter = 15

# validasi silang 5 lipatan
cv = 5

# tentukan f1 macro
f1_macro_scorer = make_scorer(f1_score, greater_is_better=True, average='macro')

# random grid search
random_grid = {'n_estimators': jlh_estimator,'max_depth': max_depth,'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,'max_features': max_features}

rf_random = RandomizedSearchCV(estimator=rf, param_distributions=random_grid, 
                               n_iter=n_iter, cv=cv, verbose=10, random_state=17, n_jobs=None, scoring=f1_macro_scorer)

# terapkan random grid pada data latih
rf_random.fit(X_train_chi, y_train['label_binary'])

s_hyper = time.time()
print ("Lama waktu 'hyperparameter tuning' : ", s_hyper - m_hyper)
# Out:
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
# [CV 1/5; 1/15] START max_depth=30, max_features=5, min_samples_leaf=3, min_samples_split=17, n_estimators=45
# [CV 1/5; 1/15] END max_depth=30, max_features=5, min_samples_leaf=3, min_samples_split=17, n_estimators=45;, score=0.987 total time= 6.3min
# [CV 2/5; 1/15] START max_depth=30, max_features=5, min_samples_leaf=3, min_samples_split=17, n_estimators=45
# [CV 2/5; 1/15] END max_depth=30, max_features=5, min_samples_leaf=3, min_samples_split=17, n_estimators=45;, score=0.987 total time= 6.1min
# [CV 3/5; 1/15] START max_depth=30, max_features=5, min_samples_leaf=3, min_samples_split=17, n_estimators=45
# [CV 3/5; 1/15] END max_depth=30, max_features=5, min_samples_leaf=3, min_samples_split=17, n_estimators=45;, score=0.987 total time= 6.0min
# [CV 4/5; 1/15] START max_depth=30, max_features=5, min_samples_leaf=3, min_samples_split=17, n_estimators=45
# [CV 4/5; 1/15] END max_depth=30, max_features=5, min_samples_leaf=3, min_samples_split=17, n_estimators=45;, score=0.987 total time= 6.0min
# [CV 5/5; 1/15] START max_depth=30, max_features=5, min_samples_leaf=3, min_samples_split=17, n_estimators=45
# [CV 5/5; 1/15] END max_depth=30, max_features=5, min_samples_leaf=3, min_samples_split=17, n_estimators=45;, score=0.987 total time= 6.0min
# [CV 1/5; 2/15] START max_depth=5, max_features=9, min_samples_leaf=3, min_samples_split=9, n_estimators=45
# [CV 1/5; 2/15] END max_depth=5, max_features=9, min_samples_leaf=3, min_samples_split=9, n_estimators=45;, score=0.974 total time= 3.3min
# [CV 2/5; 2/15] START max_depth=5, max_features=9, min_samples_leaf=3, min_samples_split=9, n_estimators=45
# [CV 2/5; 2/15] END max_depth=5, max_features=9, min_samples_leaf=3, min_samples_split=9, n_estimators=45;, score=0.976 total time= 3.3min
# [CV 3/5; 2/15] START max_depth=5, max_features=9, min_samples_leaf=3, min_samples_split=9, n_estimators=45
# [CV 3/5; 2/15] END max_depth=5, max_features=9, min_samples_leaf=3, min_samples_split=9, n_estimators=45;, score=0.976 total time= 3.3min
# [CV 4/5; 2/15] START max_depth=5, max_features=9, min_samples_leaf=3, min_samples_split=9, n_estimators=45
# [CV 4/5; 2/15] END max_depth=5, max_features=9, min_samples_leaf=3, min_samples_split=9, n_estimators=45;, score=0.972 total time= 3.3min
# [CV 5/5; 2/15] START max_depth=5, max_features=9, min_samples_leaf=3, min_samples_split=9, n_estimators=45
# [CV 5/5; 2/15] END max_depth=5, max_features=9, min_samples_leaf=3, min_samples_split=9, n_estimators=45;, score=0.972 total time= 3.3min
# [CV 1/5; 3/15] START max_depth=35, max_features=12, min_samples_leaf=20, min_samples_split=5, n_estimators=45
# [CV 1/5; 3/15] END max_depth=35, max_features=12, min_samples_leaf=20, min_samples_split=5, n_estimators=45;, score=0.988 total time=12.4min
# [CV 2/5; 3/15] START max_depth=35, max_features=12, min_samples_leaf=20, min_samples_split=5, n_estimators=45
# [CV 2/5; 3/15] END max_depth=35, max_features=12, min_samples_leaf=20, min_samples_split=5, n_estimators=45;, score=0.988 total time=12.3min
# [CV 3/5; 3/15] START max_depth=35, max_features=12, min_samples_leaf=20, min_samples_split=5, n_estimators=45
# [CV 3/5; 3/15] END max_depth=35, max_features=12, min_samples_leaf=20, min_samples_split=5, n_estimators=45;, score=0.988 total time=12.3min
# [CV 4/5; 3/15] START max_depth=35, max_features=12, min_samples_leaf=20, min_samples_split=5, n_estimators=45
# [CV 4/5; 3/15] END max_depth=35, max_features=12, min_samples_leaf=20, min_samples_split=5, n_estimators=45;, score=0.988 total time=12.2min
# [CV 5/5; 3/15] START max_depth=35, max_features=12, min_samples_leaf=20, min_samples_split=5, n_estimators=45
# [CV 5/5; 3/15] END max_depth=35, max_features=12, min_samples_leaf=20, min_samples_split=5, n_estimators=45;, score=0.988 total time=12.4min
# [CV 1/5; 4/15] START max_depth=None, max_features=9, min_samples_leaf=4, min_samples_split=10, n_estimators=45
# [CV 1/5; 4/15] END max_depth=None, max_features=9, min_samples_leaf=4, min_samples_split=10, n_estimators=45;, score=0.988 total time=10.4min
# [CV 2/5; 4/15] START max_depth=None, max_features=9, min_samples_leaf=4, min_samples_split=10, n_estimators=45
# [CV 2/5; 4/15] END max_depth=None, max_features=9, min_samples_leaf=4, min_samples_split=10, n_estimators=45;, score=0.988 total time=10.2min
# [CV 3/5; 4/15] START max_depth=None, max_features=9, min_samples_leaf=4, min_samples_split=10, n_estimators=45
# [CV 3/5; 4/15] END max_depth=None, max_features=9, min_samples_leaf=4, min_samples_split=10, n_estimators=45;, score=0.988 total time=10.4min
# [CV 4/5; 4/15] START max_depth=None, max_features=9, min_samples_leaf=4, min_samples_split=10, n_estimators=45
# [CV 4/5; 4/15] END max_depth=None, max_features=9, min_samples_leaf=4, min_samples_split=10, n_estimators=45;, score=0.988 total time=10.5min
# [CV 5/5; 4/15] START max_depth=None, max_features=9, min_samples_leaf=4, min_samples_split=10, n_estimators=45
# [CV 5/5; 4/15] END max_depth=None, max_features=9, min_samples_leaf=4, min_samples_split=10, n_estimators=45;, score=0.988 total time=10.3min
# [CV 1/5; 5/15] START max_depth=25, max_features=9, min_samples_leaf=10, min_samples_split=13, n_estimators=45
# [CV 1/5; 5/15] END max_depth=25, max_features=9, min_samples_leaf=10, min_samples_split=13, n_estimators=45;, score=0.988 total time= 8.9min
# [CV 2/5; 5/15] START max_depth=25, max_features=9, min_samples_leaf=10, min_samples_split=13, n_estimators=45
# [CV 2/5; 5/15] END max_depth=25, max_features=9, min_samples_leaf=10, min_samples_split=13, n_estimators=45;, score=0.988 total time= 9.0min
# [CV 3/5; 5/15] START max_depth=25, max_features=9, min_samples_leaf=10, min_samples_split=13, n_estimators=45
# [CV 3/5; 5/15] END max_depth=25, max_features=9, min_samples_leaf=10, min_samples_split=13, n_estimators=45;, score=0.988 total time= 8.9min
# [CV 4/5; 5/15] START max_depth=25, max_features=9, min_samples_leaf=10, min_samples_split=13, n_estimators=45
# [CV 4/5; 5/15] END max_depth=25, max_features=9, min_samples_leaf=10, min_samples_split=13, n_estimators=45;, score=0.988 total time= 8.9min
# [CV 5/5; 5/15] START max_depth=25, max_features=9, min_samples_leaf=10, min_samples_split=13, n_estimators=45
# [CV 5/5; 5/15] END max_depth=25, max_features=9, min_samples_leaf=10, min_samples_split=13, n_estimators=45;, score=0.988 total time= 8.8min
# [CV 1/5; 6/15] START max_depth=30, max_features=5, min_samples_leaf=11, min_samples_split=13, n_estimators=45
# [CV 1/5; 6/15] END max_depth=30, max_features=5, min_samples_leaf=11, min_samples_split=13, n_estimators=45;, score=0.986 total time= 5.9min
# [CV 2/5; 6/15] START max_depth=30, max_features=5, min_samples_leaf=11, min_samples_split=13, n_estimators=45
# [CV 2/5; 6/15] END max_depth=30, max_features=5, min_samples_leaf=11, min_samples_split=13, n_estimators=45;, score=0.987 total time= 5.8min
# [CV 3/5; 6/15] START max_depth=30, max_features=5, min_samples_leaf=11, min_samples_split=13, n_estimators=45
# [CV 3/5; 6/15] END max_depth=30, max_features=5, min_samples_leaf=11, min_samples_split=13, n_estimators=45;, score=0.987 total time= 6.1min
# [CV 4/5; 6/15] START max_depth=30, max_features=5, min_samples_leaf=11, min_samples_split=13, n_estimators=45
# [CV 4/5; 6/15] END max_depth=30, max_features=5, min_samples_leaf=11, min_samples_split=13, n_estimators=45;, score=0.987 total time= 6.1min
# [CV 5/5; 6/15] START max_depth=30, max_features=5, min_samples_leaf=11, min_samples_split=13, n_estimators=45
# [CV 5/5; 6/15] END max_depth=30, max_features=5, min_samples_leaf=11, min_samples_split=13, n_estimators=45;, score=0.986 total time= 5.7min
# [CV 1/5; 7/15] START max_depth=15, max_features=9, min_samples_leaf=17, min_samples_split=2, n_estimators=45
# [CV 1/5; 7/15] END max_depth=15, max_features=9, min_samples_leaf=17, min_samples_split=2, n_estimators=45;, score=0.987 total time= 7.6min
# [CV 2/5; 7/15] START max_depth=15, max_features=9, min_samples_leaf=17, min_samples_split=2, n_estimators=45
# [CV 2/5; 7/15] END max_depth=15, max_features=9, min_samples_leaf=17, min_samples_split=2, n_estimators=45;, score=0.987 total time= 6.9min
# [CV 3/5; 7/15] START max_depth=15, max_features=9, min_samples_leaf=17, min_samples_split=2, n_estimators=45
# [CV 3/5; 7/15] END max_depth=15, max_features=9, min_samples_leaf=17, min_samples_split=2, n_estimators=45;, score=0.987 total time= 6.9min
# [CV 4/5; 7/15] START max_depth=15, max_features=9, min_samples_leaf=17, min_samples_split=2, n_estimators=45
# [CV 4/5; 7/15] END max_depth=15, max_features=9, min_samples_leaf=17, min_samples_split=2, n_estimators=45;, score=0.987 total time= 6.8min
# [CV 5/5; 7/15] START max_depth=15, max_features=9, min_samples_leaf=17, min_samples_split=2, n_estimators=45
# [CV 5/5; 7/15] END max_depth=15, max_features=9, min_samples_leaf=17, min_samples_split=2, n_estimators=45;, score=0.987 total time= 6.9min
# [CV 1/5; 8/15] START max_depth=20, max_features=15, min_samples_leaf=11, min_samples_split=17, n_estimators=45
# [CV 1/5; 8/15] END max_depth=20, max_features=15, min_samples_leaf=11, min_samples_split=17, n_estimators=45;, score=0.988 total time=12.4min
# [CV 2/5; 8/15] START max_depth=20, max_features=15, min_samples_leaf=11, min_samples_split=17, n_estimators=45
# [CV 2/5; 8/15] END max_depth=20, max_features=15, min_samples_leaf=11, min_samples_split=17, n_estimators=45;, score=0.988 total time=12.5min
# [CV 3/5; 8/15] START max_depth=20, max_features=15, min_samples_leaf=11, min_samples_split=17, n_estimators=45
# [CV 3/5; 8/15] END max_depth=20, max_features=15, min_samples_leaf=11, min_samples_split=17, n_estimators=45;, score=0.988 total time=12.4min
# [CV 4/5; 8/15] START max_depth=20, max_features=15, min_samples_leaf=11, min_samples_split=17, n_estimators=45
# [CV 4/5; 8/15] END max_depth=20, max_features=15, min_samples_leaf=11, min_samples_split=17, n_estimators=45;, score=0.988 total time=12.4min
# [CV 5/5; 8/15] START max_depth=20, max_features=15, min_samples_leaf=11, min_samples_split=17, n_estimators=45
# [CV 5/5; 8/15] END max_depth=20, max_features=15, min_samples_leaf=11, min_samples_split=17, n_estimators=45;, score=0.988 total time=12.3min
# [CV 1/5; 9/15] START max_depth=25, max_features=5, min_samples_leaf=14, min_samples_split=16, n_estimators=45
# [CV 1/5; 9/15] END max_depth=25, max_features=5, min_samples_leaf=14, min_samples_split=16, n_estimators=45;, score=0.986 total time= 5.5min
# [CV 2/5; 9/15] START max_depth=25, max_features=5, min_samples_leaf=14, min_samples_split=16, n_estimators=45
# [CV 2/5; 9/15] END max_depth=25, max_features=5, min_samples_leaf=14, min_samples_split=16, n_estimators=45;, score=0.987 total time= 5.4min
# [CV 3/5; 9/15] START max_depth=25, max_features=5, min_samples_leaf=14, min_samples_split=16, n_estimators=45
# [CV 3/5; 9/15] END max_depth=25, max_features=5, min_samples_leaf=14, min_samples_split=16, n_estimators=45;, score=0.987 total time= 5.3min
# [CV 4/5; 9/15] START max_depth=25, max_features=5, min_samples_leaf=14, min_samples_split=16, n_estimators=45
# [CV 4/5; 9/15] END max_depth=25, max_features=5, min_samples_leaf=14, min_samples_split=16, n_estimators=45;, score=0.986 total time= 5.4min
# [CV 5/5; 9/15] START max_depth=25, max_features=5, min_samples_leaf=14, min_samples_split=16, n_estimators=45
# [CV 5/5; 9/15] END max_depth=25, max_features=5, min_samples_leaf=14, min_samples_split=16, n_estimators=45;, score=0.986 total time= 5.9min
# [CV 1/5; 10/15] START max_depth=10, max_features=5, min_samples_leaf=2, min_samples_split=16, n_estimators=45
# [CV 1/5; 10/15] END max_depth=10, max_features=5, min_samples_leaf=2, min_samples_split=16, n_estimators=45;, score=0.981 total time= 3.8min
# [CV 2/5; 10/15] START max_depth=10, max_features=5, min_samples_leaf=2, min_samples_split=16, n_estimators=45
# [CV 2/5; 10/15] END max_depth=10, max_features=5, min_samples_leaf=2, min_samples_split=16, n_estimators=45;, score=0.981 total time= 4.0min
# [CV 3/5; 10/15] START max_depth=10, max_features=5, min_samples_leaf=2, min_samples_split=16, n_estimators=45
# [CV 3/5; 10/15] END max_depth=10, max_features=5, min_samples_leaf=2, min_samples_split=16, n_estimators=45;, score=0.983 total time= 3.7min
# [CV 4/5; 10/15] START max_depth=10, max_features=5, min_samples_leaf=2, min_samples_split=16, n_estimators=45
# [CV 4/5; 10/15] END max_depth=10, max_features=5, min_samples_leaf=2, min_samples_split=16, n_estimators=45;, score=0.980 total time= 3.7min
# [CV 5/5; 10/15] START max_depth=10, max_features=5, min_samples_leaf=2, min_samples_split=16, n_estimators=45
# [CV 5/5; 10/15] END max_depth=10, max_features=5, min_samples_leaf=2, min_samples_split=16, n_estimators=45;, score=0.981 total time= 3.7min
# [CV 1/5; 11/15] START max_depth=10, max_features=12, min_samples_leaf=15, min_samples_split=6, n_estimators=45
# [CV 1/5; 11/15] END max_depth=10, max_features=12, min_samples_leaf=15, min_samples_split=6, n_estimators=45;, score=0.985 total time= 6.9min
# [CV 2/5; 11/15] START max_depth=10, max_features=12, min_samples_leaf=15, min_samples_split=6, n_estimators=45
# [CV 2/5; 11/15] END max_depth=10, max_features=12, min_samples_leaf=15, min_samples_split=6, n_estimators=45;, score=0.986 total time= 6.8min
# [CV 3/5; 11/15] START max_depth=10, max_features=12, min_samples_leaf=15, min_samples_split=6, n_estimators=45
# [CV 3/5; 11/15] END max_depth=10, max_features=12, min_samples_leaf=15, min_samples_split=6, n_estimators=45;, score=0.985 total time= 6.7min
# [CV 4/5; 11/15] START max_depth=10, max_features=12, min_samples_leaf=15, min_samples_split=6, n_estimators=45
# [CV 4/5; 11/15] END max_depth=10, max_features=12, min_samples_leaf=15, min_samples_split=6, n_estimators=45;, score=0.985 total time= 6.7min
# [CV 5/5; 11/15] START max_depth=10, max_features=12, min_samples_leaf=15, min_samples_split=6, n_estimators=45
# [CV 5/5; 11/15] END max_depth=10, max_features=12, min_samples_leaf=15, min_samples_split=6, n_estimators=45;, score=0.985 total time= 6.7min
# [CV 1/5; 12/15] START max_depth=35, max_features=18, min_samples_leaf=12, min_samples_split=4, n_estimators=45
# [CV 1/5; 12/15] END max_depth=35, max_features=18, min_samples_leaf=12, min_samples_split=4, n_estimators=45;, score=0.988 total time=17.7min
# [CV 2/5; 12/15] START max_depth=35, max_features=18, min_samples_leaf=12, min_samples_split=4, n_estimators=45
# [CV 2/5; 12/15] END max_depth=35, max_features=18, min_samples_leaf=12, min_samples_split=4, n_estimators=45;, score=0.988 total time=17.6min
# [CV 3/5; 12/15] START max_depth=35, max_features=18, min_samples_leaf=12, min_samples_split=4, n_estimators=45
# [CV 3/5; 12/15] END max_depth=35, max_features=18, min_samples_leaf=12, min_samples_split=4, n_estimators=45;, score=0.988 total time=17.4min
# [CV 4/5; 12/15] START max_depth=35, max_features=18, min_samples_leaf=12, min_samples_split=4, n_estimators=45
# [CV 4/5; 12/15] END max_depth=35, max_features=18, min_samples_leaf=12, min_samples_split=4, n_estimators=45;, score=0.988 total time=17.6min
# [CV 5/5; 12/15] START max_depth=35, max_features=18, min_samples_leaf=12, min_samples_split=4, n_estimators=45
# [CV 5/5; 12/15] END max_depth=35, max_features=18, min_samples_leaf=12, min_samples_split=4, n_estimators=45;, score=0.988 total time=17.5min
# [CV 1/5; 13/15] START max_depth=35, max_features=15, min_samples_leaf=7, min_samples_split=20, n_estimators=45
# [CV 1/5; 13/15] END max_depth=35, max_features=15, min_samples_leaf=7, min_samples_split=20, n_estimators=45;, score=0.988 total time=14.9min
# [CV 2/5; 13/15] START max_depth=35, max_features=15, min_samples_leaf=7, min_samples_split=20, n_estimators=45
# [CV 2/5; 13/15] END max_depth=35, max_features=15, min_samples_leaf=7, min_samples_split=20, n_estimators=45;, score=0.988 total time=15.0min
# [CV 3/5; 13/15] START max_depth=35, max_features=15, min_samples_leaf=7, min_samples_split=20, n_estimators=45
# [CV 3/5; 13/15] END max_depth=35, max_features=15, min_samples_leaf=7, min_samples_split=20, n_estimators=45;, score=0.988 total time=15.1min
# [CV 4/5; 13/15] START max_depth=35, max_features=15, min_samples_leaf=7, min_samples_split=20, n_estimators=45
# [CV 4/5; 13/15] END max_depth=35, max_features=15, min_samples_leaf=7, min_samples_split=20, n_estimators=45;, score=0.988 total time=15.1min
# [CV 5/5; 13/15] START max_depth=35, max_features=15, min_samples_leaf=7, min_samples_split=20, n_estimators=45
# [CV 5/5; 13/15] END max_depth=35, max_features=15, min_samples_leaf=7, min_samples_split=20, n_estimators=45;, score=0.988 total time=15.2min
# [CV 1/5; 14/15] START max_depth=5, max_features=15, min_samples_leaf=5, min_samples_split=2, n_estimators=45
# [CV 1/5; 14/15] END max_depth=5, max_features=15, min_samples_leaf=5, min_samples_split=2, n_estimators=45;, score=0.976 total time= 4.8min
# [CV 2/5; 14/15] START max_depth=5, max_features=15, min_samples_leaf=5, min_samples_split=2, n_estimators=45
# [CV 2/5; 14/15] END max_depth=5, max_features=15, min_samples_leaf=5, min_samples_split=2, n_estimators=45;, score=0.976 total time= 4.8min
# [CV 3/5; 14/15] START max_depth=5, max_features=15, min_samples_leaf=5, min_samples_split=2, n_estimators=45
# [CV 3/5; 14/15] END max_depth=5, max_features=15, min_samples_leaf=5, min_samples_split=2, n_estimators=45;, score=0.977 total time= 4.8min
# [CV 4/5; 14/15] START max_depth=5, max_features=15, min_samples_leaf=5, min_samples_split=2, n_estimators=45
# [CV 4/5; 14/15] END max_depth=5, max_features=15, min_samples_leaf=5, min_samples_split=2, n_estimators=45;, score=0.976 total time= 4.9min
# [CV 5/5; 14/15] START max_depth=5, max_features=15, min_samples_leaf=5, min_samples_split=2, n_estimators=45
# [CV 5/5; 14/15] END max_depth=5, max_features=15, min_samples_leaf=5, min_samples_split=2, n_estimators=45;, score=0.973 total time= 5.3min
# [CV 1/5; 15/15] START max_depth=None, max_features=18, min_samples_leaf=19, min_samples_split=10, n_estimators=45
# [CV 1/5; 15/15] END max_depth=None, max_features=18, min_samples_leaf=19, min_samples_split=10, n_estimators=45;, score=0.988 total time=21.5min
# [CV 2/5; 15/15] START max_depth=None, max_features=18, min_samples_leaf=19, min_samples_split=10, n_estimators=45
# [CV 2/5; 15/15] END max_depth=None, max_features=18, min_samples_leaf=19, min_samples_split=10, n_estimators=45;, score=0.988 total time=21.2min
# [CV 3/5; 15/15] START max_depth=None, max_features=18, min_samples_leaf=19, min_samples_split=10, n_estimators=45
# [CV 3/5; 15/15] END max_depth=None, max_features=18, min_samples_leaf=19, min_samples_split=10, n_estimators=45;, score=0.988 total time=21.0min
# [CV 4/5; 15/15] START max_depth=None, max_features=18, min_samples_leaf=19, min_samples_split=10, n_estimators=45
# [CV 4/5; 15/15] END max_depth=None, max_features=18, min_samples_leaf=19, min_samples_split=10, n_estimators=45;, score=0.988 total time=21.3min
# [CV 5/5; 15/15] START max_depth=None, max_features=18, min_samples_leaf=19, min_samples_split=10, n_estimators=45
# [CV 5/5; 15/15] END max_depth=None, max_features=18, min_samples_leaf=19, min_samples_split=10, n_estimators=45;, score=0.988 total time=18.4min
# Lama waktu 'hyperparameter tuning' :  43345.59543824196

# %%
# Hasil tuning hyperparameter #
# =========================== #

# hasil
print ('F1 skor dan parameter terbaik')
print ('=============================')
print ('Nilai F1 skor terbaik : %s' % rf_random.best_score_)
print ('Parameter terbaik     : %s' % rf_random.best_params_)
print ('Estimator terbaik     : %s' % rf_random.best_estimator_)
test_49_rf_new_params_2 = pd.DataFrame(rf_random.cv_results_)

# simpan hasil hyperparameter random forest
test_49_rf_new_params_2.to_csv("G:\\Universitas Indonesia\\Rancangan Paper\\Dataset CSE-CIC-IDS2018-AWS\\CIC2018\\test_49_rf_new_params_2.txt", index=False)
# Out:
# F1 skor dan parameter terbaik
# =============================
# Nilai F1 skor terbaik : 0.9880155314273734
# Parameter terbaik     : {'n_estimators': 45, 'min_samples_split': 20, 'min_samples_leaf': 7, 'max_features': 15, 'max_depth': 35}
# Estimator terbaik     : RandomForestClassifier(max_depth=35, max_features=15, min_samples_leaf=7,
#                        min_samples_split=20, n_estimators=45, n_jobs=-1,
#                        random_state=42)

# %% [markdown]
# ### 49.4. Hyperparameter terbaik

# %%
# 5 hyperparameter terbaik #
# ======================== #

# hyperparameter terbaik
hyperparam_rf = pd.read_csv("G:\\Universitas Indonesia\\Rancangan Paper\\Dataset CSE-CIC-IDS2018-AWS\\CIC2018\\test_49_rf_new_params_2.txt")

# mengurutkan hyperparameter terbaik berdasarkan f1
hyperparam_rf = hyperparam_rf.sort_values("rank_test_score")

# menampilkan 5 hyperparameter terbaik
print ('5 hyperparameter terbaik berdasarkan f1')
print ('=======================================')
param = hyperparam_rf[['rank_test_score','params','mean_fit_time','mean_test_score']].reset_index(drop=True)
#param = param[['params']]
param.head(5)
# Out:
# 5 hyperparameter terbaik berdasarkan f1
# =======================================
#    rank_test_score  \
# 0                1
# 1                2
# 2                3
# 3                4
# 4                5
#
#                                                                                                          params  \
# 0     {'n_estimators': 45, 'min_samples_split': 20, 'min_samples_leaf': 7, 'max_features': 15, 'max_depth': 35}
# 1     {'n_estimators': 45, 'min_samples_split': 4, 'min_samples_leaf': 12, 'max_features': 18, 'max_depth': 35}
# 2  {'n_estimators': 45, 'min_samples_split': 10, 'min_samples_leaf': 19, 'max_features': 18, 'max_depth': None}
# 3    {'n_estimators': 45, 'min_samples_split': 17, 'min_samples_leaf': 11, 'max_features': 15, 'max_depth': 20}
# 4     {'n_estimators': 45, 'min_samples_split': 5, 'min_samples_leaf': 20, 'max_features': 12, 'max_depth': 35}
#
#    mean_fit_time  mean_test_score
# 0     882.418129         0.988016
# 1    1031.740965         0.987993
# 2    1216.792960         0.987958
# 3     723.704648         0.987947
# 4     716.057742         0.987852

# %% [markdown]
# #### 49.4.1. Latih hyperparameter terbaik berdasarkan f1

# %%
param_rf = param['params'][0]
param_terbaik = [eval(param_rf)]  

#jumlah estimator
for n in param_terbaik:
    jlh_estimator=[n['n_estimators']]
    
param_terbaik
# Out:
# [{'n_estimators': 45,
#   'min_samples_split': 20,
#   'min_samples_leaf': 7,
#   'max_features': 15,
#   'max_depth': 35}]

# %%
print ('|=======================================|')
print ("| Hyperparameter terbaik berdasarkan f1 |")
print ('|=======================================|')
print ('')
klf_f1, y_f1 = latih_eval_rf(param_terbaik, jlh_estimator, y_aktual_biner)
# Out:
# |=======================================|
# | Hyperparameter terbaik berdasarkan f1 |
# |=======================================|
#
# hyperparameter : {'n_estimators': 45, 'min_samples_split': 20, 'min_samples_leaf': 7, 'max_features': 15, 'max_depth': 35}
# Lama waktu latih    : 6327.0758764743805
# Lama waktu prediksi : 26.191251516342163
# hasil 'Accuracy'    : 0.9911000583005393
# hasil 'f1-score'    : 0.9880015018190846

# %% [markdown]
# #### 49.4.2. Metrik evaluasi

# %%
# metrik evaluasi lapisan 1 berdasarkan f1
metrik (None, 1, y_aktual_biner, y_f1)

# misklasifikasi lapisan 1
misklasifikasi(y_aktual_biner, y_f1)
# Out:
# Accuracy, Precision, Recall dan F1-score :
# ==========================================
# Accuracy  : 0.9911000583005393
# Precision : 0.9936227340877448
# Recall    : 0.9826810960501384
# F1-score  : 0.9880015018190846
#
# metrik evaluasi :
# =================
#               precision    recall  f1-score   support
#
#       attack   0.998508  0.965843  0.981904    548880
#       benign   0.988737  0.999519  0.994099   1646640
#
#     accuracy                       0.991100   2195520
#    macro avg   0.993623  0.982681  0.988002   2195520
# weighted avg   0.991180  0.991100  0.991050   2195520
#
#
# matriks "confusion" :
# =====================
# misklasifikasi kelas target:
# ============================
#         misklasifikasi    total  persentase_misklasifikasi(%)
# attack           18748   548880                      3.415683
# benign             792  1646640                      0.048098

# %% [markdown]
# # ===================================

# %% [markdown]
# ## Test 50

# %% [markdown]
# ### 50.1. Seleksi fitur chi squared - 99%

# %%
# Seleksi fitur dengan 'chi squared' #
# ================================== #

m_sf = time.time()

# ambang batas persentase skor
persentase_skor = 99

# vektor target
vektor_target = y_train['label']

# fitur terpilih dan fitur dihapus
fit_chi = seleksi_fitur(chi2, X_train_norm, vektor_target)
fitur_dihapus_chi,fitur_terpilih_chi = fitur_terbaik (fit_chi, persentase_skor, X_train_norm, 'chi')

# hapus fitur dengan skor terendah
X_train_chi = X_train_norm.drop(fitur_dihapus_chi, axis=1)
X_test_chi = X_test_norm.drop(fitur_dihapus_chi, axis=1)

s_sf = time.time()
print ('')
print ("Lama waktu seleksi fitur 'chi squared' : ", s_sf - m_sf)
# Out:
# Fitur yang dihapus
# ==================
# ['bwd_pkt_len_min', 'pkt_len_mean', 'pkt_size_avg', 'bwd_pkt_len_mean', 'fwd_iat_std', 'fwd_urg_flags', 'pkt_len_min', 'fwd_pkt_len_min', 'pkt_len_max', 'bwd_pkt_len_max', 'pkt_len_var', 'fin_flag_cnt', 'bwd_header_len', 'down_up_ratio', 'flow_byts_s', 'tot_bwd_pkts', 'totlen_bwd_pkts']
#
#
# Fitur dengan skor terbaik
# =========================
#     Skor Chi-kuadrat              Fitur  Persentase skor  jumlah persentase
# 1       2.409937e+06  fwd_act_data_pkts         7.434345           7.434345
# 2       2.296485e+06       tot_fwd_pkts         7.084360          14.518704
# 3       2.215494e+06        flow_pkts_s         6.834514          21.353218
# 4       1.862728e+06     fwd_header_len         5.746274          27.099492
# 5       1.811408e+06         bwd_pkts_s         5.587960          32.687452
# 6       1.673186e+06    totlen_fwd_pkts         5.161564          37.849016
# 7       1.331233e+06  init_fwd_win_byts         4.106681          41.955697
# 8       1.327604e+06        bwd_iat_min         4.095486          46.051183
# 9       1.184807e+06           idle_std         3.654976          49.706159
# 10      1.022994e+06         fwd_pkts_s         3.155805          52.861964
# 11      1.006798e+06       ack_flag_cnt         3.105840          55.967804
# 12      7.796834e+05       bwd_iat_mean         2.405223          58.373027
# 13      7.791878e+05           idle_max         2.403694          60.776720
# 14      7.674690e+05       urg_flag_cnt         2.367543          63.144263
# 15      7.431888e+05        fwd_iat_min         2.292642          65.436904
# 16      7.225461e+05       flow_iat_min         2.228962          67.665866
# 17      6.989168e+05          idle_mean         2.156068          69.821934
# 18      6.798157e+05           protocol         2.097144          71.919078
# 19      6.643303e+05           idle_min         2.049373          73.968451
# 20      6.234639e+05      flow_iat_mean         1.923305          75.891756
# 21      6.161725e+05       fwd_iat_mean         1.900813          77.792569
# 22      6.040468e+05        fwd_iat_tot         1.863406          79.655975
# 23      5.763463e+05      flow_duration         1.777954          81.433929
# 24      5.006695e+05       rst_flag_cnt         1.544501          82.978430
# 25      5.006693e+05       ece_flag_cnt         1.544500          84.522930
# 26      4.944611e+05        bwd_iat_tot         1.525349          86.048279
# 27      4.781651e+05        bwd_iat_max         1.475078          87.523357
# 28      4.762831e+05        fwd_iat_max         1.469272          88.992628
# 29      4.656907e+05       flow_iat_max         1.436596          90.429224
# 30      4.651505e+05   fwd_seg_size_min         1.434929          91.864153
# 31      4.644499e+05  init_bwd_win_byts         1.432768          93.296921
# 32      4.195247e+05       psh_flag_cnt         1.294179          94.591101
# 33      2.848472e+05           dst_port         0.878717          95.469817
# 34      1.872405e+05       flow_iat_std         0.577613          96.047430
# 35      1.146484e+05        bwd_iat_std         0.353676          96.401106
# 36      1.125301e+05    fwd_pkt_len_max         0.347141          96.748247
# 37      1.050770e+05      fwd_psh_flags         0.324149          97.072396
# 38      9.772379e+04         active_max         0.301465          97.373861
# 39      7.531431e+04        active_mean         0.232335          97.606196
# 40      7.439370e+04    fwd_pkt_len_std         0.229495          97.835691
# 41      7.375318e+04         active_std         0.227519          98.063210
# 42      7.091767e+04    bwd_pkt_len_std         0.218772          98.281982
# 43      6.029050e+04        pkt_len_std         0.185988          98.467970
# 44      5.180169e+04          timestamp         0.159802          98.627772
# 45      5.129903e+04   fwd_pkt_len_mean         0.158251          98.786023
# 46      5.055095e+04         active_min         0.155943          98.941966
#
# Lama waktu seleksi fitur 'chi squared' :  33.5573353767395

# %%
# label aktual dan jumlah fitur #
# ============================= #

# label aktual biner kelas
y_aktual_biner = y_test['label_binary'].reset_index(drop=True)

# fitur dan jumlah fitur yang digunakan
print ('Fitur yang digunakan')
print ('====================')
print (list(X_train_chi.columns))
print ('')
print ('Jumlah fitur')
print ('============')
print (len(X_train_chi.columns),'fitur')
# Out:
# Fitur yang digunakan
# ====================
# ['dst_port', 'protocol', 'timestamp', 'flow_duration', 'tot_fwd_pkts', 'totlen_fwd_pkts', 'fwd_pkt_len_max', 'fwd_pkt_len_mean', 'fwd_pkt_len_std', 'bwd_pkt_len_std', 'flow_pkts_s', 'flow_iat_mean', 'flow_iat_std', 'flow_iat_max', 'flow_iat_min', 'fwd_iat_tot', 'fwd_iat_mean', 'fwd_iat_max', 'fwd_iat_min', 'bwd_iat_tot', 'bwd_iat_mean', 'bwd_iat_std', 'bwd_iat_max', 'bwd_iat_min', 'fwd_psh_flags', 'fwd_header_len', 'fwd_pkts_s', 'bwd_pkts_s', 'pkt_len_std', 'rst_flag_cnt', 'psh_flag_cnt', 'ack_flag_cnt', 'urg_flag_cnt', 'ece_flag_cnt', 'init_fwd_win_byts', 'init_bwd_win_byts', 'fwd_act_data_pkts', 'fwd_seg_size_min', 'active_mean', 'active_std', 'active_max', 'active_min', 'idle_mean', 'idle_std', 'idle_max', 'idle_min']
#
# Jumlah fitur
# ============
# 46 fitur

# %% [markdown]
# ### 50.2. Pemilihan jumlah 'tree'

# %%
# Pemilihan jumlah 'trees' #
# ======================== #

m_jlh = time.time()

# parameter yang digunakan
param_klf = [{'random_state':42, 'n_jobs':-1}]                
jlh_estimator = [10,15,20,25,30,35,40,45,50]

# hasil pelatihan
latih_eval_rf(param_klf, jlh_estimator, y_aktual_biner)

s_jlh = time.time()
print ("Lama waktu pencarian jumlah 'tree' : ", s_jlh - m_jlh)
# Out:
# jumlah 'trees' : 10
# ===================
# hyperparameter : {'random_state': 42, 'n_jobs': -1}
# Lama waktu latih    : 141.03467440605164
# Lama waktu prediksi : 1.347102165222168
# hasil 'Accuracy'    : 0.995890267453724
# hasil 'f1-score'    : 0.9945155672836028
#
# jumlah 'trees' : 15
# ===================
# hyperparameter : {'random_state': 42, 'n_jobs': -1}
# Lama waktu latih    : 158.34998750686646
# Lama waktu prediksi : 1.7111294269561768
# hasil 'Accuracy'    : 0.9959768073167177
# hasil 'f1-score'    : 0.9946317733364708
#
# jumlah 'trees' : 20
# ===================
# hyperparameter : {'random_state': 42, 'n_jobs': -1}
# Lama waktu latih    : 219.03367137908936
# Lama waktu prediksi : 1.8881430625915527
# hasil 'Accuracy'    : 0.9959768073167177
# hasil 'f1-score'    : 0.9946322762395147
#
# jumlah 'trees' : 25
# ===================
# hyperparameter : {'random_state': 42, 'n_jobs': -1}
# Lama waktu latih    : 260.90375089645386
# Lama waktu prediksi : 2.2371697425842285
# hasil 'Accuracy'    : 0.9959813620463489
# hasil 'f1-score'    : 0.9946379030017145
#
# jumlah 'trees' : 30
# ===================
# hyperparameter : {'random_state': 42, 'n_jobs': -1}
# Lama waktu latih    : 310.02246952056885
# Lama waktu prediksi : 2.6512012481689453
# hasil 'Accuracy'    : 0.995989105086722
# hasil 'f1-score'    : 0.9946485178448274
#
# jumlah 'trees' : 35
# ===================
# hyperparameter : {'random_state': 42, 'n_jobs': -1}
# Lama waktu latih    : 361.8043894767761
# Lama waktu prediksi : 3.067232370376587
# hasil 'Accuracy'    : 0.9959813620463489
# hasil 'f1-score'    : 0.9946380530615686
#
# jumlah 'trees' : 40
# ===================
# hyperparameter : {'random_state': 42, 'n_jobs': -1}
# Lama waktu latih    : 396.89604687690735
# Lama waktu prediksi : 3.31425142288208
# hasil 'Accuracy'    : 0.9959845503570908
# hasil 'f1-score'    : 0.9946423494999657
#
# jumlah 'trees' : 45
# ===================
# hyperparameter : {'random_state': 42, 'n_jobs': -1}
# Lama waktu latih    : 449.4150230884552
# Lama waktu prediksi : 3.723281145095825
# hasil 'Accuracy'    : 0.9959722525870864
# hasil 'f1-score'    : 0.9946258070398263
#
# jumlah 'trees' : 50
# ===================
# hyperparameter : {'random_state': 42, 'n_jobs': -1}
# Lama waktu latih    : 498.190714597702
# Lama waktu prediksi : 4.157315492630005
# hasil 'Accuracy'    : 0.9959749854248652
# hasil 'f1-score'    : 0.9946296756105345
#
# Lama waktu pencarian jumlah 'tree' :  3270.6026842594147

# %%
# list hasil pelatihan
print ('List hasil pelatihan')
print ('====================')
print ('hasil_waktu_latih    =', hasil_waktu_latih)
print ('hasil_waktu_prediksi =', hasil_waktu_pred)
print ('hasil_f1_macro       =', hasil_f1_macro)
print ('hasil_akurasi        =', hasil_akurasi)
print ('jumlah_estimator     =', jlh_estimator)
# Out:
# List hasil pelatihan
# ====================
# hasil_waktu_latih    = [141.03467440605164, 158.34998750686646, 219.03367137908936, 260.90375089645386, 310.02246952056885, 361.8043894767761, 396.89604687690735, 449.4150230884552, 498.190714597702]
# hasil_waktu_prediksi = [1.347102165222168, 1.7111294269561768, 1.8881430625915527, 2.2371697425842285, 2.6512012481689453, 3.067232370376587, 3.31425142288208, 3.723281145095825, 4.157315492630005]
# hasil_f1_macro       = [0.9945155672836028, 0.9946317733364708, 0.9946322762395147, 0.9946379030017145, 0.9946485178448274, 0.9946380530615686, 0.9946423494999657, 0.9946258070398263, 0.9946296756105345]
# hasil_akurasi        = [0.995890267453724, 0.9959768073167177, 0.9959768073167177, 0.9959813620463489, 0.995989105086722, 0.9959813620463489, 0.9959845503570908, 0.9959722525870864, 0.9959749854248652]
# jumlah_estimator     = [10, 15, 20, 25, 30, 35, 40, 45, 50]

# %% [markdown]
# #### 50.2.1. Plot hasil pengukuran

# %%
# Plot hasil pengukuran #
# ===================== #

# Plot waktu latih dan akurasi
plot_eval(hasil_waktu_latih,hasil_akurasi,jumlah_estimator,'Jumlah "trees"','Waktu latih','Accuracy')

# Plot waktu prediksi dan akurasi
plot_eval(hasil_waktu_pred,hasil_akurasi,jumlah_estimator,'Jumlah "trees"','Waktu prediksi','Accuracy')

# Plot waktu pelatihan
plot_eval(None,hasil_waktu_latih,jumlah_estimator,'Jumlah trees','Waktu latih',None)

# Plot waktu prediksi
plot_eval(None,hasil_waktu_pred,jumlah_estimator,'Jumlah trees','Waktu prediksi',None)

# Plot Akurasi
plot_eval(None,hasil_akurasi,jumlah_estimator,'Jumlah trees','Accuracy',None)

# plot F1
plot_eval(None,hasil_f1_macro,jumlah_estimator,'Jumlah trees','F1-score',None)
# Out:
#  PLOT WAKTU LATIH
# ==================
#  PLOT WAKTU PREDIKSI
# =====================
#  PLOT WAKTU LATIH
# ==================
#  PLOT WAKTU PREDIKSI
# =====================
#  PLOT ACCURACY
# ===============
#  PLOT F1-SCORE
# ===============

# %% [markdown]
# ### 50.3. Hyperparameter tuning random forest

# %%
# Hyperparameter tuning random forest #
# =================================== #

m_hyper = time.time()

# hyperparameter yang digunakan untuk tuning
jlh_estimator     = [30]
max_features      = [5, 9, 12, 15, 18]
max_depth         = [None,5,10,15,20,25,30,35]
min_samples_split = [2,3,4,5,6,7,9,10,11,12,13,14,15,16,17,17,18,19,20]
min_samples_leaf  = [2,3,4,5,6,7,9,10,11,12,13,14,15,16,17,17,18,19,20]

# pembangunan model
rf = RandomForestClassifier(random_state=42, n_jobs=-1)

# jumlah acak kombinasi nilai hyperparameter
n_iter = 15

# validasi silang 5 lipatan
cv = 5

# tentukan f1 macro
f1_macro_scorer = make_scorer(f1_score, greater_is_better=True, average='macro')

# random grid search
random_grid = {'n_estimators': jlh_estimator,'max_depth': max_depth,'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,'max_features': max_features}

rf_random = RandomizedSearchCV(estimator=rf, param_distributions=random_grid, 
                               n_iter=n_iter, cv=cv, verbose=10, random_state=18, n_jobs=None, scoring=f1_macro_scorer)

# terapkan random grid pada data latih
rf_random.fit(X_train_chi, y_train['label_binary'])

s_hyper = time.time()
print ("Lama waktu 'hyperparameter tuning' : ", s_hyper - m_hyper)
# Out:
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
# [CV 1/5; 1/15] START max_depth=30, max_features=12, min_samples_leaf=2, min_samples_split=13, n_estimators=30
# [CV 1/5; 1/15] END max_depth=30, max_features=12, min_samples_leaf=2, min_samples_split=13, n_estimators=30;, score=0.996 total time= 7.2min
# [CV 2/5; 1/15] START max_depth=30, max_features=12, min_samples_leaf=2, min_samples_split=13, n_estimators=30
# [CV 2/5; 1/15] END max_depth=30, max_features=12, min_samples_leaf=2, min_samples_split=13, n_estimators=30;, score=0.996 total time= 7.1min
# [CV 3/5; 1/15] START max_depth=30, max_features=12, min_samples_leaf=2, min_samples_split=13, n_estimators=30
# [CV 3/5; 1/15] END max_depth=30, max_features=12, min_samples_leaf=2, min_samples_split=13, n_estimators=30;, score=0.996 total time= 7.1min
# [CV 4/5; 1/15] START max_depth=30, max_features=12, min_samples_leaf=2, min_samples_split=13, n_estimators=30
# [CV 4/5; 1/15] END max_depth=30, max_features=12, min_samples_leaf=2, min_samples_split=13, n_estimators=30;, score=0.996 total time= 7.3min
# [CV 5/5; 1/15] START max_depth=30, max_features=12, min_samples_leaf=2, min_samples_split=13, n_estimators=30
# [CV 5/5; 1/15] END max_depth=30, max_features=12, min_samples_leaf=2, min_samples_split=13, n_estimators=30;, score=0.996 total time= 7.2min
# [CV 1/5; 2/15] START max_depth=30, max_features=18, min_samples_leaf=17, min_samples_split=6, n_estimators=30
# [CV 1/5; 2/15] END max_depth=30, max_features=18, min_samples_leaf=17, min_samples_split=6, n_estimators=30;, score=0.996 total time= 9.2min
# [CV 2/5; 2/15] START max_depth=30, max_features=18, min_samples_leaf=17, min_samples_split=6, n_estimators=30
# [CV 2/5; 2/15] END max_depth=30, max_features=18, min_samples_leaf=17, min_samples_split=6, n_estimators=30;, score=0.996 total time= 9.6min
# [CV 3/5; 2/15] START max_depth=30, max_features=18, min_samples_leaf=17, min_samples_split=6, n_estimators=30
# [CV 3/5; 2/15] END max_depth=30, max_features=18, min_samples_leaf=17, min_samples_split=6, n_estimators=30;, score=0.996 total time= 9.4min
# [CV 4/5; 2/15] START max_depth=30, max_features=18, min_samples_leaf=17, min_samples_split=6, n_estimators=30
# [CV 4/5; 2/15] END max_depth=30, max_features=18, min_samples_leaf=17, min_samples_split=6, n_estimators=30;, score=0.996 total time= 9.3min
# [CV 5/5; 2/15] START max_depth=30, max_features=18, min_samples_leaf=17, min_samples_split=6, n_estimators=30
# [CV 5/5; 2/15] END max_depth=30, max_features=18, min_samples_leaf=17, min_samples_split=6, n_estimators=30;, score=0.996 total time= 9.1min
# [CV 1/5; 3/15] START max_depth=25, max_features=5, min_samples_leaf=18, min_samples_split=10, n_estimators=30
# [CV 1/5; 3/15] END max_depth=25, max_features=5, min_samples_leaf=18, min_samples_split=10, n_estimators=30;, score=0.996 total time= 3.7min
# [CV 2/5; 3/15] START max_depth=25, max_features=5, min_samples_leaf=18, min_samples_split=10, n_estimators=30
# [CV 2/5; 3/15] END max_depth=25, max_features=5, min_samples_leaf=18, min_samples_split=10, n_estimators=30;, score=0.996 total time= 3.7min
# [CV 3/5; 3/15] START max_depth=25, max_features=5, min_samples_leaf=18, min_samples_split=10, n_estimators=30
# [CV 3/5; 3/15] END max_depth=25, max_features=5, min_samples_leaf=18, min_samples_split=10, n_estimators=30;, score=0.996 total time= 3.8min
# [CV 4/5; 3/15] START max_depth=25, max_features=5, min_samples_leaf=18, min_samples_split=10, n_estimators=30
# [CV 4/5; 3/15] END max_depth=25, max_features=5, min_samples_leaf=18, min_samples_split=10, n_estimators=30;, score=0.995 total time= 3.8min
# [CV 5/5; 3/15] START max_depth=25, max_features=5, min_samples_leaf=18, min_samples_split=10, n_estimators=30
# [CV 5/5; 3/15] END max_depth=25, max_features=5, min_samples_leaf=18, min_samples_split=10, n_estimators=30;, score=0.996 total time= 3.7min
# [CV 1/5; 4/15] START max_depth=5, max_features=12, min_samples_leaf=20, min_samples_split=18, n_estimators=30
# [CV 1/5; 4/15] END max_depth=5, max_features=12, min_samples_leaf=20, min_samples_split=18, n_estimators=30;, score=0.986 total time= 2.9min
# [CV 2/5; 4/15] START max_depth=5, max_features=12, min_samples_leaf=20, min_samples_split=18, n_estimators=30
# [CV 2/5; 4/15] END max_depth=5, max_features=12, min_samples_leaf=20, min_samples_split=18, n_estimators=30;, score=0.987 total time= 2.9min
# [CV 3/5; 4/15] START max_depth=5, max_features=12, min_samples_leaf=20, min_samples_split=18, n_estimators=30
# [CV 3/5; 4/15] END max_depth=5, max_features=12, min_samples_leaf=20, min_samples_split=18, n_estimators=30;, score=0.987 total time= 2.9min
# [CV 4/5; 4/15] START max_depth=5, max_features=12, min_samples_leaf=20, min_samples_split=18, n_estimators=30
# [CV 4/5; 4/15] END max_depth=5, max_features=12, min_samples_leaf=20, min_samples_split=18, n_estimators=30;, score=0.985 total time= 2.9min
# [CV 5/5; 4/15] START max_depth=5, max_features=12, min_samples_leaf=20, min_samples_split=18, n_estimators=30
# [CV 5/5; 4/15] END max_depth=5, max_features=12, min_samples_leaf=20, min_samples_split=18, n_estimators=30;, score=0.985 total time= 2.9min
# [CV 1/5; 5/15] START max_depth=None, max_features=18, min_samples_leaf=17, min_samples_split=18, n_estimators=30
# [CV 1/5; 5/15] END max_depth=None, max_features=18, min_samples_leaf=17, min_samples_split=18, n_estimators=30;, score=0.996 total time= 9.2min
# [CV 2/5; 5/15] START max_depth=None, max_features=18, min_samples_leaf=17, min_samples_split=18, n_estimators=30
# [CV 2/5; 5/15] END max_depth=None, max_features=18, min_samples_leaf=17, min_samples_split=18, n_estimators=30;, score=0.996 total time= 9.5min
# [CV 3/5; 5/15] START max_depth=None, max_features=18, min_samples_leaf=17, min_samples_split=18, n_estimators=30
# [CV 3/5; 5/15] END max_depth=None, max_features=18, min_samples_leaf=17, min_samples_split=18, n_estimators=30;, score=0.996 total time= 9.7min
# [CV 4/5; 5/15] START max_depth=None, max_features=18, min_samples_leaf=17, min_samples_split=18, n_estimators=30
# [CV 4/5; 5/15] END max_depth=None, max_features=18, min_samples_leaf=17, min_samples_split=18, n_estimators=30;, score=0.996 total time= 9.5min
# [CV 5/5; 5/15] START max_depth=None, max_features=18, min_samples_leaf=17, min_samples_split=18, n_estimators=30
# [CV 5/5; 5/15] END max_depth=None, max_features=18, min_samples_leaf=17, min_samples_split=18, n_estimators=30;, score=0.996 total time= 9.2min
# [CV 1/5; 6/15] START max_depth=10, max_features=18, min_samples_leaf=15, min_samples_split=15, n_estimators=30
# [CV 1/5; 6/15] END max_depth=10, max_features=18, min_samples_leaf=15, min_samples_split=15, n_estimators=30;, score=0.995 total time= 6.7min
# [CV 2/5; 6/15] START max_depth=10, max_features=18, min_samples_leaf=15, min_samples_split=15, n_estimators=30
# [CV 2/5; 6/15] END max_depth=10, max_features=18, min_samples_leaf=15, min_samples_split=15, n_estimators=30;, score=0.995 total time= 6.4min
# [CV 3/5; 6/15] START max_depth=10, max_features=18, min_samples_leaf=15, min_samples_split=15, n_estimators=30
# [CV 3/5; 6/15] END max_depth=10, max_features=18, min_samples_leaf=15, min_samples_split=15, n_estimators=30;, score=0.995 total time= 6.5min
# [CV 4/5; 6/15] START max_depth=10, max_features=18, min_samples_leaf=15, min_samples_split=15, n_estimators=30
# [CV 4/5; 6/15] END max_depth=10, max_features=18, min_samples_leaf=15, min_samples_split=15, n_estimators=30;, score=0.995 total time= 6.5min
# [CV 5/5; 6/15] START max_depth=10, max_features=18, min_samples_leaf=15, min_samples_split=15, n_estimators=30
# [CV 5/5; 6/15] END max_depth=10, max_features=18, min_samples_leaf=15, min_samples_split=15, n_estimators=30;, score=0.995 total time= 6.5min
# [CV 1/5; 7/15] START max_depth=5, max_features=9, min_samples_leaf=9, min_samples_split=13, n_estimators=30
# [CV 1/5; 7/15] END max_depth=5, max_features=9, min_samples_leaf=9, min_samples_split=13, n_estimators=30;, score=0.980 total time= 2.4min
# [CV 2/5; 7/15] START max_depth=5, max_features=9, min_samples_leaf=9, min_samples_split=13, n_estimators=30
# [CV 2/5; 7/15] END max_depth=5, max_features=9, min_samples_leaf=9, min_samples_split=13, n_estimators=30;, score=0.980 total time= 2.4min
# [CV 3/5; 7/15] START max_depth=5, max_features=9, min_samples_leaf=9, min_samples_split=13, n_estimators=30
# [CV 3/5; 7/15] END max_depth=5, max_features=9, min_samples_leaf=9, min_samples_split=13, n_estimators=30;, score=0.981 total time= 2.4min
# [CV 4/5; 7/15] START max_depth=5, max_features=9, min_samples_leaf=9, min_samples_split=13, n_estimators=30
# [CV 4/5; 7/15] END max_depth=5, max_features=9, min_samples_leaf=9, min_samples_split=13, n_estimators=30;, score=0.981 total time= 2.4min
# [CV 5/5; 7/15] START max_depth=5, max_features=9, min_samples_leaf=9, min_samples_split=13, n_estimators=30
# [CV 5/5; 7/15] END max_depth=5, max_features=9, min_samples_leaf=9, min_samples_split=13, n_estimators=30;, score=0.983 total time= 2.4min
# [CV 1/5; 8/15] START max_depth=35, max_features=5, min_samples_leaf=15, min_samples_split=5, n_estimators=30
# [CV 1/5; 8/15] END max_depth=35, max_features=5, min_samples_leaf=15, min_samples_split=5, n_estimators=30;, score=0.996 total time= 4.1min
# [CV 2/5; 8/15] START max_depth=35, max_features=5, min_samples_leaf=15, min_samples_split=5, n_estimators=30
# [CV 2/5; 8/15] END max_depth=35, max_features=5, min_samples_leaf=15, min_samples_split=5, n_estimators=30;, score=0.995 total time= 4.1min
# [CV 3/5; 8/15] START max_depth=35, max_features=5, min_samples_leaf=15, min_samples_split=5, n_estimators=30
# [CV 3/5; 8/15] END max_depth=35, max_features=5, min_samples_leaf=15, min_samples_split=5, n_estimators=30;, score=0.996 total time= 4.0min
# [CV 4/5; 8/15] START max_depth=35, max_features=5, min_samples_leaf=15, min_samples_split=5, n_estimators=30
# [CV 4/5; 8/15] END max_depth=35, max_features=5, min_samples_leaf=15, min_samples_split=5, n_estimators=30;, score=0.995 total time= 4.2min
# [CV 5/5; 8/15] START max_depth=35, max_features=5, min_samples_leaf=15, min_samples_split=5, n_estimators=30
# [CV 5/5; 8/15] END max_depth=35, max_features=5, min_samples_leaf=15, min_samples_split=5, n_estimators=30;, score=0.996 total time= 3.9min
# [CV 1/5; 9/15] START max_depth=5, max_features=9, min_samples_leaf=10, min_samples_split=16, n_estimators=30
# [CV 1/5; 9/15] END max_depth=5, max_features=9, min_samples_leaf=10, min_samples_split=16, n_estimators=30;, score=0.980 total time= 2.4min
# [CV 2/5; 9/15] START max_depth=5, max_features=9, min_samples_leaf=10, min_samples_split=16, n_estimators=30
# [CV 2/5; 9/15] END max_depth=5, max_features=9, min_samples_leaf=10, min_samples_split=16, n_estimators=30;, score=0.980 total time= 2.4min
# [CV 3/5; 9/15] START max_depth=5, max_features=9, min_samples_leaf=10, min_samples_split=16, n_estimators=30
# [CV 3/5; 9/15] END max_depth=5, max_features=9, min_samples_leaf=10, min_samples_split=16, n_estimators=30;, score=0.981 total time= 2.4min
# [CV 4/5; 9/15] START max_depth=5, max_features=9, min_samples_leaf=10, min_samples_split=16, n_estimators=30
# [CV 4/5; 9/15] END max_depth=5, max_features=9, min_samples_leaf=10, min_samples_split=16, n_estimators=30;, score=0.981 total time= 2.4min
# [CV 5/5; 9/15] START max_depth=5, max_features=9, min_samples_leaf=10, min_samples_split=16, n_estimators=30
# [CV 5/5; 9/15] END max_depth=5, max_features=9, min_samples_leaf=10, min_samples_split=16, n_estimators=30;, score=0.983 total time= 2.4min
# [CV 1/5; 10/15] START max_depth=30, max_features=15, min_samples_leaf=2, min_samples_split=17, n_estimators=30
# [CV 1/5; 10/15] END max_depth=30, max_features=15, min_samples_leaf=2, min_samples_split=17, n_estimators=30;, score=0.996 total time= 8.5min
# [CV 2/5; 10/15] START max_depth=30, max_features=15, min_samples_leaf=2, min_samples_split=17, n_estimators=30
# [CV 2/5; 10/15] END max_depth=30, max_features=15, min_samples_leaf=2, min_samples_split=17, n_estimators=30;, score=0.996 total time= 8.4min
# [CV 3/5; 10/15] START max_depth=30, max_features=15, min_samples_leaf=2, min_samples_split=17, n_estimators=30
# [CV 3/5; 10/15] END max_depth=30, max_features=15, min_samples_leaf=2, min_samples_split=17, n_estimators=30;, score=0.996 total time= 8.6min
# [CV 4/5; 10/15] START max_depth=30, max_features=15, min_samples_leaf=2, min_samples_split=17, n_estimators=30
# [CV 4/5; 10/15] END max_depth=30, max_features=15, min_samples_leaf=2, min_samples_split=17, n_estimators=30;, score=0.996 total time= 8.4min
# [CV 5/5; 10/15] START max_depth=30, max_features=15, min_samples_leaf=2, min_samples_split=17, n_estimators=30
# [CV 5/5; 10/15] END max_depth=30, max_features=15, min_samples_leaf=2, min_samples_split=17, n_estimators=30;, score=0.996 total time= 8.3min
# [CV 1/5; 11/15] START max_depth=15, max_features=18, min_samples_leaf=3, min_samples_split=6, n_estimators=30
# [CV 1/5; 11/15] END max_depth=15, max_features=18, min_samples_leaf=3, min_samples_split=6, n_estimators=30;, score=0.997 total time= 8.6min
# [CV 2/5; 11/15] START max_depth=15, max_features=18, min_samples_leaf=3, min_samples_split=6, n_estimators=30
# [CV 2/5; 11/15] END max_depth=15, max_features=18, min_samples_leaf=3, min_samples_split=6, n_estimators=30;, score=0.997 total time= 8.6min
# [CV 3/5; 11/15] START max_depth=15, max_features=18, min_samples_leaf=3, min_samples_split=6, n_estimators=30
# [CV 3/5; 11/15] END max_depth=15, max_features=18, min_samples_leaf=3, min_samples_split=6, n_estimators=30;, score=0.997 total time= 8.9min
# [CV 4/5; 11/15] START max_depth=15, max_features=18, min_samples_leaf=3, min_samples_split=6, n_estimators=30
# [CV 4/5; 11/15] END max_depth=15, max_features=18, min_samples_leaf=3, min_samples_split=6, n_estimators=30;, score=0.997 total time= 8.6min
# [CV 5/5; 11/15] START max_depth=15, max_features=18, min_samples_leaf=3, min_samples_split=6, n_estimators=30
# [CV 5/5; 11/15] END max_depth=15, max_features=18, min_samples_leaf=3, min_samples_split=6, n_estimators=30;, score=0.997 total time= 8.7min
# [CV 1/5; 12/15] START max_depth=25, max_features=5, min_samples_leaf=6, min_samples_split=6, n_estimators=30
# [CV 1/5; 12/15] END max_depth=25, max_features=5, min_samples_leaf=6, min_samples_split=6, n_estimators=30;, score=0.996 total time= 3.9min
# [CV 2/5; 12/15] START max_depth=25, max_features=5, min_samples_leaf=6, min_samples_split=6, n_estimators=30
# [CV 2/5; 12/15] END max_depth=25, max_features=5, min_samples_leaf=6, min_samples_split=6, n_estimators=30;, score=0.996 total time= 3.9min
# [CV 3/5; 12/15] START max_depth=25, max_features=5, min_samples_leaf=6, min_samples_split=6, n_estimators=30
# [CV 3/5; 12/15] END max_depth=25, max_features=5, min_samples_leaf=6, min_samples_split=6, n_estimators=30;, score=0.995 total time= 4.0min
# [CV 4/5; 12/15] START max_depth=25, max_features=5, min_samples_leaf=6, min_samples_split=6, n_estimators=30
# [CV 4/5; 12/15] END max_depth=25, max_features=5, min_samples_leaf=6, min_samples_split=6, n_estimators=30;, score=0.996 total time= 3.9min
# [CV 5/5; 12/15] START max_depth=25, max_features=5, min_samples_leaf=6, min_samples_split=6, n_estimators=30
# [CV 5/5; 12/15] END max_depth=25, max_features=5, min_samples_leaf=6, min_samples_split=6, n_estimators=30;, score=0.996 total time= 3.9min
# [CV 1/5; 13/15] START max_depth=None, max_features=9, min_samples_leaf=17, min_samples_split=20, n_estimators=30
# [CV 1/5; 13/15] END max_depth=None, max_features=9, min_samples_leaf=17, min_samples_split=20, n_estimators=30;, score=0.997 total time= 5.8min
# [CV 2/5; 13/15] START max_depth=None, max_features=9, min_samples_leaf=17, min_samples_split=20, n_estimators=30
# [CV 2/5; 13/15] END max_depth=None, max_features=9, min_samples_leaf=17, min_samples_split=20, n_estimators=30;, score=0.996 total time= 5.7min
# [CV 3/5; 13/15] START max_depth=None, max_features=9, min_samples_leaf=17, min_samples_split=20, n_estimators=30
# [CV 3/5; 13/15] END max_depth=None, max_features=9, min_samples_leaf=17, min_samples_split=20, n_estimators=30;, score=0.997 total time= 5.8min
# [CV 4/5; 13/15] START max_depth=None, max_features=9, min_samples_leaf=17, min_samples_split=20, n_estimators=30
# [CV 4/5; 13/15] END max_depth=None, max_features=9, min_samples_leaf=17, min_samples_split=20, n_estimators=30;, score=0.997 total time= 5.6min
# [CV 5/5; 13/15] START max_depth=None, max_features=9, min_samples_leaf=17, min_samples_split=20, n_estimators=30
# [CV 5/5; 13/15] END max_depth=None, max_features=9, min_samples_leaf=17, min_samples_split=20, n_estimators=30;, score=0.997 total time= 6.1min
# [CV 1/5; 14/15] START max_depth=35, max_features=18, min_samples_leaf=6, min_samples_split=13, n_estimators=30
# [CV 1/5; 14/15] END max_depth=35, max_features=18, min_samples_leaf=6, min_samples_split=13, n_estimators=30;, score=0.996 total time= 9.6min
# [CV 2/5; 14/15] START max_depth=35, max_features=18, min_samples_leaf=6, min_samples_split=13, n_estimators=30
# [CV 2/5; 14/15] END max_depth=35, max_features=18, min_samples_leaf=6, min_samples_split=13, n_estimators=30;, score=0.996 total time= 9.8min
# [CV 3/5; 14/15] START max_depth=35, max_features=18, min_samples_leaf=6, min_samples_split=13, n_estimators=30
# [CV 3/5; 14/15] END max_depth=35, max_features=18, min_samples_leaf=6, min_samples_split=13, n_estimators=30;, score=0.996 total time= 9.8min
# [CV 4/5; 14/15] START max_depth=35, max_features=18, min_samples_leaf=6, min_samples_split=13, n_estimators=30
# [CV 4/5; 14/15] END max_depth=35, max_features=18, min_samples_leaf=6, min_samples_split=13, n_estimators=30;, score=0.996 total time= 9.9min
# [CV 5/5; 14/15] START max_depth=35, max_features=18, min_samples_leaf=6, min_samples_split=13, n_estimators=30
# [CV 5/5; 14/15] END max_depth=35, max_features=18, min_samples_leaf=6, min_samples_split=13, n_estimators=30;, score=0.996 total time= 9.9min
# [CV 1/5; 15/15] START max_depth=30, max_features=15, min_samples_leaf=4, min_samples_split=17, n_estimators=30
# [CV 1/5; 15/15] END max_depth=30, max_features=15, min_samples_leaf=4, min_samples_split=17, n_estimators=30;, score=0.996 total time= 8.3min
# [CV 2/5; 15/15] START max_depth=30, max_features=15, min_samples_leaf=4, min_samples_split=17, n_estimators=30
# [CV 2/5; 15/15] END max_depth=30, max_features=15, min_samples_leaf=4, min_samples_split=17, n_estimators=30;, score=0.996 total time= 8.2min
# [CV 3/5; 15/15] START max_depth=30, max_features=15, min_samples_leaf=4, min_samples_split=17, n_estimators=30
# [CV 3/5; 15/15] END max_depth=30, max_features=15, min_samples_leaf=4, min_samples_split=17, n_estimators=30;, score=0.996 total time= 8.1min
# [CV 4/5; 15/15] START max_depth=30, max_features=15, min_samples_leaf=4, min_samples_split=17, n_estimators=30
# [CV 4/5; 15/15] END max_depth=30, max_features=15, min_samples_leaf=4, min_samples_split=17, n_estimators=30;, score=0.996 total time= 8.9min
# [CV 5/5; 15/15] START max_depth=30, max_features=15, min_samples_leaf=4, min_samples_split=17, n_estimators=30
# [CV 5/5; 15/15] END max_depth=30, max_features=15, min_samples_leaf=4, min_samples_split=17, n_estimators=30;, score=0.996 total time= 8.4min
# Lama waktu 'hyperparameter tuning' :  28581.503640413284

# %%
# Hasil tuning hyperparameter #
# =========================== #

# hasil
print ('F1 skor dan parameter terbaik')
print ('=============================')
print ('Nilai F1 skor terbaik : %s' % rf_random.best_score_)
print ('Parameter terbaik     : %s' % rf_random.best_params_)
print ('Estimator terbaik     : %s' % rf_random.best_estimator_)
test_50_rf_new_params_2 = pd.DataFrame(rf_random.cv_results_)

# simpan hasil hyperparameter random forest
test_50_rf_new_params_2.to_csv("G:\\Universitas Indonesia\\Rancangan Paper\\Dataset CSE-CIC-IDS2018-AWS\\CIC2018\\test_50_rf_new_params_2.txt", index=False)
# Out:
# F1 skor dan parameter terbaik
# =============================
# Nilai F1 skor terbaik : 0.996752509099984
# Parameter terbaik     : {'n_estimators': 30, 'min_samples_split': 6, 'min_samples_leaf': 3, 'max_features': 18, 'max_depth': 15}
# Estimator terbaik     : RandomForestClassifier(max_depth=15, max_features=18, min_samples_leaf=3,
#                        min_samples_split=6, n_estimators=30, n_jobs=-1,
#                        random_state=42)

# %% [markdown]
# ### 50.4. Hyperarameter terbaik

# %%
# 5 hyperparameter terbaik #
# ======================== #

# hyperparameter terbaik
hyperparam_rf = pd.read_csv("G:\\Universitas Indonesia\\Rancangan Paper\\Dataset CSE-CIC-IDS2018-AWS\\CIC2018\\test_50_rf_new_params_2.txt")

# mengurutkan hyperparameter terbaik berdasarkan f1
hyperparam_rf = hyperparam_rf.sort_values("rank_test_score")

# menampilkan 5 hyperparameter terbaik
print ('5 hyperparameter terbaik berdasarkan f1')
print ('=======================================')
param = hyperparam_rf[['rank_test_score','params','mean_fit_time','mean_test_score']].reset_index(drop=True)
#param = param[['params']]
param.head(5)
# Out:
# 5 hyperparameter terbaik berdasarkan f1
# =======================================
#    rank_test_score  \
# 0                1
# 1                2
# 2                3
# 3                4
# 4                5
#
#                                                                                                          params  \
# 0      {'n_estimators': 30, 'min_samples_split': 6, 'min_samples_leaf': 3, 'max_features': 18, 'max_depth': 15}
# 1   {'n_estimators': 30, 'min_samples_split': 20, 'min_samples_leaf': 17, 'max_features': 9, 'max_depth': None}
# 2     {'n_estimators': 30, 'min_samples_split': 6, 'min_samples_leaf': 17, 'max_features': 18, 'max_depth': 30}
# 3  {'n_estimators': 30, 'min_samples_split': 18, 'min_samples_leaf': 17, 'max_features': 18, 'max_depth': None}
# 4     {'n_estimators': 30, 'min_samples_split': 17, 'min_samples_leaf': 4, 'max_features': 15, 'max_depth': 30}
#
#    mean_fit_time  mean_test_score
# 0     500.072228         0.996753
# 1     326.666956         0.996540
# 2     540.904003         0.996405
# 3     546.033748         0.996251
# 4     484.382667         0.996032

# %% [markdown]
# #### 50.4.1. Latih hyperparameter terbaik berdasarkan f1

# %%
param_rf = param['params'][0]
param_terbaik = [eval(param_rf)]       

# jumlah estimator
for n in param_terbaik:
    jlh_estimator = [n['n_estimators']]

param_terbaik
# Out:
# [{'n_estimators': 30,
#   'min_samples_split': 6,
#   'min_samples_leaf': 3,
#   'max_features': 18,
#   'max_depth': 15}]

# %%
print ('|=======================================|')
print ("| Hyperparameter terbaik berdasarkan f1 |")
print ('|=======================================|')
print ('')
klf_f1, y_f1 = latih_eval_rf(param_terbaik, jlh_estimator, y_aktual_biner)
# Out:
# |=======================================|
# | Hyperparameter terbaik berdasarkan f1 |
# |=======================================|
#
# hyperparameter : {'n_estimators': 30, 'min_samples_split': 6, 'min_samples_leaf': 3, 'max_features': 18, 'max_depth': 15}
# Lama waktu latih    : 3424.9809622764587
# Lama waktu prediksi : 7.29485011100769
# hasil 'Accuracy'    : 0.9975304255939368
# hasil 'f1-score'    : 0.9966999632878646

# %% [markdown]
# #### 50.4.2. Metrik evaluasi

# %%
# metrik evaluasi lapisan 1 berdasarkan f1
metrik (None, 1, y_aktual_biner, y_f1)

# misklasifikasi lapisan 1
misklasifikasi(y_aktual_biner, y_f1)
# Out:
# Accuracy, Precision, Recall dan F1-score :
# ==========================================
# Accuracy  : 0.9975304255939368
# Precision : 0.997804617140507
# Recall    : 0.9956074187436235
# F1-score  : 0.9966999632878646
#
# metrik evaluasi :
# =================
#               precision    recall  f1-score   support
#
#       attack   0.998349  0.991761  0.995045    548880
#       benign   0.997260  0.999453  0.998355   1646640
#
#     accuracy                       0.997530   2195520
#    macro avg   0.997805  0.995607  0.996700   2195520
# weighted avg   0.997532  0.997530  0.997528   2195520
#
#
# matriks "confusion" :
# =====================
# misklasifikasi kelas target:
# ============================
#         misklasifikasi    total  persentase_misklasifikasi(%)
# attack            4522   548880                      0.823859
# benign             900  1646640                      0.054657
