# %% [markdown]
# ## Hyperparameter Tuning RF Test 53 & 54

# %% [markdown]
# ### Import library

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import time

### Pra proses
from sklearn.preprocessing import MinMaxScaler

### Near Miss under sampling
from imblearn.under_sampling import NearMiss 

### Bagi data
from sklearn.model_selection import train_test_split

### Seleksi fitur
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

### Random forest (RF)
from sklearn.ensemble import RandomForestClassifier

### metrik pengukuran
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_recall_fscore_support as score
from sklearn.metrics import make_scorer, f1_score

### Tuning Hyperparameter
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import RepeatedStratifiedKFold

### save model
import joblib

import warnings
warnings.filterwarnings('ignore')

# menampilkan lebih banyak kolom dan baris pada Dataset
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %%
# Tipe Dataset #
# ============ #

tipe_dataset = {'dst_port':'uint32','protocol':'uint8','timestamp':'uint64','flow_duration':'int64','tot_fwd_pkts':'uint32','tot_bwd_pkts':'uint32','totlen_fwd_pkts':'uint32','totlen_bwd_pkts':'uint32','fwd_pkt_len_max':'uint16','fwd_pkt_len_min':'uint16',
'fwd_pkt_len_mean':'float32','fwd_pkt_len_std':'float32','bwd_pkt_len_max':'uint16','bwd_pkt_len_min':'uint16','bwd_pkt_len_mean':'float32','bwd_pkt_len_std':'float32','flow_byts_s':'float64','flow_pkts_s':'float64','flow_iat_mean':'float32','flow_iat_std':'float32',
'flow_iat_max':'int64','flow_iat_min':'int64','fwd_iat_tot':'int64','fwd_iat_mean':'float32','fwd_iat_std':'float32','fwd_iat_max':'int64','fwd_iat_min':'int64','bwd_iat_tot':'uint32','bwd_iat_mean':'float32','bwd_iat_std':'float32',
'bwd_iat_max':'uint32','bwd_iat_min':'uint32','fwd_psh_flags':'uint8','bwd_psh_flags':'uint8','fwd_urg_flags':'uint8','bwd_urg_flags':'uint8','fwd_header_len':'uint32','bwd_header_len':'uint32','fwd_pkts_s':'float32','bwd_pkts_s':'float32',
'pkt_len_min':'uint16','pkt_len_max':'uint16','pkt_len_mean':'float32','pkt_len_std':'float32','pkt_len_var':'float32','fin_flag_cnt':'uint8','syn_flag_cnt':'uint8','rst_flag_cnt':'uint8','psh_flag_cnt':'uint8','ack_flag_cnt':'uint8',
'urg_flag_cnt':'uint8','cwe_flag_count':'uint8','ece_flag_cnt':'uint8','down_up_ratio':'uint16','pkt_size_avg':'float32','fwd_seg_size_avg':'float32','bwd_seg_size_avg':'float32','fwd_byts_b_avg':'uint8','fwd_pkts_b_avg':'uint8','fwd_blk_rate_avg':'uint8',
'bwd_byts_b_avg':'uint8','bwd_pkts_b_avg':'uint8','bwd_blk_rate_avg':'uint8','subflow_fwd_pkts':'uint32','subflow_fwd_byts':'uint32','subflow_bwd_pkts':'uint32','subflow_bwd_byts':'uint32','init_fwd_win_byts':'int32','init_bwd_win_byts':'int32','fwd_act_data_pkts':'uint32',
'fwd_seg_size_min':'uint8','active_mean':'float32','active_std':'float32','active_max':'uint32','active_min':'uint32','idle_mean':'float32','idle_std':'float32','idle_max':'uint64','idle_min':'uint64','label':'category',
'flow_id':'object','src_ip':'object','src_port':'float64','dst_ip':'object'}

# %%
# Fungsi #
# ====== #

# bagi dataset menjadi variabel input X dan variabel output y
def variabel_input_output(dataset, n, variabel_output):
    X = dataset.iloc[:,:-n]
    y = dataset[variabel_output]
    return X, y

# seleksi fitur metode Chi-squared
def seleksi_fitur(metode, X, y):
    chi2 = SelectKBest(score_func= metode , k=X.shape[1])
    fit = chi2.fit(X, y) 
    return fit

# pemilihan fitur terbaik       
def fitur_terbaik(klf, persentase_skor, X, tipe):    
    if tipe == 'rf' :
        importances = klf.feature_importances_
        sorted_indices = np.argsort(importances)[::-1]
        labels = X.columns
    
        # mengurutkan fitur berdasarkan skor tertinggi
        skor_fitur = zip(labels, importances)
        skor_fitur_diurutkan = sorted(skor_fitur, key = lambda x: x[1], reverse = True)
        skor_diurutkan = [skor[1] for skor in skor_fitur_diurutkan]
        fitur_diurutkan = [skor[0] for skor in skor_fitur_diurutkan]

        # Fitur dengan persentase skor 1% atau 5% dihapus
        # pilih fitur dengan persentase skor 95% atau 99%
        fitur_skor_rendah = []
        total_skor = 0 
        jumlah_persentase = []
        for skor in skor_fitur_diurutkan:
            total_skor = total_skor + skor[1]
            jumlah_persentase.append(total_skor)
            if total_skor >= sum(skor_diurutkan)*(persentase_skor/100):
                fitur_skor_rendah.append(skor[0])
                 
        # menampilkan fitur terpilih dengan persentase skor 95% atau 99%
        fitur_terpilih = pd.DataFrame({'Fitur':fitur_diurutkan, 
                                       'Persentase skor': skor_diurutkan/sum(importances)*100,
                                       'jumlah persentase': jumlah_persentase/sum(importances)*100})
        fitur_terpilih.index = np.arange(1,len(fitur_terpilih)+1)                       
        fitur_terpilih = fitur_terpilih[~fitur_terpilih['Fitur'].isin(fitur_skor_rendah)]
    
        # plot skor dengan setiap fitur
        plt.figure(figsize=(11, 5))
        plt.title('Bobot Fitur')
        plt.bar([i for i in range(len(importances))], importances)
        plt.xticks([i for i in range(len(importances))], X.columns)
        plt.xticks(rotation=80, fontsize=10)
        plt.tight_layout()
        #plt.savefig('features.png', dpi=300)
        
    else :
        # mengurutkan fitur berdasarkan bobot tertinggi
        skor_fitur = zip(X.columns, klf.scores_)
        skor_fitur_diurutkan = sorted(skor_fitur, key = lambda x: x[1], reverse = True)
        skor_diurutkan = [skor[1] for skor in skor_fitur_diurutkan]
        fitur_diurutkan = [skor[0] for skor in skor_fitur_diurutkan]
    
        # Fitur dengan persentase skor 1% atau 5% dihapus
        # pilih fitur dengan persentase skor 95% atau 99%
        fitur_skor_rendah = []
        total_skor = 0 
        jumlah_persentase = []
        for skor in skor_fitur_diurutkan:
            total_skor = total_skor + skor[1]
            jumlah_persentase.append(total_skor)
            if total_skor >= sum(skor_diurutkan)*(persentase_skor/100):
                fitur_skor_rendah.append(skor[0])
  
        # menampilkan fitur terpilih dengan persentase skor 95% atau 99%
        fitur_terpilih = pd.DataFrame({'Skor Chi-kuadrat':skor_diurutkan, 'Fitur':fitur_diurutkan, 
                                       'Persentase skor': skor_diurutkan/sum(klf.scores_)*100,
                                       'jumlah persentase': jumlah_persentase/sum(klf.scores_)*100})
        fitur_terpilih.index = np.arange(1,len(fitur_terpilih)+1)
        fitur_terpilih = fitur_terpilih[~fitur_terpilih['Fitur'].isin(fitur_skor_rendah)]
    
        # plot skor dengan setiap fitur
        plt.figure(figsize=(11, 5))
        plt.title('Bobot Fitur')
        plt.bar([i for i in range(len(klf.scores_))], klf.scores_)
        plt.xticks([i for i in range(len(klf.scores_))], X.columns)
        plt.xticks(rotation=80, fontsize=10)
        plt.tight_layout()
        #plt.savefig('features.png', dpi=300)
    
    # skor kumulatif
    skor_kumulatif = np.cumsum(skor_diurutkan)
    plt.figure(figsize=(13,5))
    x_values = range(len(skor_fitur_diurutkan))
    plt.plot(x_values, skor_kumulatif)

    # menampilkan garis batas persentase skor
    garis_batas = skor_kumulatif[-1]*(persentase_skor/100)
    plt.hlines(y = garis_batas, xmin=0, xmax=len(skor_diurutkan), color = 'r', linestyles = 'dashed')
    plt.xticks(x_values, fitur_diurutkan, rotation = 80, fontsize=10)
    plt.yticks([], [])
    plt.xlabel('Fitur', fontsize=12)
    plt.title('Skor Fitur', fontsize=12)
    plt.tight_layout()
    #plt.savefig('cum_features.png', dpi=300)
    print ("Fitur yang dihapus")
    print ('==================')
    print(fitur_skor_rendah)
    print ('\n')
    print ('Fitur dengan skor terbaik')
    print ('=========================')
    print (fitur_terpilih)
    
    return fitur_skor_rendah, fitur_terpilih

# misklasifikasi
def misklasifikasi(y_aktual, y_prediksi):
    print('misklasifikasi kelas target:')
    print('============================')
    
    misklasifikasi = y_aktual[y_aktual != y_prediksi]

    mk_df = pd.merge(pd.DataFrame({'misklasifikasi': misklasifikasi.value_counts()}),
                     pd.DataFrame({'total': y_aktual.value_counts()}),
                     how='left', left_index=True, right_index=True)
    mk_df['persentase_misklasifikasi(%)'] = mk_df.apply(lambda x: x[0] / x[1], axis=1)*100
    print (mk_df.sort_values('persentase_misklasifikasi(%)', ascending=False))

# metrik evaluasi
def metrik(clf, figsize, y_aktual, y_prediksi):
    print('')
    print('Accuracy, Precision, Recall dan F1-score :')
    print('==========================================')
    accuracy = accuracy_score(y_aktual, y_prediksi) 
    precision_rfc, recall_rfc, fscore_rfc, none = score(y_aktual, y_prediksi, average='macro')    
    print('Accuracy  : '+(str(accuracy)))
    print('Precision : '+(str(precision_rfc)))
    print('Recall    : '+(str(recall_rfc)))
    print('F1-score  : '+(str(fscore_rfc)))
        
    print('')
    print('metrik evaluasi :')
    print('=================')
    print(classification_report(y_aktual, y_prediksi, digits=6))
    
    print('')
    print('matriks "confusion" :')
    print('=====================')
    f,ax = plt.subplots(figsize=(7.5*figsize,5*figsize))
    cm = confusion_matrix(y_aktual, y_prediksi)
    if figsize == 1 :
        #if clf == None :
            #group_names = ['True Neg','False Pos','False Neg','True Pos']
        
        #else :
            #group_names = ['True','False','False ','True ']
            #group_names = ['True Pos','False Neg','False Pos','True Neg']
        
        group_counts = ['{0:0.0f}'.format(value) for value in cm.flatten()]
        group_percentages = ['{0:.2%}'.format(value) for value in (cm/np.sum(cm,axis=1)).flatten()]
        #labels = [f'{v1}\n{v2}\n{v3}' for v1, v2, v3 in zip(group_names,group_counts,group_percentages)]
        labels = [f'{v1}\n{v2}' for v1, v2 in zip(group_counts,group_percentages)]
        labels = np.asarray(labels).reshape(2,2)
        ax = sns.heatmap(cm, annot=labels, linewidth=3, linecolor="black", fmt='', cmap='Blues')
    
    else :
        ax = sns.heatmap(cm, annot=True, linewidth=3, linecolor="black", fmt=".0f", cmap='Greens')
        
    ax.set_xlabel('Label Prediksi', fontsize=12)
    ax.set_ylabel('Label Aktual', fontsize=12)
    ax.set_title('matriks "confusion"')

    if clf == None:
        Label = None
        plt.yticks(rotation=0, ha="right")
        plt.show() 
    else :
        Label = clf.classes_
        #if len(Label) < 15:
            #Label = Label
            #Label = np.append(['benign'],Label)
        #else :
            #Label = Label  
        ax.xaxis.set_ticklabels(Label)
        ax.yaxis.set_ticklabels(Label)
        plt.yticks(rotation=0, ha="right")
        plt.xticks(rotation=40, ha="right")
        plt.show() 
        
def param_terbaik_ke(param_ke):
    print ('Hyperparameter ke 1')
    print ('===================')
    return [param_rf[param_ke-1]]

def latih_eval_rf (params, jlh_est, y_aktual):
    global param_ke,hasil_akurasi,hasil_p_macro,hasil_p_weight,hasil_r_macro,hasil_r_weight,hasil_f1_macro,hasil_f1_weight,hasil_waktu_latih, hasil_waktu_pred,jumlah_estimator,hasil_y_pred
    hasil_akurasi=[]; hasil_p_macro=[]; hasil_p_weight=[]
    hasil_r_macro=[]; hasil_r_weight=[]; hasil_f1_macro=[]
    hasil_f1_weight=[]; hasil_waktu_latih=[]; hasil_waktu_pred=[];
    jumlah_estimator=[];hasil_y_pred=[]
      
    for m in jlh_est: 
        if len(jlh_est) > 1 : 
            print("jumlah 'trees' :",m)
            print('===================')
        param_ke = 0
        for n in params:
            # fit model dengan parameter jlh_estimator 
            param_ke += 1
            if len(params) > 1 :
                print('hyperparameter ke 1')
                print('===================')
            print('hyperparameter :',n)
            m_latih = time.time()
            if len(jlh_est) > 1 :
                klasifikasi = RandomForestClassifier(**n, n_estimators= m)
            else:
                klasifikasi = RandomForestClassifier(**n, random_state=42, n_jobs=-1)
            klasifikasi.fit(X_train_rf, y_train['label_binary'])
            s_latih = time.time()
            waktu_latih = s_latih-m_latih
            print ('Lama waktu latih    :', waktu_latih)
    
            # prediksi
            m_pred = time.time()
            y_pred = klasifikasi.predict(X_test_rf)
            s_pred = time.time()
            print ('Lama waktu prediksi :', s_pred-m_pred)
    
            # metrik evaluasi
            akurasi = accuracy_score(y_aktual, y_pred)
            p_macro,r_macro,f1_macro,n = score(y_aktual, y_pred, average='macro')
            p_weight,r_weight,f1_weight,n = score(y_aktual, y_pred, average='weighted')
    
            # tambahkan hasil
            hasil_akurasi.append(akurasi); hasil_p_macro.append(p_macro); hasil_p_weight.append(p_weight)
            hasil_r_macro.append(r_macro); hasil_r_weight.append(r_weight); hasil_f1_macro.append(f1_macro)
            hasil_f1_weight.append(f1_weight); hasil_waktu_latih.append(waktu_latih); hasil_waktu_pred.append(s_pred-m_pred)
            hasil_y_pred.append(y_pred); jumlah_estimator.append(m)
            print ("hasil 'Accuracy'    :", akurasi)
            print ("hasil 'f1-score'    :", f1_macro)
            print ('')
    param_ke=[i+1 for i in range(len(hasil_akurasi))]
    
    return klasifikasi, y_pred

def plot_eval(hasil_1, hasil_2, jlh_estimator, xlabel, ylabel1, ylabel2):
    print("") 
    pjg = len(ylabel1)+7
    print(' PLOT '+ylabel1.upper())
    print("".center(pjg, '='))    
    hasil_2 = np.around(np.array(hasil_2),8)
    
    if hasil_1 == None :
        fig,ax = plt.subplots(figsize=(15,7))
        ax.bar(jlh_estimator, hasil_2, width=2, label = ylabel1)
               #marker='o',linestyle='dashed', markersize=10, 
               #markerfacecolor = 'b', color='orange', label = ylabel1) 
                
        # batas tampilan sumbu y
        y1 = hasil_2
        y2 = (max(y1)-min(y1))
        ymax = max(y1)+(y2*10/100)
        ymin = min(y1)-(y2*10/100)
        ax.set_ylim([ymin,ymax])
        
        ax.set_xlabel(xlabel,fontsize=12)
        ax.set_ylabel(ylabel1, fontsize=12,)
        ax.tick_params(labelsize=12)
        ax.grid(linestyle = 'dashdot')
        
        for i,j in zip(jlh_estimator,hasil_2):
            ax.annotate(j,xy=(i,j),ha="right", va="bottom",fontsize=12)
        ax.legend(fontsize = 14,loc='center', bbox_to_anchor=(0.5,1.04))
        xy = pd.DataFrame({xlabel : jlh_estimator, ylabel1 : hasil_2})
        colors = [["orange", "mediumslateblue"]]*len(jlh_estimator)         
        ytabel = ax.table(cellText=xy.values, colLabels=xy.columns, loc=14,colLoc ='center',
                          cellLoc ='center',fontsize=12,visible=True,
                          colWidths =(0.15,0.15),cellColours=colors)
        ytabel.set_fontsize(12)
        ytabel.scale(0.8, 1.5)
        ytabel.set_zorder(100)

    else :
        plot=2
        n_plot = np.arange(plot)
        hasil_1 = np.around(np.array(hasil_1),8)
        fig,ax = plt.subplots(1,plot,figsize=(15,7))      
        colors = [["orange", "mediumslateblue"]]*len(jlh_estimator)
        
        ax[0].plot(jlh_estimator, hasil_1, marker='o',linestyle='dashed', markersize=10, 
                   markerfacecolor = 'mediumslateblue', color='orange', label = ylabel1)
        ax[1].plot(jlh_estimator, hasil_2,  marker='o',linestyle='dashed',markersize=10,
                    markerfacecolor = 'orange', color='mediumslateblue', label = ylabel2)       
   
        for i,j,k in zip(jlh_estimator,hasil_1,hasil_2):
            ax[0].annotate(j,xy=(i,j),ha="right", va="bottom",fontsize=12)
            ax[1].annotate(k,xy=(i,k),ha="left", va="bottom",fontsize=12)
        for n in n_plot:
            #xy = pd.DataFrame({xlabel : jlh_estimator, ylabel1 : locals()[f'hasil_{n+1}']})
            ax[n].set_xlabel(xlabel,fontsize=12)
            #ax[n].set_ylabel(ylabel1, fontsize=12)
            ax[0].set_ylabel(ylabel1, fontsize=12)
            ax[1].set_ylabel(ylabel2, fontsize=12)
            ax[n].grid(linestyle = 'dashdot')
            ax[n].tick_params(labelsize=12)
            #ytabel = ax[n].table(cellText=xy.values, colLabels=xy.columns, loc=6,
            #              colLoc ='center',cellLoc ='center',fontsize=20,visible=True,
            #              colWidths =(0.3,0.3),cellColours=colors)
            #ytabel.set_fontsize(20)
            #ytabel.scale(0.8, 1.5)
            #ytabel.set_zorder(100)
            ax[n].legend(fontsize = 14,loc='center',bbox_to_anchor=(0.5,1.04))
            
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Load dataset

# %%
# Load Dataset CIC-IDS2018 #
# ======================== #

m_load = time.time()
dataset_cic2018 = pd.read_csv("G:\\Universitas Indonesia\\Rancangan Paper\\Dataset CSE-CIC-IDS2018-AWS\\CIC2018\\CSE_CIC_IDS2018_Praproses.csv", dtype = tipe_dataset)
s_load = time.time()
print ('Lama waktu memuat dataset : ', s_load - m_load)
# Out:
# Lama waktu memuat dataset :  108.47132539749146

# %%
# Rasio kelas normal dan serangan sebelum 'under sampling' #
# ======================================================== #

jlh_target   = dataset_cic2018['label'].value_counts()
jlh_normal   = jlh_target[0]
jlh_serangan = sum(jlh_target[1:15])
print ("Rasio kelas normal dan serangan sebelum 'under sampling'")
print ('=======================================================')
print (f'jumlah sampel kelas normal dan serangan = {jlh_normal} : {jlh_serangan}' )
print (f'Rasio kelas normal dan serangan         = {round(jlh_normal/jlh_serangan,2)} : 1')
# Out:
# Rasio kelas normal dan serangan sebelum 'under sampling'
# =======================================================
# jumlah sampel kelas normal dan serangan = 13154471 : 2744400
# Rasio kelas normal dan serangan         = 4.79 : 1

# %% [markdown]
# ### Under sampling

# %%
# Near Miss undersampling #
# ======================= #

# bagi dataset CIC-IDS2018 menjadi X dan y
X_layer, y_layer = variabel_input_output(dataset_cic2018, 1, ['label'])

# rasio 3:1 kelas normal dan serangan
jlh_sampel = dataset_cic2018['label'].value_counts()
jlh_serangan = sum(jlh_sampel[1:15])
jlh_norm = jlh_serangan*3

# nearmiss under sampling rasio 3:1
m_under = time.time()
nm = NearMiss(version=2, n_jobs = -1, sampling_strategy={'benign' : jlh_norm})
X_layer, y_layer = nm.fit_resample(X_layer,y_layer)
s_under = time.time()
print ("Lama waktu 'under sampling' : ", s_under - m_under)

# %% [markdown]
# # =============================

# %%
# Load Dataset CIC-IDS2018 #
# ======================== #

m_load = time.time()
dataset_cic2018 = pd.read_csv("G:\\Universitas Indonesia\\Rancangan Paper\\Dataset CSE-CIC-IDS2018-AWS\\CIC2018\\CSE_CIC_IDS2018_Praproses_3_1.csv", dtype = tipe_dataset)
s_load = time.time()
print ('Lama waktu memuat dataset : ', s_load - m_load)
# Out:
# Lama waktu memuat dataset :  59.24549126625061

# %%
# bagi dataset CIC-IDS2018 menjadi X dan y
X_layer, y_layer = variabel_input_output(dataset_cic2018, 1, ['label'])

# %% [markdown]
# # =============================

# %%
# Rasio kelas normal dan serangan setelah 'under sampling' #
# ======================================================== #

jlh_sampel = y_layer.value_counts()
jlh_serangan = sum(jlh_sampel[1:15])
jlh_normal = jlh_sampel[0]
print ("Rasio kelas normal dan serangan setelah 'under sampling'")
print ('========================================================')
print (f'jumlah sampel kelas normal dan serangan = {jlh_normal} : {jlh_serangan}' )
print (f'Rasio kelas normal dan serangan         = {jlh_normal/jlh_serangan} : 1')
# Out:
# Rasio kelas normal dan serangan setelah 'under sampling'
# ========================================================
# jumlah sampel kelas normal dan serangan = 8233200 : 2744400
# Rasio kelas normal dan serangan         = 3.0 : 1

# %% [markdown]
# ### Bagi data

# %%
# Bagi data latih dan uji 80%:20% #
# =============================== #

m_bagi = time.time()
X_train, X_test, y_train, y_test = train_test_split(X_layer, y_layer, train_size = 0.8, test_size = 0.2, random_state = 42, stratify = y_layer)
s_bagi = time.time()
print ('Lama waktu bagi data : ', s_bagi - m_bagi)
# Out:
# Lama waktu bagi data :  60.65071129798889

# %% [markdown]
# ### Penambahan label

# %%
# Penambahan label #
# ================ #

# konversi tipe data label menjadi 'category'
y_train = y_train.astype('category')
y_test = y_test.astype('category')

# penambahan label pada data latih
y_train = pd.DataFrame(y_train)
y_train['label_binary'] = np.where(y_train['label'] == 'benign', 'benign', 'attack')
y_train['label_binary_code'] = np.where(y_train['label'] == 'benign', 0, 1)

# penambahan label pada data uji
y_test = pd.DataFrame(y_test)
y_test['label_binary'] = np.where(y_test['label'] == 'benign', 'benign', 'attack')
y_test['label_binary_code'] = np.where(y_test['label'] == 'benign', 0, 1)

# %% [markdown]
# ### Normalisasi

# %%
# Normalisasi data #
# ================ #

m_norm = time.time()

# menskalakan nilai setiap fitur ke rentang 0 sampai 1 dengan 'MinMaxscaler'.
scaler = MinMaxScaler().fit(X_train)

# terapkan normalisasi
X_train_norm = scaler.transform(X_train)
X_test_norm = scaler.transform(X_test)

X_train_norm = pd.DataFrame(X_train_norm)
X_train_norm.columns = X_train.columns
X_test_norm = pd.DataFrame(X_test_norm)
X_test_norm.columns = X_train.columns

s_norm = time.time()
print ('Lama waktu min-max normalisasi : ', s_norm - m_norm)
# Out:
# Lama waktu min-max normalisasi :  7.847076654434204

# %% [markdown]
# # Test 53

# %% [markdown]
# ### 53.1. Seleksi fitur dengan random forest - 95%

# %%
# Seleksi fitur dengan 'random forest' #
# ==================================== #

m_sf = time.time()

# ambang batas persentase skor
persentase_skor = 95

# vektor target
vektor_target = y_train['label']

# jumlah 'trees'
jumlah_trees = 100

# fitur terpilih dan fitur dihapus
klf = RandomForestClassifier(n_estimators=jumlah_trees, random_state=42, n_jobs=-1)
fit = klf.fit(X_train_norm, vektor_target)
fitur_dihapus_rf,fitur_terpilih_rf = fitur_terbaik (fit, persentase_skor, X_train_norm, 'rf')

# hapus fitur dengan skor terendah
X_train_rf = X_train_norm.drop(fitur_dihapus_rf, axis=1)
X_test_rf = X_test_norm.drop(fitur_dihapus_rf, axis=1)

s_sf = time.time()
print ('')
print ("Lama waktu seleksi fitur 'random forest' : ", s_sf - m_sf)
# Out:
# Fitur yang dihapus
# ==================
# ['flow_iat_std', 'down_up_ratio', 'fwd_iat_std', 'idle_max', 'ece_flag_cnt', 'urg_flag_cnt', 'rst_flag_cnt', 'flow_byts_s', 'bwd_iat_tot', 'bwd_iat_std', 'bwd_iat_mean', 'bwd_iat_max', 'bwd_iat_min', 'active_mean', 'active_min', 'active_max', 'protocol', 'fin_flag_cnt', 'fwd_pkt_len_min', 'bwd_pkt_len_min', 'fwd_psh_flags', 'active_std', 'pkt_len_min', 'idle_std', 'fwd_urg_flags']
#
#
# Fitur dengan skor terbaik
# =========================
#                 Fitur  Persentase skor  jumlah persentase
# 1           timestamp        13.203745          13.203745
# 2   init_fwd_win_byts        11.820155          25.023900
# 3            dst_port         6.175546          31.199446
# 4    fwd_seg_size_min         5.007278          36.206724
# 5          fwd_pkts_s         3.588357          39.795081
# 6     totlen_fwd_pkts         3.583811          43.378891
# 7     fwd_pkt_len_max         3.499403          46.878294
# 8    fwd_pkt_len_mean         3.479688          50.357982
# 9         flow_pkts_s         3.396002          53.753984
# 10     fwd_header_len         3.118528          56.872513
# 11      flow_duration         2.047449          58.919962
# 12       pkt_size_avg         2.042128          60.962090
# 13       tot_bwd_pkts         2.012136          62.974226
# 14     bwd_header_len         1.998965          64.973191
# 15      flow_iat_mean         1.907097          66.880288
# 16       pkt_len_mean         1.688748          68.569037
# 17       flow_iat_max         1.676447          70.245484
# 18   bwd_pkt_len_mean         1.659495          71.904979
# 19        pkt_len_std         1.561449          73.466428
# 20       flow_iat_min         1.529020          74.995449
# 21        pkt_len_max         1.515209          76.510658
# 22  init_bwd_win_byts         1.502816          78.013474
# 23       fwd_iat_mean         1.478805          79.492279
# 24       tot_fwd_pkts         1.428082          80.920361
# 25        fwd_iat_max         1.236525          82.156886
# 26    bwd_pkt_len_std         1.139477          83.296363
# 27    fwd_pkt_len_std         1.126184          84.422548
# 28         bwd_pkts_s         1.103041          85.525589
# 29        pkt_len_var         1.043581          86.569170
# 30        fwd_iat_tot         1.035958          87.605128
# 31    totlen_bwd_pkts         1.033024          88.638152
# 32       psh_flag_cnt         1.021122          89.659274
# 33        fwd_iat_min         0.924765          90.584039
# 34    bwd_pkt_len_max         0.918601          91.502639
# 35          idle_mean         0.898417          92.401056
# 36       ack_flag_cnt         0.877906          93.278963
# 37           idle_min         0.845042          94.124005
# 38  fwd_act_data_pkts         0.696160          94.820165
#
# Lama waktu seleksi fitur 'random forest' :  1199.8489201068878

# %%
# label aktual dan jumlah fitur #
# ============================= #

# label aktual biner kelas
y_aktual_biner = y_test['label_binary'].reset_index(drop=True)

# fitur dan jumlah fitur yang digunakan
print ('Fitur yang digunakan')
print ('====================')
print (list(X_train_rf.columns))
print ('')
print ('Jumlah fitur')
print ('============')
print (len(X_train_rf.columns),'fitur')
# Out:
# Fitur yang digunakan
# ====================
# ['dst_port', 'timestamp', 'flow_duration', 'tot_fwd_pkts', 'tot_bwd_pkts', 'totlen_fwd_pkts', 'totlen_bwd_pkts', 'fwd_pkt_len_max', 'fwd_pkt_len_mean', 'fwd_pkt_len_std', 'bwd_pkt_len_max', 'bwd_pkt_len_mean', 'bwd_pkt_len_std', 'flow_pkts_s', 'flow_iat_mean', 'flow_iat_max', 'flow_iat_min', 'fwd_iat_tot', 'fwd_iat_mean', 'fwd_iat_max', 'fwd_iat_min', 'fwd_header_len', 'bwd_header_len', 'fwd_pkts_s', 'bwd_pkts_s', 'pkt_len_max', 'pkt_len_mean', 'pkt_len_std', 'pkt_len_var', 'psh_flag_cnt', 'ack_flag_cnt', 'pkt_size_avg', 'init_fwd_win_byts', 'init_bwd_win_byts', 'fwd_act_data_pkts', 'fwd_seg_size_min', 'idle_mean', 'idle_min']
#
# Jumlah fitur
# ============
# 38 fitur

# %% [markdown]
# ### 53.2. Pemilihan jumlah 'tree'

# %%
# Pemilihan jumlah 'trees' #
# ======================== #

m_jlh = time.time()

# parameter yang digunakan
param_klf = [{'random_state':42, 'n_jobs':-1}]                
jlh_estimator = [10,15,20,25,30,35,40,45,50]

# hasil pelatihan
latih_eval_rf(param_klf, jlh_estimator, y_aktual_biner)

s_jlh = time.time()
print ("Lama waktu pencarian jumlah 'tree' : ", s_jlh - m_jlh)
# Out:
# jumlah 'trees' : 10
# ===================
# hyperparameter : {'random_state': 42, 'n_jobs': -1}
# Lama waktu latih    : 186.87687182426453
# Lama waktu prediksi : 1.4651107788085938
# hasil 'Accuracy'    : 0.9959326264392946
# hasil 'f1-score'    : 0.9945747062071799
#
# jumlah 'trees' : 15
# ===================
# hyperparameter : {'random_state': 42, 'n_jobs': -1}
# Lama waktu latih    : 254.99762845039368
# Lama waktu prediksi : 1.987398386001587
# hasil 'Accuracy'    : 0.9959576774522665
# hasil 'f1-score'    : 0.9946073502217447
#
# jumlah 'trees' : 20
# ===================
# hyperparameter : {'random_state': 42, 'n_jobs': -1}
# Lama waktu latih    : 322.2316827774048
# Lama waktu prediksi : 2.2386770248413086
# hasil 'Accuracy'    : 0.9959626876548608
# hasil 'f1-score'    : 0.9946143582860265
#
# jumlah 'trees' : 25
# ===================
# hyperparameter : {'random_state': 42, 'n_jobs': -1}
# Lama waktu latih    : 348.76978969573975
# Lama waktu prediksi : 3.183354139328003
# hasil 'Accuracy'    : 0.9959626876548608
# hasil 'f1-score'    : 0.9946144041293403
#
# jumlah 'trees' : 30
# ===================
# hyperparameter : {'random_state': 42, 'n_jobs': -1}
# Lama waktu latih    : 442.2279632091522
# Lama waktu prediksi : 3.2112433910369873
# hasil 'Accuracy'    : 0.9959567665063401
# hasil 'f1-score'    : 0.994606633465903
#
# jumlah 'trees' : 35
# ===================
# hyperparameter : {'random_state': 42, 'n_jobs': -1}
# Lama waktu latih    : 519.2943415641785
# Lama waktu prediksi : 3.6162753105163574
# hasil 'Accuracy'    : 0.9959499344118933
# hasil 'f1-score'    : 0.994597391868016
#
# jumlah 'trees' : 40
# ===================
# hyperparameter : {'random_state': 42, 'n_jobs': -1}
# Lama waktu latih    : 549.947319984436
# Lama waktu prediksi : 4.032959222793579
# hasil 'Accuracy'    : 0.995963143127824
# hasil 'f1-score'    : 0.9946149364038623
#
# jumlah 'trees' : 45
# ===================
# hyperparameter : {'random_state': 42, 'n_jobs': -1}
# Lama waktu latih    : 580.2479104995728
# Lama waktu prediksi : 3.9753024578094482
# hasil 'Accuracy'    : 0.9959672423844921
# hasil 'f1-score'    : 0.9946204079781229
#
# jumlah 'trees' : 50
# ===================
# hyperparameter : {'random_state': 42, 'n_jobs': -1}
# Lama waktu latih    : 711.3580164909363
# Lama waktu prediksi : 4.490444660186768
# hasil 'Accuracy'    : 0.9959722525870864
# hasil 'f1-score'    : 0.9946271861921754
#
# Lama waktu pencarian jumlah 'tree' :  4423.970171928406

# %%
# list hasil pelatihan
print ('List hasil pelatihan')
print ('====================')
print ('hasil_waktu_latih    =', hasil_waktu_latih)
print ('hasil_waktu_prediksi =', hasil_waktu_pred)
print ('hasil_f1_macro       =', hasil_f1_macro)
print ('hasil_akurasi        =', hasil_akurasi)
print ('jumlah_estimator     =', jlh_estimator)
# Out:
# List hasil pelatihan
# ====================
# hasil_waktu_latih    = [186.87687182426453, 254.99762845039368, 322.2316827774048, 348.76978969573975, 442.2279632091522, 519.2943415641785, 549.947319984436, 580.2479104995728, 711.3580164909363]
# hasil_waktu_prediksi = [1.4651107788085938, 1.987398386001587, 2.2386770248413086, 3.183354139328003, 3.2112433910369873, 3.6162753105163574, 4.032959222793579, 3.9753024578094482, 4.490444660186768]
# hasil_f1_macro       = [0.9945747062071799, 0.9946073502217447, 0.9946143582860265, 0.9946144041293403, 0.994606633465903, 0.994597391868016, 0.9946149364038623, 0.9946204079781229, 0.9946271861921754]
# hasil_akurasi        = [0.9959326264392946, 0.9959576774522665, 0.9959626876548608, 0.9959626876548608, 0.9959567665063401, 0.9959499344118933, 0.995963143127824, 0.9959672423844921, 0.9959722525870864]
# jumlah_estimator     = [10, 15, 20, 25, 30, 35, 40, 45, 50]

# %% [markdown]
# #### 53.2.1. Plot hasil pengukuran

# %%
# Plot hasil pengukuran #
# ===================== #

# Plot waktu latih dan akurasi
plot_eval(hasil_waktu_latih,hasil_akurasi,jumlah_estimator,'Jumlah "trees"','Waktu latih','Accuracy')

# Plot waktu prediksi dan akurasi
plot_eval(hasil_waktu_pred,hasil_f1_macro,jumlah_estimator,'Jumlah "trees"','Waktu prediksi','F1-score')

# Plot waktu pelatihan
plot_eval(None,hasil_waktu_latih,jumlah_estimator,'Jumlah trees','Waktu latih',None)

# Plot waktu prediksi
plot_eval(None,hasil_waktu_pred,jumlah_estimator,'Jumlah trees','Waktu prediksi',None)

# Plot Akurasi
plot_eval(None,hasil_akurasi,jumlah_estimator,'Jumlah trees','Accuracy',None)

# plot F1
plot_eval(None,hasil_f1_macro,jumlah_estimator,'Jumlah trees','F1-score',None)
# Out:
#  PLOT WAKTU LATIH
# ==================
#  PLOT WAKTU PREDIKSI
# =====================
#  PLOT WAKTU LATIH
# ==================
#  PLOT WAKTU PREDIKSI
# =====================
#  PLOT ACCURACY
# ===============
#  PLOT F1-SCORE
# ===============

# %% [markdown]
# ### 53.2. Hyperparameter tuning random forest

# %%
# Hyperparameter tuning random forest #
# =================================== #

m_hyper = time.time()

# hyperparameter yang digunakan untuk tuning
jlh_estimator     = [50]
max_features      = [5, 9, 12, 15, 18]
max_depth         = [None,5,10,15,20,25,30,35]
min_samples_split = [2,3,4,5,6,7,9,10,11,12,13,14,15,16,17,17,18,19,20]
min_samples_leaf  = [2,3,4,5,6,7,9,10,11,12,13,14,15,16,17,17,18,19,20]

# pembangunan model
rf = RandomForestClassifier(random_state=42, n_jobs=-1)

# jumlah acak kombinasi nilai hyperparameter
n_iter = 15

# validasi silang 5 lipatan
cv = 5

# tentukan f1 macro
f1_macro_scorer = make_scorer(f1_score, greater_is_better=True, average='macro')

# random grid search
random_grid = {'n_estimators': jlh_estimator,'max_depth': max_depth,'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,'max_features': max_features}

rf_random = RandomizedSearchCV(estimator=rf, param_distributions=random_grid, 
                               n_iter=n_iter, cv=cv, verbose=10, random_state=22, n_jobs=None, scoring=f1_macro_scorer)

# terapkan random grid pada data latih
rf_random.fit(X_train_rf, y_train['label_binary'])

s_hyper = time.time()
print ("Lama waktu 'hyperparameter tuning' : ", s_hyper - m_hyper)
# Out:
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
# [CV 1/5; 1/15] START max_depth=30, max_features=5, min_samples_leaf=17, min_samples_split=13, n_estimators=50
# [CV 1/5; 1/15] END max_depth=30, max_features=5, min_samples_leaf=17, min_samples_split=13, n_estimators=50;, score=0.996 total time= 7.5min
# [CV 2/5; 1/15] START max_depth=30, max_features=5, min_samples_leaf=17, min_samples_split=13, n_estimators=50
# [CV 2/5; 1/15] END max_depth=30, max_features=5, min_samples_leaf=17, min_samples_split=13, n_estimators=50;, score=0.996 total time= 7.0min
# [CV 3/5; 1/15] START max_depth=30, max_features=5, min_samples_leaf=17, min_samples_split=13, n_estimators=50
# [CV 3/5; 1/15] END max_depth=30, max_features=5, min_samples_leaf=17, min_samples_split=13, n_estimators=50;, score=0.996 total time= 6.8min
# [CV 4/5; 1/15] START max_depth=30, max_features=5, min_samples_leaf=17, min_samples_split=13, n_estimators=50
# [CV 4/5; 1/15] END max_depth=30, max_features=5, min_samples_leaf=17, min_samples_split=13, n_estimators=50;, score=0.996 total time= 6.9min
# [CV 5/5; 1/15] START max_depth=30, max_features=5, min_samples_leaf=17, min_samples_split=13, n_estimators=50
# [CV 5/5; 1/15] END max_depth=30, max_features=5, min_samples_leaf=17, min_samples_split=13, n_estimators=50;, score=0.996 total time= 7.0min
# [CV 1/5; 2/15] START max_depth=15, max_features=12, min_samples_leaf=10, min_samples_split=9, n_estimators=50
# [CV 1/5; 2/15] END max_depth=15, max_features=12, min_samples_leaf=10, min_samples_split=9, n_estimators=50;, score=0.997 total time=11.5min
# [CV 2/5; 2/15] START max_depth=15, max_features=12, min_samples_leaf=10, min_samples_split=9, n_estimators=50
# [CV 2/5; 2/15] END max_depth=15, max_features=12, min_samples_leaf=10, min_samples_split=9, n_estimators=50;, score=0.997 total time=11.7min
# [CV 3/5; 2/15] START max_depth=15, max_features=12, min_samples_leaf=10, min_samples_split=9, n_estimators=50
# [CV 3/5; 2/15] END max_depth=15, max_features=12, min_samples_leaf=10, min_samples_split=9, n_estimators=50;, score=0.997 total time=11.6min
# [CV 4/5; 2/15] START max_depth=15, max_features=12, min_samples_leaf=10, min_samples_split=9, n_estimators=50
# [CV 4/5; 2/15] END max_depth=15, max_features=12, min_samples_leaf=10, min_samples_split=9, n_estimators=50;, score=0.997 total time=11.4min
# [CV 5/5; 2/15] START max_depth=15, max_features=12, min_samples_leaf=10, min_samples_split=9, n_estimators=50
# [CV 5/5; 2/15] END max_depth=15, max_features=12, min_samples_leaf=10, min_samples_split=9, n_estimators=50;, score=0.997 total time=11.5min
# [CV 1/5; 3/15] START max_depth=35, max_features=9, min_samples_leaf=7, min_samples_split=12, n_estimators=50
# [CV 1/5; 3/15] END max_depth=35, max_features=9, min_samples_leaf=7, min_samples_split=12, n_estimators=50;, score=0.996 total time=10.3min
# [CV 2/5; 3/15] START max_depth=35, max_features=9, min_samples_leaf=7, min_samples_split=12, n_estimators=50
# [CV 2/5; 3/15] END max_depth=35, max_features=9, min_samples_leaf=7, min_samples_split=12, n_estimators=50;, score=0.996 total time=10.5min
# [CV 3/5; 3/15] START max_depth=35, max_features=9, min_samples_leaf=7, min_samples_split=12, n_estimators=50
# [CV 3/5; 3/15] END max_depth=35, max_features=9, min_samples_leaf=7, min_samples_split=12, n_estimators=50;, score=0.996 total time=10.6min
# [CV 4/5; 3/15] START max_depth=35, max_features=9, min_samples_leaf=7, min_samples_split=12, n_estimators=50
# [CV 4/5; 3/15] END max_depth=35, max_features=9, min_samples_leaf=7, min_samples_split=12, n_estimators=50;, score=0.996 total time=10.5min
# [CV 5/5; 3/15] START max_depth=35, max_features=9, min_samples_leaf=7, min_samples_split=12, n_estimators=50
# [CV 5/5; 3/15] END max_depth=35, max_features=9, min_samples_leaf=7, min_samples_split=12, n_estimators=50;, score=0.996 total time=10.2min
# [CV 1/5; 4/15] START max_depth=20, max_features=15, min_samples_leaf=15, min_samples_split=19, n_estimators=50
# [CV 1/5; 4/15] END max_depth=20, max_features=15, min_samples_leaf=15, min_samples_split=19, n_estimators=50;, score=0.997 total time=15.4min
# [CV 2/5; 4/15] START max_depth=20, max_features=15, min_samples_leaf=15, min_samples_split=19, n_estimators=50
# [CV 2/5; 4/15] END max_depth=20, max_features=15, min_samples_leaf=15, min_samples_split=19, n_estimators=50;, score=0.997 total time=15.5min
# [CV 3/5; 4/15] START max_depth=20, max_features=15, min_samples_leaf=15, min_samples_split=19, n_estimators=50
# [CV 3/5; 4/15] END max_depth=20, max_features=15, min_samples_leaf=15, min_samples_split=19, n_estimators=50;, score=0.997 total time=15.3min
# [CV 4/5; 4/15] START max_depth=20, max_features=15, min_samples_leaf=15, min_samples_split=19, n_estimators=50
# [CV 4/5; 4/15] END max_depth=20, max_features=15, min_samples_leaf=15, min_samples_split=19, n_estimators=50;, score=0.997 total time=15.7min
# [CV 5/5; 4/15] START max_depth=20, max_features=15, min_samples_leaf=15, min_samples_split=19, n_estimators=50
# [CV 5/5; 4/15] END max_depth=20, max_features=15, min_samples_leaf=15, min_samples_split=19, n_estimators=50;, score=0.997 total time=15.0min
# [CV 1/5; 5/15] START max_depth=15, max_features=5, min_samples_leaf=5, min_samples_split=9, n_estimators=50
# [CV 1/5; 5/15] END max_depth=15, max_features=5, min_samples_leaf=5, min_samples_split=9, n_estimators=50;, score=0.994 total time= 5.8min
# [CV 2/5; 5/15] START max_depth=15, max_features=5, min_samples_leaf=5, min_samples_split=9, n_estimators=50
# [CV 2/5; 5/15] END max_depth=15, max_features=5, min_samples_leaf=5, min_samples_split=9, n_estimators=50;, score=0.994 total time= 5.7min
# [CV 3/5; 5/15] START max_depth=15, max_features=5, min_samples_leaf=5, min_samples_split=9, n_estimators=50
# [CV 3/5; 5/15] END max_depth=15, max_features=5, min_samples_leaf=5, min_samples_split=9, n_estimators=50;, score=0.994 total time= 5.7min
# [CV 4/5; 5/15] START max_depth=15, max_features=5, min_samples_leaf=5, min_samples_split=9, n_estimators=50
# [CV 4/5; 5/15] END max_depth=15, max_features=5, min_samples_leaf=5, min_samples_split=9, n_estimators=50;, score=0.994 total time= 5.6min
# [CV 5/5; 5/15] START max_depth=15, max_features=5, min_samples_leaf=5, min_samples_split=9, n_estimators=50
# [CV 5/5; 5/15] END max_depth=15, max_features=5, min_samples_leaf=5, min_samples_split=9, n_estimators=50;, score=0.994 total time= 5.6min
# [CV 1/5; 6/15] START max_depth=15, max_features=15, min_samples_leaf=10, min_samples_split=17, n_estimators=50
# [CV 1/5; 6/15] END max_depth=15, max_features=15, min_samples_leaf=10, min_samples_split=17, n_estimators=50;, score=0.997 total time=14.2min
# [CV 2/5; 6/15] START max_depth=15, max_features=15, min_samples_leaf=10, min_samples_split=17, n_estimators=50
# [CV 2/5; 6/15] END max_depth=15, max_features=15, min_samples_leaf=10, min_samples_split=17, n_estimators=50;, score=0.997 total time=13.9min
# [CV 3/5; 6/15] START max_depth=15, max_features=15, min_samples_leaf=10, min_samples_split=17, n_estimators=50
# [CV 3/5; 6/15] END max_depth=15, max_features=15, min_samples_leaf=10, min_samples_split=17, n_estimators=50;, score=0.997 total time=13.9min
# [CV 4/5; 6/15] START max_depth=15, max_features=15, min_samples_leaf=10, min_samples_split=17, n_estimators=50
# [CV 4/5; 6/15] END max_depth=15, max_features=15, min_samples_leaf=10, min_samples_split=17, n_estimators=50;, score=0.997 total time=13.5min
# [CV 5/5; 6/15] START max_depth=15, max_features=15, min_samples_leaf=10, min_samples_split=17, n_estimators=50
# [CV 5/5; 6/15] END max_depth=15, max_features=15, min_samples_leaf=10, min_samples_split=17, n_estimators=50;, score=0.997 total time=14.0min
# [CV 1/5; 7/15] START max_depth=10, max_features=12, min_samples_leaf=16, min_samples_split=11, n_estimators=50
# [CV 1/5; 7/15] END max_depth=10, max_features=12, min_samples_leaf=16, min_samples_split=11, n_estimators=50;, score=0.994 total time= 9.0min
# [CV 2/5; 7/15] START max_depth=10, max_features=12, min_samples_leaf=16, min_samples_split=11, n_estimators=50
# [CV 2/5; 7/15] END max_depth=10, max_features=12, min_samples_leaf=16, min_samples_split=11, n_estimators=50;, score=0.994 total time= 8.9min
# [CV 3/5; 7/15] START max_depth=10, max_features=12, min_samples_leaf=16, min_samples_split=11, n_estimators=50
# [CV 3/5; 7/15] END max_depth=10, max_features=12, min_samples_leaf=16, min_samples_split=11, n_estimators=50;, score=0.994 total time= 8.9min
# [CV 4/5; 7/15] START max_depth=10, max_features=12, min_samples_leaf=16, min_samples_split=11, n_estimators=50
# [CV 4/5; 7/15] END max_depth=10, max_features=12, min_samples_leaf=16, min_samples_split=11, n_estimators=50;, score=0.994 total time= 9.0min
# [CV 5/5; 7/15] START max_depth=10, max_features=12, min_samples_leaf=16, min_samples_split=11, n_estimators=50
# [CV 5/5; 7/15] END max_depth=10, max_features=12, min_samples_leaf=16, min_samples_split=11, n_estimators=50;, score=0.994 total time= 9.0min
# [CV 1/5; 8/15] START max_depth=30, max_features=5, min_samples_leaf=18, min_samples_split=13, n_estimators=50
# [CV 1/5; 8/15] END max_depth=30, max_features=5, min_samples_leaf=18, min_samples_split=13, n_estimators=50;, score=0.996 total time= 6.8min
# [CV 2/5; 8/15] START max_depth=30, max_features=5, min_samples_leaf=18, min_samples_split=13, n_estimators=50
# [CV 2/5; 8/15] END max_depth=30, max_features=5, min_samples_leaf=18, min_samples_split=13, n_estimators=50;, score=0.996 total time= 6.7min
# [CV 3/5; 8/15] START max_depth=30, max_features=5, min_samples_leaf=18, min_samples_split=13, n_estimators=50
# [CV 3/5; 8/15] END max_depth=30, max_features=5, min_samples_leaf=18, min_samples_split=13, n_estimators=50;, score=0.996 total time= 6.8min
# [CV 4/5; 8/15] START max_depth=30, max_features=5, min_samples_leaf=18, min_samples_split=13, n_estimators=50
# [CV 4/5; 8/15] END max_depth=30, max_features=5, min_samples_leaf=18, min_samples_split=13, n_estimators=50;, score=0.996 total time= 6.9min
# [CV 5/5; 8/15] START max_depth=30, max_features=5, min_samples_leaf=18, min_samples_split=13, n_estimators=50
# [CV 5/5; 8/15] END max_depth=30, max_features=5, min_samples_leaf=18, min_samples_split=13, n_estimators=50;, score=0.996 total time= 6.7min
# [CV 1/5; 9/15] START max_depth=5, max_features=12, min_samples_leaf=2, min_samples_split=2, n_estimators=50
# [CV 1/5; 9/15] END max_depth=5, max_features=12, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=0.984 total time= 5.2min
# [CV 2/5; 9/15] START max_depth=5, max_features=12, min_samples_leaf=2, min_samples_split=2, n_estimators=50
# [CV 2/5; 9/15] END max_depth=5, max_features=12, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=0.983 total time= 5.2min
# [CV 3/5; 9/15] START max_depth=5, max_features=12, min_samples_leaf=2, min_samples_split=2, n_estimators=50
# [CV 3/5; 9/15] END max_depth=5, max_features=12, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=0.984 total time= 5.2min
# [CV 4/5; 9/15] START max_depth=5, max_features=12, min_samples_leaf=2, min_samples_split=2, n_estimators=50
# [CV 4/5; 9/15] END max_depth=5, max_features=12, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=0.983 total time= 5.2min
# [CV 5/5; 9/15] START max_depth=5, max_features=12, min_samples_leaf=2, min_samples_split=2, n_estimators=50
# [CV 5/5; 9/15] END max_depth=5, max_features=12, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=0.984 total time= 5.1min
# [CV 1/5; 10/15] START max_depth=25, max_features=5, min_samples_leaf=11, min_samples_split=6, n_estimators=50
# [CV 1/5; 10/15] END max_depth=25, max_features=5, min_samples_leaf=11, min_samples_split=6, n_estimators=50;, score=0.996 total time= 6.7min
# [CV 2/5; 10/15] START max_depth=25, max_features=5, min_samples_leaf=11, min_samples_split=6, n_estimators=50
# [CV 2/5; 10/15] END max_depth=25, max_features=5, min_samples_leaf=11, min_samples_split=6, n_estimators=50;, score=0.996 total time= 6.7min
# [CV 3/5; 10/15] START max_depth=25, max_features=5, min_samples_leaf=11, min_samples_split=6, n_estimators=50
# [CV 3/5; 10/15] END max_depth=25, max_features=5, min_samples_leaf=11, min_samples_split=6, n_estimators=50;, score=0.996 total time= 6.7min
# [CV 4/5; 10/15] START max_depth=25, max_features=5, min_samples_leaf=11, min_samples_split=6, n_estimators=50
# [CV 4/5; 10/15] END max_depth=25, max_features=5, min_samples_leaf=11, min_samples_split=6, n_estimators=50;, score=0.996 total time= 6.6min
# [CV 5/5; 10/15] START max_depth=25, max_features=5, min_samples_leaf=11, min_samples_split=6, n_estimators=50
# [CV 5/5; 10/15] END max_depth=25, max_features=5, min_samples_leaf=11, min_samples_split=6, n_estimators=50;, score=0.996 total time= 6.6min
# [CV 1/5; 11/15] START max_depth=35, max_features=15, min_samples_leaf=16, min_samples_split=7, n_estimators=50
# [CV 1/5; 11/15] END max_depth=35, max_features=15, min_samples_leaf=16, min_samples_split=7, n_estimators=50;, score=0.996 total time=16.2min
# [CV 2/5; 11/15] START max_depth=35, max_features=15, min_samples_leaf=16, min_samples_split=7, n_estimators=50
# [CV 2/5; 11/15] END max_depth=35, max_features=15, min_samples_leaf=16, min_samples_split=7, n_estimators=50;, score=0.996 total time=15.7min
# [CV 3/5; 11/15] START max_depth=35, max_features=15, min_samples_leaf=16, min_samples_split=7, n_estimators=50
# [CV 3/5; 11/15] END max_depth=35, max_features=15, min_samples_leaf=16, min_samples_split=7, n_estimators=50;, score=0.996 total time=16.1min
# [CV 4/5; 11/15] START max_depth=35, max_features=15, min_samples_leaf=16, min_samples_split=7, n_estimators=50
# [CV 4/5; 11/15] END max_depth=35, max_features=15, min_samples_leaf=16, min_samples_split=7, n_estimators=50;, score=0.996 total time=15.9min
# [CV 5/5; 11/15] START max_depth=35, max_features=15, min_samples_leaf=16, min_samples_split=7, n_estimators=50
# [CV 5/5; 11/15] END max_depth=35, max_features=15, min_samples_leaf=16, min_samples_split=7, n_estimators=50;, score=0.996 total time=16.0min
# [CV 1/5; 12/15] START max_depth=15, max_features=5, min_samples_leaf=15, min_samples_split=5, n_estimators=50
# [CV 1/5; 12/15] END max_depth=15, max_features=5, min_samples_leaf=15, min_samples_split=5, n_estimators=50;, score=0.994 total time= 5.7min
# [CV 2/5; 12/15] START max_depth=15, max_features=5, min_samples_leaf=15, min_samples_split=5, n_estimators=50
# [CV 2/5; 12/15] END max_depth=15, max_features=5, min_samples_leaf=15, min_samples_split=5, n_estimators=50;, score=0.994 total time= 5.7min
# [CV 3/5; 12/15] START max_depth=15, max_features=5, min_samples_leaf=15, min_samples_split=5, n_estimators=50
# [CV 3/5; 12/15] END max_depth=15, max_features=5, min_samples_leaf=15, min_samples_split=5, n_estimators=50;, score=0.994 total time= 5.7min
# [CV 4/5; 12/15] START max_depth=15, max_features=5, min_samples_leaf=15, min_samples_split=5, n_estimators=50
# [CV 4/5; 12/15] END max_depth=15, max_features=5, min_samples_leaf=15, min_samples_split=5, n_estimators=50;, score=0.994 total time= 5.7min
# [CV 5/5; 12/15] START max_depth=15, max_features=5, min_samples_leaf=15, min_samples_split=5, n_estimators=50
# [CV 5/5; 12/15] END max_depth=15, max_features=5, min_samples_leaf=15, min_samples_split=5, n_estimators=50;, score=0.994 total time= 5.6min
# [CV 1/5; 13/15] START max_depth=20, max_features=18, min_samples_leaf=17, min_samples_split=10, n_estimators=50
# [CV 1/5; 13/15] END max_depth=20, max_features=18, min_samples_leaf=17, min_samples_split=10, n_estimators=50;, score=0.997 total time=18.8min
# [CV 2/5; 13/15] START max_depth=20, max_features=18, min_samples_leaf=17, min_samples_split=10, n_estimators=50
# [CV 2/5; 13/15] END max_depth=20, max_features=18, min_samples_leaf=17, min_samples_split=10, n_estimators=50;, score=0.997 total time=18.7min
# [CV 3/5; 13/15] START max_depth=20, max_features=18, min_samples_leaf=17, min_samples_split=10, n_estimators=50
# [CV 3/5; 13/15] END max_depth=20, max_features=18, min_samples_leaf=17, min_samples_split=10, n_estimators=50;, score=0.997 total time=18.8min
# [CV 4/5; 13/15] START max_depth=20, max_features=18, min_samples_leaf=17, min_samples_split=10, n_estimators=50
# [CV 4/5; 13/15] END max_depth=20, max_features=18, min_samples_leaf=17, min_samples_split=10, n_estimators=50;, score=0.997 total time=18.4min
# [CV 5/5; 13/15] START max_depth=20, max_features=18, min_samples_leaf=17, min_samples_split=10, n_estimators=50
# [CV 5/5; 13/15] END max_depth=20, max_features=18, min_samples_leaf=17, min_samples_split=10, n_estimators=50;, score=0.997 total time=18.2min
# [CV 1/5; 14/15] START max_depth=30, max_features=12, min_samples_leaf=17, min_samples_split=5, n_estimators=50
# [CV 1/5; 14/15] END max_depth=30, max_features=12, min_samples_leaf=17, min_samples_split=5, n_estimators=50;, score=0.996 total time=12.5min
# [CV 2/5; 14/15] START max_depth=30, max_features=12, min_samples_leaf=17, min_samples_split=5, n_estimators=50
# [CV 2/5; 14/15] END max_depth=30, max_features=12, min_samples_leaf=17, min_samples_split=5, n_estimators=50;, score=0.996 total time=12.6min
# [CV 3/5; 14/15] START max_depth=30, max_features=12, min_samples_leaf=17, min_samples_split=5, n_estimators=50
# [CV 3/5; 14/15] END max_depth=30, max_features=12, min_samples_leaf=17, min_samples_split=5, n_estimators=50;, score=0.997 total time=13.0min
# [CV 4/5; 14/15] START max_depth=30, max_features=12, min_samples_leaf=17, min_samples_split=5, n_estimators=50
# [CV 4/5; 14/15] END max_depth=30, max_features=12, min_samples_leaf=17, min_samples_split=5, n_estimators=50;, score=0.997 total time=12.8min
# [CV 5/5; 14/15] START max_depth=30, max_features=12, min_samples_leaf=17, min_samples_split=5, n_estimators=50
# [CV 5/5; 14/15] END max_depth=30, max_features=12, min_samples_leaf=17, min_samples_split=5, n_estimators=50;, score=0.996 total time=12.6min
# [CV 1/5; 15/15] START max_depth=None, max_features=12, min_samples_leaf=17, min_samples_split=14, n_estimators=50
# [CV 1/5; 15/15] END max_depth=None, max_features=12, min_samples_leaf=17, min_samples_split=14, n_estimators=50;, score=0.996 total time=12.6min
# [CV 2/5; 15/15] START max_depth=None, max_features=12, min_samples_leaf=17, min_samples_split=14, n_estimators=50
# [CV 2/5; 15/15] END max_depth=None, max_features=12, min_samples_leaf=17, min_samples_split=14, n_estimators=50;, score=0.996 total time=12.6min
# [CV 3/5; 15/15] START max_depth=None, max_features=12, min_samples_leaf=17, min_samples_split=14, n_estimators=50
# [CV 3/5; 15/15] END max_depth=None, max_features=12, min_samples_leaf=17, min_samples_split=14, n_estimators=50;, score=0.996 total time=13.0min
# [CV 4/5; 15/15] START max_depth=None, max_features=12, min_samples_leaf=17, min_samples_split=14, n_estimators=50
# [CV 4/5; 15/15] END max_depth=None, max_features=12, min_samples_leaf=17, min_samples_split=14, n_estimators=50;, score=0.996 total time=12.9min
# [CV 5/5; 15/15] START max_depth=None, max_features=12, min_samples_leaf=17, min_samples_split=14, n_estimators=50
# [CV 5/5; 15/15] END max_depth=None, max_features=12, min_samples_leaf=17, min_samples_split=14, n_estimators=50;, score=0.996 total time=12.7min
# Lama waktu 'hyperparameter tuning' :  48274.422743320465

# %%
# Hasil tuning hyperparameter #
# =========================== #

# hasil
print ('F1 skor dan parameter terbaik')
print ('=============================')
print ('Nilai F1 skor terbaik : %s' % rf_random.best_score_)
print ('Parameter terbaik     : %s' % rf_random.best_params_)
print ('Estimator terbaik     : %s' % rf_random.best_estimator_)
test_53_rf_new_params_2 = pd.DataFrame(rf_random.cv_results_)

# simpan hasil hyperparameter random forest
test_53_rf_new_params_2.to_csv("G:\\Universitas Indonesia\\Rancangan Paper\\Dataset CSE-CIC-IDS2018-AWS\\CIC2018\\test_53_rf_new_params_2.txt", index=False)
# Out:
# F1 skor dan parameter terbaik
# =============================
# Nilai F1 skor terbaik : 0.9967708105047869
# Parameter terbaik     : {'n_estimators': 50, 'min_samples_split': 17, 'min_samples_leaf': 10, 'max_features': 15, 'max_depth': 15}
# Estimator terbaik     : RandomForestClassifier(max_depth=15, max_features=15, min_samples_leaf=10,
#                        min_samples_split=17, n_estimators=50, n_jobs=-1,
#                        random_state=42)

# %% [markdown]
# ### 53.4. Hyperparameter terbaik

# %%
# 5 hyperparameter terbaik #
# ======================== #

# hyperparameter terbaik
hyperparam_rf = pd.read_csv("G:\\Universitas Indonesia\\Rancangan Paper\\Dataset CSE-CIC-IDS2018-AWS\\CIC2018\\test_53_rf_new_params_2.txt")

# mengurutkan hyperparameter terbaik berdasarkan f1
hyperparam_rf = hyperparam_rf.sort_values("rank_test_score")

# menampilkan 5 hyperparameter terbaik
print ('5 hyperparameter terbaik berdasarkan f1')
print ('=======================================')
param = hyperparam_rf[['rank_test_score','params','mean_fit_time','mean_test_score']].reset_index(drop=True)
#param = param[['params']]
param.head(5)
# Out:
# 5 hyperparameter terbaik berdasarkan f1
# =======================================
#    rank_test_score  \
# 0                1
# 1                2
# 2                3
# 3                4
# 4                5
#
#                                                                                                        params  \
# 0  {'n_estimators': 50, 'min_samples_split': 17, 'min_samples_leaf': 10, 'max_features': 15, 'max_depth': 15}
# 1  {'n_estimators': 50, 'min_samples_split': 19, 'min_samples_leaf': 15, 'max_features': 15, 'max_depth': 20}
# 2  {'n_estimators': 50, 'min_samples_split': 10, 'min_samples_leaf': 17, 'max_features': 18, 'max_depth': 20}
# 3   {'n_estimators': 50, 'min_samples_split': 9, 'min_samples_leaf': 10, 'max_features': 12, 'max_depth': 15}
# 4   {'n_estimators': 50, 'min_samples_split': 5, 'min_samples_leaf': 17, 'max_features': 12, 'max_depth': 30}
#
#    mean_fit_time  mean_test_score
# 0     814.098207         0.996771
# 1     901.515331         0.996742
# 2    1094.738043         0.996730
# 3     672.804943         0.996712
# 4     743.023601         0.996505

# %% [markdown]
# #### 51.4.1. Latih hyperparameter terbaik berdasarkan f1

# %%
param_rf = param['params'][0]
param_terbaik = [eval(param_rf)]       

# jumlah estimator
for n in param_terbaik:
    jlh_estimator = [n['n_estimators']]

param_terbaik
# Out:
# [{'n_estimators': 50,
#   'min_samples_split': 17,
#   'min_samples_leaf': 10,
#   'max_features': 15,
#   'max_depth': 15}]

# %%
print ('|=======================================|')
print ("| Hyperparameter terbaik berdasarkan f1 |")
print ('|=======================================|')
print ('')
klf_f1, y_f1 = latih_eval_rf(param_terbaik, jlh_estimator, y_aktual_biner)
# Out:
# |=======================================|
# | Hyperparameter terbaik berdasarkan f1 |
# |=======================================|
#
# hyperparameter : {'n_estimators': 50, 'min_samples_split': 17, 'min_samples_leaf': 10, 'max_features': 15, 'max_depth': 15}
# Lama waktu latih    : 1082.092524766922
# Lama waktu prediksi : 2.6847033500671387
# hasil 'Accuracy'    : 0.9976010239032211
# hasil 'f1-score'    : 0.9967941123183024

# %% [markdown]
# #### 53.4.2. Metrik evaluasi

# %%
# metrik evaluasi lapisan 1 berdasarkan f1
metrik (None, 1, y_aktual_biner, y_f1)

# misklasifikasi lapisan 1
misklasifikasi(y_aktual_biner, y_f1)
# Out:
# Accuracy, Precision, Recall dan F1-score :
# ==========================================
# Accuracy  : 0.9976010239032211
# Precision : 0.997928898981888
# Recall    : 0.9956720959043871
# F1-score  : 0.9967941123183024
#
# metrik evaluasi :
# =================
#               precision    recall  f1-score   support
#
#       attack   0.998580  0.991814  0.995186    548880
#       benign   0.997278  0.999530  0.998402   1646640
#
#     accuracy                       0.997601   2195520
#    macro avg   0.997929  0.995672  0.996794   2195520
# weighted avg   0.997603  0.997601  0.997598   2195520
#
#
# matriks "confusion" :
# =====================
# misklasifikasi kelas target:
# ============================
#         misklasifikasi    total  persentase_misklasifikasi(%)
# attack            4493   548880                      0.818576
# benign             774  1646640                      0.047005

# %% [markdown]
# # Test 54

# %% [markdown]
# ### 54.1. Seleksi fitur dengan random forest - 99%

# %%
# Seleksi fitur dengan 'random forest' #
# ==================================== #

m_sf = time.time()

# ambang batas persentase skor
persentase_skor = 99

# vektor target
vektor_target = y_train['label']

# jumlah 'trees'
jumlah_trees = 100

# fitur terpilih dan fitur dihapus
klf = RandomForestClassifier(n_estimators=jumlah_trees, random_state=42, n_jobs=-1)
fit = klf.fit(X_train_norm, vektor_target)
fitur_dihapus_rf,fitur_terpilih_rf = fitur_terbaik (fit, persentase_skor, X_train_norm, 'rf')

# hapus fitur dengan skor terendah
X_train_rf = X_train_norm.drop(fitur_dihapus_rf, axis=1)
X_test_rf = X_test_norm.drop(fitur_dihapus_rf, axis=1)

s_sf = time.time()
print ('')
print ("Lama waktu seleksi fitur 'random forest' : ", s_sf - m_sf)
# Out:
# Fitur yang dihapus
# ==================
# ['bwd_iat_tot', 'bwd_iat_std', 'bwd_iat_mean', 'bwd_iat_max', 'bwd_iat_min', 'active_mean', 'active_min', 'active_max', 'protocol', 'fin_flag_cnt', 'fwd_pkt_len_min', 'bwd_pkt_len_min', 'fwd_psh_flags', 'active_std', 'pkt_len_min', 'idle_std', 'fwd_urg_flags']
#
#
# Fitur dengan skor terbaik
# =========================
#                 Fitur  Persentase skor  jumlah persentase
# 1           timestamp        13.203745          13.203745
# 2   init_fwd_win_byts        11.820155          25.023900
# 3            dst_port         6.175546          31.199446
# 4    fwd_seg_size_min         5.007278          36.206724
# 5          fwd_pkts_s         3.588357          39.795081
# 6     totlen_fwd_pkts         3.583811          43.378891
# 7     fwd_pkt_len_max         3.499403          46.878294
# 8    fwd_pkt_len_mean         3.479688          50.357982
# 9         flow_pkts_s         3.396002          53.753984
# 10     fwd_header_len         3.118528          56.872513
# 11      flow_duration         2.047449          58.919962
# 12       pkt_size_avg         2.042128          60.962090
# 13       tot_bwd_pkts         2.012136          62.974226
# 14     bwd_header_len         1.998965          64.973191
# 15      flow_iat_mean         1.907097          66.880288
# 16       pkt_len_mean         1.688748          68.569037
# 17       flow_iat_max         1.676447          70.245484
# 18   bwd_pkt_len_mean         1.659495          71.904979
# 19        pkt_len_std         1.561449          73.466428
# 20       flow_iat_min         1.529020          74.995449
# 21        pkt_len_max         1.515209          76.510658
# 22  init_bwd_win_byts         1.502816          78.013474
# 23       fwd_iat_mean         1.478805          79.492279
# 24       tot_fwd_pkts         1.428082          80.920361
# 25        fwd_iat_max         1.236525          82.156886
# 26    bwd_pkt_len_std         1.139477          83.296363
# 27    fwd_pkt_len_std         1.126184          84.422548
# 28         bwd_pkts_s         1.103041          85.525589
# 29        pkt_len_var         1.043581          86.569170
# 30        fwd_iat_tot         1.035958          87.605128
# 31    totlen_bwd_pkts         1.033024          88.638152
# 32       psh_flag_cnt         1.021122          89.659274
# 33        fwd_iat_min         0.924765          90.584039
# 34    bwd_pkt_len_max         0.918601          91.502639
# 35          idle_mean         0.898417          92.401056
# 36       ack_flag_cnt         0.877906          93.278963
# 37           idle_min         0.845042          94.124005
# 38  fwd_act_data_pkts         0.696160          94.820165
# 39       flow_iat_std         0.607959          95.428124
# 40      down_up_ratio         0.601002          96.029126
# 41        fwd_iat_std         0.584522          96.613648
# 42           idle_max         0.566132          97.179780
# 43       ece_flag_cnt         0.537375          97.717155
# 44       urg_flag_cnt         0.424153          98.141308
# 45       rst_flag_cnt         0.303805          98.445113
# 46        flow_byts_s         0.286933          98.732046
#
# Lama waktu seleksi fitur 'random forest' :  1204.3918762207031

# %%
# label aktual dan jumlah fitur #
# ============================= #

# label aktual biner kelas
y_aktual_biner = y_test['label_binary'].reset_index(drop=True)

# fitur dan jumlah fitur yang digunakan
print ('Fitur yang digunakan')
print ('====================')
print (list(X_train_rf.columns))
print ('')
print ('Jumlah fitur')
print ('============')
print (len(X_train_rf.columns),'fitur')
# Out:
# Fitur yang digunakan
# ====================
# ['dst_port', 'timestamp', 'flow_duration', 'tot_fwd_pkts', 'tot_bwd_pkts', 'totlen_fwd_pkts', 'totlen_bwd_pkts', 'fwd_pkt_len_max', 'fwd_pkt_len_mean', 'fwd_pkt_len_std', 'bwd_pkt_len_max', 'bwd_pkt_len_mean', 'bwd_pkt_len_std', 'flow_byts_s', 'flow_pkts_s', 'flow_iat_mean', 'flow_iat_std', 'flow_iat_max', 'flow_iat_min', 'fwd_iat_tot', 'fwd_iat_mean', 'fwd_iat_std', 'fwd_iat_max', 'fwd_iat_min', 'fwd_header_len', 'bwd_header_len', 'fwd_pkts_s', 'bwd_pkts_s', 'pkt_len_max', 'pkt_len_mean', 'pkt_len_std', 'pkt_len_var', 'rst_flag_cnt', 'psh_flag_cnt', 'ack_flag_cnt', 'urg_flag_cnt', 'ece_flag_cnt', 'down_up_ratio', 'pkt_size_avg', 'init_fwd_win_byts', 'init_bwd_win_byts', 'fwd_act_data_pkts', 'fwd_seg_size_min', 'idle_mean', 'idle_max', 'idle_min']
#
# Jumlah fitur
# ============
# 46 fitur

# %% [markdown]
# ### 54.2. Pemilihan jumlah 'tree'

# %%
# Pemilihan jumlah 'trees' #
# ======================== #

m_jlh = time.time()

# parameter yang digunakan
param_klf = [{'random_state':42, 'n_jobs':-1}]                
jlh_estimator = [10,15,20,25,30,35,40,45,50]

# hasil pelatihan
latih_eval_rf(param_klf, jlh_estimator, y_aktual_biner)

s_jlh = time.time()
print ("Lama waktu pencarian jumlah 'tree' : ", s_jlh - m_jlh)
# Out:
# jumlah 'trees' : 10
# ===================
# hyperparameter : {'random_state': 42, 'n_jobs': -1}
# Lama waktu latih    : 150.46628999710083
# Lama waktu prediksi : 1.337672472000122
# hasil 'Accuracy'    : 0.9959148629937327
# hasil 'f1-score'    : 0.994548953954138
#
# jumlah 'trees' : 15
# ===================
# hyperparameter : {'random_state': 42, 'n_jobs': -1}
# Lama waktu latih    : 196.35320901870728
# Lama waktu prediksi : 1.6994071006774902
# hasil 'Accuracy'    : 0.9959239724529952
# hasil 'f1-score'    : 0.9945605531822641
#
# jumlah 'trees' : 20
# ===================
# hyperparameter : {'random_state': 42, 'n_jobs': -1}
# Lama waktu latih    : 259.2374653816223
# Lama waktu prediksi : 2.1894960403442383
# hasil 'Accuracy'    : 0.9959444687363358
# hasil 'f1-score'    : 0.994587994345589
#
# jumlah 'trees' : 25
# ===================
# hyperparameter : {'random_state': 42, 'n_jobs': -1}
# Lama waktu latih    : 294.1394953727722
# Lama waktu prediksi : 2.4747610092163086
# hasil 'Accuracy'    : 0.9959390030607783
# hasil 'f1-score'    : 0.9945806015892004
#
# jumlah 'trees' : 30
# ===================
# hyperparameter : {'random_state': 42, 'n_jobs': -1}
# Lama waktu latih    : 362.7732083797455
# Lama waktu prediksi : 3.1392533779144287
# hasil 'Accuracy'    : 0.9959321709663315
# hasil 'f1-score'    : 0.9945718508553223
#
# jumlah 'trees' : 35
# ===================
# hyperparameter : {'random_state': 42, 'n_jobs': -1}
# Lama waktu latih    : 418.5826051235199
# Lama waktu prediksi : 3.4001388549804688
# hasil 'Accuracy'    : 0.995930349074479
# hasil 'f1-score'    : 0.9945692412456127
#
# jumlah 'trees' : 40
# ===================
# hyperparameter : {'random_state': 42, 'n_jobs': -1}
# Lama waktu latih    : 464.45691537857056
# Lama waktu prediksi : 3.773040771484375
# hasil 'Accuracy'    : 0.9959308045474421
# hasil 'f1-score'    : 0.9945700638395797
#
# jumlah 'trees' : 45
# ===================
# hyperparameter : {'random_state': 42, 'n_jobs': -1}
# Lama waktu latih    : 514.4182913303375
# Lama waktu prediksi : 4.250978708267212
# hasil 'Accuracy'    : 0.9959362702229996
# hasil 'f1-score'    : 0.9945773770377229
#
# jumlah 'trees' : 50
# ===================
# hyperparameter : {'random_state': 42, 'n_jobs': -1}
# Lama waktu latih    : 568.9932312965393
# Lama waktu prediksi : 4.578874349594116
# hasil 'Accuracy'    : 0.9959417358985571
# hasil 'f1-score'    : 0.9945846440485813
#
# Lama waktu pencarian jumlah 'tree' :  3717.4726209640503

# %%
# list hasil pelatihan
print ('List hasil pelatihan')
print ('====================')
print ('hasil_waktu_latih    =', hasil_waktu_latih)
print ('hasil_waktu_prediksi =', hasil_waktu_pred)
print ('hasil_f1_macro       =', hasil_f1_macro)
print ('hasil_akurasi        =', hasil_akurasi)
print ('jumlah_estimator     =', jlh_estimator)
# Out:
# List hasil pelatihan
# ====================
# hasil_waktu_latih    = [150.46628999710083, 196.35320901870728, 259.2374653816223, 294.1394953727722, 362.7732083797455, 418.5826051235199, 464.45691537857056, 514.4182913303375, 568.9932312965393]
# hasil_waktu_prediksi = [1.337672472000122, 1.6994071006774902, 2.1894960403442383, 2.4747610092163086, 3.1392533779144287, 3.4001388549804688, 3.773040771484375, 4.250978708267212, 4.578874349594116]
# hasil_f1_macro       = [0.994548953954138, 0.9945605531822641, 0.994587994345589, 0.9945806015892004, 0.9945718508553223, 0.9945692412456127, 0.9945700638395797, 0.9945773770377229, 0.9945846440485813]
# hasil_akurasi        = [0.9959148629937327, 0.9959239724529952, 0.9959444687363358, 0.9959390030607783, 0.9959321709663315, 0.995930349074479, 0.9959308045474421, 0.9959362702229996, 0.9959417358985571]
# jumlah_estimator     = [10, 15, 20, 25, 30, 35, 40, 45, 50]

# %% [markdown]
# #### 54.2.1. Plot hasil pengukuran

# %%
# Plot hasil pengukuran #
# ===================== #

# Plot waktu latih dan akurasi
plot_eval(hasil_waktu_latih,hasil_akurasi,jumlah_estimator,'Jumlah "trees"','Waktu latih','Accuracy')

# Plot waktu prediksi dan akurasi
plot_eval(hasil_waktu_pred,hasil_f1_macro,jumlah_estimator,'Jumlah "trees"','Waktu prediksi','F1-score')

# Plot waktu pelatihan
plot_eval(None,hasil_waktu_latih,jumlah_estimator,'Jumlah trees','Waktu latih',None)

# Plot waktu prediksi
plot_eval(None,hasil_waktu_pred,jumlah_estimator,'Jumlah trees','Waktu prediksi',None)

# Plot Akurasi
plot_eval(None,hasil_akurasi,jumlah_estimator,'Jumlah trees','Accuracy',None)

# plot F1
plot_eval(None,hasil_f1_macro,jumlah_estimator,'Jumlah trees','F1-score',None)
# Out:
#  PLOT WAKTU LATIH
# ==================
#  PLOT WAKTU PREDIKSI
# =====================
#  PLOT WAKTU LATIH
# ==================
#  PLOT WAKTU PREDIKSI
# =====================
#  PLOT ACCURACY
# ===============
#  PLOT F1-SCORE
# ===============

# %% [markdown]
# ### 54.3. Hyperparameter tuning random forest

# %%
# Hyperparameter tuning random forest #
# =================================== #

m_hyper = time.time()

# hyperparameter yang digunakan untuk tuning
jlh_estimator     = [20]
max_features      = [5, 9, 12, 15, 18]
max_depth         = [None,5,10,15,20,25,30,35]
min_samples_split = [2,3,4,5,6,7,9,10,11,12,13,14,15,16,17,17,18,19,20]
min_samples_leaf  = [2,3,4,5,6,7,9,10,11,12,13,14,15,16,17,17,18,19,20]

# pembangunan model
rf = RandomForestClassifier(random_state=42, n_jobs=-1)

# jumlah acak kombinasi nilai hyperparameter
n_iter = 15

# validasi silang 5 lipatan
cv = 5

# tentukan f1 macro
f1_macro_scorer = make_scorer(f1_score, greater_is_better=True, average='macro')

# random grid search
random_grid = {'n_estimators': jlh_estimator,'max_depth': max_depth,'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,'max_features': max_features}

rf_random = RandomizedSearchCV(estimator=rf, param_distributions=random_grid, 
                               n_iter=n_iter, cv=cv, verbose=10, random_state=22, n_jobs=None, scoring=f1_macro_scorer)

# terapkan random grid pada data latih
rf_random.fit(X_train_rf, y_train['label_binary'])

s_hyper = time.time()
print ("Lama waktu 'hyperparameter tuning' : ", s_hyper - m_hyper)
# Out:
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
# [CV 1/5; 1/15] START max_depth=30, max_features=5, min_samples_leaf=17, min_samples_split=13, n_estimators=20
# [CV 1/5; 1/15] END max_depth=30, max_features=5, min_samples_leaf=17, min_samples_split=13, n_estimators=20;, score=0.995 total time= 3.2min
# [CV 2/5; 1/15] START max_depth=30, max_features=5, min_samples_leaf=17, min_samples_split=13, n_estimators=20
# [CV 2/5; 1/15] END max_depth=30, max_features=5, min_samples_leaf=17, min_samples_split=13, n_estimators=20;, score=0.995 total time= 3.1min
# [CV 3/5; 1/15] START max_depth=30, max_features=5, min_samples_leaf=17, min_samples_split=13, n_estimators=20
# [CV 3/5; 1/15] END max_depth=30, max_features=5, min_samples_leaf=17, min_samples_split=13, n_estimators=20;, score=0.995 total time= 3.2min
# [CV 4/5; 1/15] START max_depth=30, max_features=5, min_samples_leaf=17, min_samples_split=13, n_estimators=20
# [CV 4/5; 1/15] END max_depth=30, max_features=5, min_samples_leaf=17, min_samples_split=13, n_estimators=20;, score=0.996 total time= 3.2min
# [CV 5/5; 1/15] START max_depth=30, max_features=5, min_samples_leaf=17, min_samples_split=13, n_estimators=20
# [CV 5/5; 1/15] END max_depth=30, max_features=5, min_samples_leaf=17, min_samples_split=13, n_estimators=20;, score=0.995 total time= 3.1min
# [CV 1/5; 2/15] START max_depth=15, max_features=12, min_samples_leaf=10, min_samples_split=9, n_estimators=20
# [CV 1/5; 2/15] END max_depth=15, max_features=12, min_samples_leaf=10, min_samples_split=9, n_estimators=20;, score=0.996 total time= 5.0min
# [CV 2/5; 2/15] START max_depth=15, max_features=12, min_samples_leaf=10, min_samples_split=9, n_estimators=20
# [CV 2/5; 2/15] END max_depth=15, max_features=12, min_samples_leaf=10, min_samples_split=9, n_estimators=20;, score=0.996 total time= 5.0min
# [CV 3/5; 2/15] START max_depth=15, max_features=12, min_samples_leaf=10, min_samples_split=9, n_estimators=20
# [CV 3/5; 2/15] END max_depth=15, max_features=12, min_samples_leaf=10, min_samples_split=9, n_estimators=20;, score=0.997 total time= 4.8min
# [CV 4/5; 2/15] START max_depth=15, max_features=12, min_samples_leaf=10, min_samples_split=9, n_estimators=20
# [CV 4/5; 2/15] END max_depth=15, max_features=12, min_samples_leaf=10, min_samples_split=9, n_estimators=20;, score=0.997 total time= 4.9min
# [CV 5/5; 2/15] START max_depth=15, max_features=12, min_samples_leaf=10, min_samples_split=9, n_estimators=20
# [CV 5/5; 2/15] END max_depth=15, max_features=12, min_samples_leaf=10, min_samples_split=9, n_estimators=20;, score=0.996 total time= 4.8min
# [CV 1/5; 3/15] START max_depth=35, max_features=9, min_samples_leaf=7, min_samples_split=12, n_estimators=20
# [CV 1/5; 3/15] END max_depth=35, max_features=9, min_samples_leaf=7, min_samples_split=12, n_estimators=20;, score=0.996 total time= 4.4min
# [CV 2/5; 3/15] START max_depth=35, max_features=9, min_samples_leaf=7, min_samples_split=12, n_estimators=20
# [CV 2/5; 3/15] END max_depth=35, max_features=9, min_samples_leaf=7, min_samples_split=12, n_estimators=20;, score=0.996 total time= 4.6min
# [CV 3/5; 3/15] START max_depth=35, max_features=9, min_samples_leaf=7, min_samples_split=12, n_estimators=20
# [CV 3/5; 3/15] END max_depth=35, max_features=9, min_samples_leaf=7, min_samples_split=12, n_estimators=20;, score=0.996 total time= 5.0min
# [CV 4/5; 3/15] START max_depth=35, max_features=9, min_samples_leaf=7, min_samples_split=12, n_estimators=20
# [CV 4/5; 3/15] END max_depth=35, max_features=9, min_samples_leaf=7, min_samples_split=12, n_estimators=20;, score=0.996 total time= 4.6min
# [CV 5/5; 3/15] START max_depth=35, max_features=9, min_samples_leaf=7, min_samples_split=12, n_estimators=20
# [CV 5/5; 3/15] END max_depth=35, max_features=9, min_samples_leaf=7, min_samples_split=12, n_estimators=20;, score=0.996 total time= 4.5min
# [CV 1/5; 4/15] START max_depth=20, max_features=15, min_samples_leaf=15, min_samples_split=19, n_estimators=20
# [CV 1/5; 4/15] END max_depth=20, max_features=15, min_samples_leaf=15, min_samples_split=19, n_estimators=20;, score=0.997 total time= 6.5min
# [CV 2/5; 4/15] START max_depth=20, max_features=15, min_samples_leaf=15, min_samples_split=19, n_estimators=20
# [CV 2/5; 4/15] END max_depth=20, max_features=15, min_samples_leaf=15, min_samples_split=19, n_estimators=20;, score=0.997 total time= 6.7min
# [CV 3/5; 4/15] START max_depth=20, max_features=15, min_samples_leaf=15, min_samples_split=19, n_estimators=20
# [CV 3/5; 4/15] END max_depth=20, max_features=15, min_samples_leaf=15, min_samples_split=19, n_estimators=20;, score=0.997 total time= 6.6min
# [CV 4/5; 4/15] START max_depth=20, max_features=15, min_samples_leaf=15, min_samples_split=19, n_estimators=20
# [CV 4/5; 4/15] END max_depth=20, max_features=15, min_samples_leaf=15, min_samples_split=19, n_estimators=20;, score=0.997 total time= 6.6min
# [CV 5/5; 4/15] START max_depth=20, max_features=15, min_samples_leaf=15, min_samples_split=19, n_estimators=20
# [CV 5/5; 4/15] END max_depth=20, max_features=15, min_samples_leaf=15, min_samples_split=19, n_estimators=20;, score=0.997 total time= 6.7min
# [CV 1/5; 5/15] START max_depth=15, max_features=5, min_samples_leaf=5, min_samples_split=9, n_estimators=20
# [CV 1/5; 5/15] END max_depth=15, max_features=5, min_samples_leaf=5, min_samples_split=9, n_estimators=20;, score=0.993 total time= 2.6min
# [CV 2/5; 5/15] START max_depth=15, max_features=5, min_samples_leaf=5, min_samples_split=9, n_estimators=20
# [CV 2/5; 5/15] END max_depth=15, max_features=5, min_samples_leaf=5, min_samples_split=9, n_estimators=20;, score=0.993 total time= 2.6min
# [CV 3/5; 5/15] START max_depth=15, max_features=5, min_samples_leaf=5, min_samples_split=9, n_estimators=20
# [CV 3/5; 5/15] END max_depth=15, max_features=5, min_samples_leaf=5, min_samples_split=9, n_estimators=20;, score=0.991 total time= 2.6min
# [CV 4/5; 5/15] START max_depth=15, max_features=5, min_samples_leaf=5, min_samples_split=9, n_estimators=20
# [CV 4/5; 5/15] END max_depth=15, max_features=5, min_samples_leaf=5, min_samples_split=9, n_estimators=20;, score=0.993 total time= 2.6min
# [CV 5/5; 5/15] START max_depth=15, max_features=5, min_samples_leaf=5, min_samples_split=9, n_estimators=20
# [CV 5/5; 5/15] END max_depth=15, max_features=5, min_samples_leaf=5, min_samples_split=9, n_estimators=20;, score=0.993 total time= 2.6min
# [CV 1/5; 6/15] START max_depth=15, max_features=15, min_samples_leaf=10, min_samples_split=17, n_estimators=20
# [CV 1/5; 6/15] END max_depth=15, max_features=15, min_samples_leaf=10, min_samples_split=17, n_estimators=20;, score=0.997 total time= 6.1min
# [CV 2/5; 6/15] START max_depth=15, max_features=15, min_samples_leaf=10, min_samples_split=17, n_estimators=20
# [CV 2/5; 6/15] END max_depth=15, max_features=15, min_samples_leaf=10, min_samples_split=17, n_estimators=20;, score=0.997 total time= 6.0min
# [CV 3/5; 6/15] START max_depth=15, max_features=15, min_samples_leaf=10, min_samples_split=17, n_estimators=20
# [CV 3/5; 6/15] END max_depth=15, max_features=15, min_samples_leaf=10, min_samples_split=17, n_estimators=20;, score=0.997 total time= 6.0min
# [CV 4/5; 6/15] START max_depth=15, max_features=15, min_samples_leaf=10, min_samples_split=17, n_estimators=20
# [CV 4/5; 6/15] END max_depth=15, max_features=15, min_samples_leaf=10, min_samples_split=17, n_estimators=20;, score=0.997 total time= 6.0min
# [CV 5/5; 6/15] START max_depth=15, max_features=15, min_samples_leaf=10, min_samples_split=17, n_estimators=20
# [CV 5/5; 6/15] END max_depth=15, max_features=15, min_samples_leaf=10, min_samples_split=17, n_estimators=20;, score=0.997 total time= 6.0min
# [CV 1/5; 7/15] START max_depth=10, max_features=12, min_samples_leaf=16, min_samples_split=11, n_estimators=20
# [CV 1/5; 7/15] END max_depth=10, max_features=12, min_samples_leaf=16, min_samples_split=11, n_estimators=20;, score=0.995 total time= 3.8min
# [CV 2/5; 7/15] START max_depth=10, max_features=12, min_samples_leaf=16, min_samples_split=11, n_estimators=20
# [CV 2/5; 7/15] END max_depth=10, max_features=12, min_samples_leaf=16, min_samples_split=11, n_estimators=20;, score=0.994 total time= 3.9min
# [CV 3/5; 7/15] START max_depth=10, max_features=12, min_samples_leaf=16, min_samples_split=11, n_estimators=20
# [CV 3/5; 7/15] END max_depth=10, max_features=12, min_samples_leaf=16, min_samples_split=11, n_estimators=20;, score=0.995 total time= 3.8min
# [CV 4/5; 7/15] START max_depth=10, max_features=12, min_samples_leaf=16, min_samples_split=11, n_estimators=20
# [CV 4/5; 7/15] END max_depth=10, max_features=12, min_samples_leaf=16, min_samples_split=11, n_estimators=20;, score=0.995 total time= 3.8min
# [CV 5/5; 7/15] START max_depth=10, max_features=12, min_samples_leaf=16, min_samples_split=11, n_estimators=20
# [CV 5/5; 7/15] END max_depth=10, max_features=12, min_samples_leaf=16, min_samples_split=11, n_estimators=20;, score=0.994 total time= 3.8min
# [CV 1/5; 8/15] START max_depth=30, max_features=5, min_samples_leaf=18, min_samples_split=13, n_estimators=20
# [CV 1/5; 8/15] END max_depth=30, max_features=5, min_samples_leaf=18, min_samples_split=13, n_estimators=20;, score=0.996 total time= 3.1min
# [CV 2/5; 8/15] START max_depth=30, max_features=5, min_samples_leaf=18, min_samples_split=13, n_estimators=20
# [CV 2/5; 8/15] END max_depth=30, max_features=5, min_samples_leaf=18, min_samples_split=13, n_estimators=20;, score=0.996 total time= 3.2min
# [CV 3/5; 8/15] START max_depth=30, max_features=5, min_samples_leaf=18, min_samples_split=13, n_estimators=20
# [CV 3/5; 8/15] END max_depth=30, max_features=5, min_samples_leaf=18, min_samples_split=13, n_estimators=20;, score=0.995 total time= 3.2min
# [CV 4/5; 8/15] START max_depth=30, max_features=5, min_samples_leaf=18, min_samples_split=13, n_estimators=20
# [CV 4/5; 8/15] END max_depth=30, max_features=5, min_samples_leaf=18, min_samples_split=13, n_estimators=20;, score=0.995 total time= 3.2min
# [CV 5/5; 8/15] START max_depth=30, max_features=5, min_samples_leaf=18, min_samples_split=13, n_estimators=20
# [CV 5/5; 8/15] END max_depth=30, max_features=5, min_samples_leaf=18, min_samples_split=13, n_estimators=20;, score=0.996 total time= 3.2min
# [CV 1/5; 9/15] START max_depth=5, max_features=12, min_samples_leaf=2, min_samples_split=2, n_estimators=20
# [CV 1/5; 9/15] END max_depth=5, max_features=12, min_samples_leaf=2, min_samples_split=2, n_estimators=20;, score=0.983 total time= 2.4min
# [CV 2/5; 9/15] START max_depth=5, max_features=12, min_samples_leaf=2, min_samples_split=2, n_estimators=20
# [CV 2/5; 9/15] END max_depth=5, max_features=12, min_samples_leaf=2, min_samples_split=2, n_estimators=20;, score=0.983 total time= 2.4min
# [CV 3/5; 9/15] START max_depth=5, max_features=12, min_samples_leaf=2, min_samples_split=2, n_estimators=20
# [CV 3/5; 9/15] END max_depth=5, max_features=12, min_samples_leaf=2, min_samples_split=2, n_estimators=20;, score=0.985 total time= 2.4min
# [CV 4/5; 9/15] START max_depth=5, max_features=12, min_samples_leaf=2, min_samples_split=2, n_estimators=20
# [CV 4/5; 9/15] END max_depth=5, max_features=12, min_samples_leaf=2, min_samples_split=2, n_estimators=20;, score=0.984 total time= 2.4min
# [CV 5/5; 9/15] START max_depth=5, max_features=12, min_samples_leaf=2, min_samples_split=2, n_estimators=20
# [CV 5/5; 9/15] END max_depth=5, max_features=12, min_samples_leaf=2, min_samples_split=2, n_estimators=20;, score=0.984 total time= 2.4min
# [CV 1/5; 10/15] START max_depth=25, max_features=5, min_samples_leaf=11, min_samples_split=6, n_estimators=20
# [CV 1/5; 10/15] END max_depth=25, max_features=5, min_samples_leaf=11, min_samples_split=6, n_estimators=20;, score=0.996 total time= 3.1min
# [CV 2/5; 10/15] START max_depth=25, max_features=5, min_samples_leaf=11, min_samples_split=6, n_estimators=20
# [CV 2/5; 10/15] END max_depth=25, max_features=5, min_samples_leaf=11, min_samples_split=6, n_estimators=20;, score=0.996 total time= 3.0min
# [CV 3/5; 10/15] START max_depth=25, max_features=5, min_samples_leaf=11, min_samples_split=6, n_estimators=20
# [CV 3/5; 10/15] END max_depth=25, max_features=5, min_samples_leaf=11, min_samples_split=6, n_estimators=20;, score=0.996 total time= 3.1min
# [CV 4/5; 10/15] START max_depth=25, max_features=5, min_samples_leaf=11, min_samples_split=6, n_estimators=20
# [CV 4/5; 10/15] END max_depth=25, max_features=5, min_samples_leaf=11, min_samples_split=6, n_estimators=20;, score=0.995 total time= 3.1min
# [CV 5/5; 10/15] START max_depth=25, max_features=5, min_samples_leaf=11, min_samples_split=6, n_estimators=20
# [CV 5/5; 10/15] END max_depth=25, max_features=5, min_samples_leaf=11, min_samples_split=6, n_estimators=20;, score=0.995 total time= 3.0min
# [CV 1/5; 11/15] START max_depth=35, max_features=15, min_samples_leaf=16, min_samples_split=7, n_estimators=20
# [CV 1/5; 11/15] END max_depth=35, max_features=15, min_samples_leaf=16, min_samples_split=7, n_estimators=20;, score=0.996 total time= 6.8min
# [CV 2/5; 11/15] START max_depth=35, max_features=15, min_samples_leaf=16, min_samples_split=7, n_estimators=20
# [CV 2/5; 11/15] END max_depth=35, max_features=15, min_samples_leaf=16, min_samples_split=7, n_estimators=20;, score=0.996 total time= 6.7min
# [CV 3/5; 11/15] START max_depth=35, max_features=15, min_samples_leaf=16, min_samples_split=7, n_estimators=20
# [CV 3/5; 11/15] END max_depth=35, max_features=15, min_samples_leaf=16, min_samples_split=7, n_estimators=20;, score=0.996 total time= 6.4min
# [CV 4/5; 11/15] START max_depth=35, max_features=15, min_samples_leaf=16, min_samples_split=7, n_estimators=20
# [CV 4/5; 11/15] END max_depth=35, max_features=15, min_samples_leaf=16, min_samples_split=7, n_estimators=20;, score=0.996 total time= 6.6min
# [CV 5/5; 11/15] START max_depth=35, max_features=15, min_samples_leaf=16, min_samples_split=7, n_estimators=20
# [CV 5/5; 11/15] END max_depth=35, max_features=15, min_samples_leaf=16, min_samples_split=7, n_estimators=20;, score=0.996 total time= 6.8min
# [CV 1/5; 12/15] START max_depth=15, max_features=5, min_samples_leaf=15, min_samples_split=5, n_estimators=20
# [CV 1/5; 12/15] END max_depth=15, max_features=5, min_samples_leaf=15, min_samples_split=5, n_estimators=20;, score=0.993 total time= 2.5min
# [CV 2/5; 12/15] START max_depth=15, max_features=5, min_samples_leaf=15, min_samples_split=5, n_estimators=20
# [CV 2/5; 12/15] END max_depth=15, max_features=5, min_samples_leaf=15, min_samples_split=5, n_estimators=20;, score=0.994 total time= 2.6min
# [CV 3/5; 12/15] START max_depth=15, max_features=5, min_samples_leaf=15, min_samples_split=5, n_estimators=20
# [CV 3/5; 12/15] END max_depth=15, max_features=5, min_samples_leaf=15, min_samples_split=5, n_estimators=20;, score=0.993 total time= 2.5min
# [CV 4/5; 12/15] START max_depth=15, max_features=5, min_samples_leaf=15, min_samples_split=5, n_estimators=20
# [CV 4/5; 12/15] END max_depth=15, max_features=5, min_samples_leaf=15, min_samples_split=5, n_estimators=20;, score=0.993 total time= 2.5min
# [CV 5/5; 12/15] START max_depth=15, max_features=5, min_samples_leaf=15, min_samples_split=5, n_estimators=20
# [CV 5/5; 12/15] END max_depth=15, max_features=5, min_samples_leaf=15, min_samples_split=5, n_estimators=20;, score=0.993 total time= 2.6min
# [CV 1/5; 13/15] START max_depth=20, max_features=18, min_samples_leaf=17, min_samples_split=10, n_estimators=20
# [CV 1/5; 13/15] END max_depth=20, max_features=18, min_samples_leaf=17, min_samples_split=10, n_estimators=20;, score=0.997 total time= 7.4min
# [CV 2/5; 13/15] START max_depth=20, max_features=18, min_samples_leaf=17, min_samples_split=10, n_estimators=20
# [CV 2/5; 13/15] END max_depth=20, max_features=18, min_samples_leaf=17, min_samples_split=10, n_estimators=20;, score=0.997 total time= 7.2min
# [CV 3/5; 13/15] START max_depth=20, max_features=18, min_samples_leaf=17, min_samples_split=10, n_estimators=20
# [CV 3/5; 13/15] END max_depth=20, max_features=18, min_samples_leaf=17, min_samples_split=10, n_estimators=20;, score=0.997 total time= 7.8min
# [CV 4/5; 13/15] START max_depth=20, max_features=18, min_samples_leaf=17, min_samples_split=10, n_estimators=20
# [CV 4/5; 13/15] END max_depth=20, max_features=18, min_samples_leaf=17, min_samples_split=10, n_estimators=20;, score=0.997 total time= 8.0min
# [CV 5/5; 13/15] START max_depth=20, max_features=18, min_samples_leaf=17, min_samples_split=10, n_estimators=20
# [CV 5/5; 13/15] END max_depth=20, max_features=18, min_samples_leaf=17, min_samples_split=10, n_estimators=20;, score=0.997 total time= 7.9min
# [CV 1/5; 14/15] START max_depth=30, max_features=12, min_samples_leaf=17, min_samples_split=5, n_estimators=20
# [CV 1/5; 14/15] END max_depth=30, max_features=12, min_samples_leaf=17, min_samples_split=5, n_estimators=20;, score=0.996 total time= 5.6min
# [CV 2/5; 14/15] START max_depth=30, max_features=12, min_samples_leaf=17, min_samples_split=5, n_estimators=20
# [CV 2/5; 14/15] END max_depth=30, max_features=12, min_samples_leaf=17, min_samples_split=5, n_estimators=20;, score=0.996 total time= 5.8min
# [CV 3/5; 14/15] START max_depth=30, max_features=12, min_samples_leaf=17, min_samples_split=5, n_estimators=20
# [CV 3/5; 14/15] END max_depth=30, max_features=12, min_samples_leaf=17, min_samples_split=5, n_estimators=20;, score=0.997 total time= 5.7min
# [CV 4/5; 14/15] START max_depth=30, max_features=12, min_samples_leaf=17, min_samples_split=5, n_estimators=20
# [CV 4/5; 14/15] END max_depth=30, max_features=12, min_samples_leaf=17, min_samples_split=5, n_estimators=20;, score=0.997 total time= 5.6min
# [CV 5/5; 14/15] START max_depth=30, max_features=12, min_samples_leaf=17, min_samples_split=5, n_estimators=20
# [CV 5/5; 14/15] END max_depth=30, max_features=12, min_samples_leaf=17, min_samples_split=5, n_estimators=20;, score=0.997 total time= 5.6min
# [CV 1/5; 15/15] START max_depth=None, max_features=12, min_samples_leaf=17, min_samples_split=14, n_estimators=20
# [CV 1/5; 15/15] END max_depth=None, max_features=12, min_samples_leaf=17, min_samples_split=14, n_estimators=20;, score=0.996 total time= 5.8min
# [CV 2/5; 15/15] START max_depth=None, max_features=12, min_samples_leaf=17, min_samples_split=14, n_estimators=20
# [CV 2/5; 15/15] END max_depth=None, max_features=12, min_samples_leaf=17, min_samples_split=14, n_estimators=20;, score=0.996 total time= 5.6min
# [CV 3/5; 15/15] START max_depth=None, max_features=12, min_samples_leaf=17, min_samples_split=14, n_estimators=20
# [CV 3/5; 15/15] END max_depth=None, max_features=12, min_samples_leaf=17, min_samples_split=14, n_estimators=20;, score=0.996 total time= 5.6min
# [CV 4/5; 15/15] START max_depth=None, max_features=12, min_samples_leaf=17, min_samples_split=14, n_estimators=20
# [CV 4/5; 15/15] END max_depth=None, max_features=12, min_samples_leaf=17, min_samples_split=14, n_estimators=20;, score=0.996 total time= 5.9min
# [CV 5/5; 15/15] START max_depth=None, max_features=12, min_samples_leaf=17, min_samples_split=14, n_estimators=20
# [CV 5/5; 15/15] END max_depth=None, max_features=12, min_samples_leaf=17, min_samples_split=14, n_estimators=20;, score=0.996 total time= 5.7min
# Lama waktu 'hyperparameter tuning' :  21097.091315984726

# %%
# Hasil tuning hyperparameter #
# =========================== #

# hasil
print ('F1 skor dan parameter terbaik')
print ('=============================')
print ('Nilai F1 skor terbaik : %s' % rf_random.best_score_)
print ('Parameter terbaik     : %s' % rf_random.best_params_)
print ('Estimator terbaik     : %s' % rf_random.best_estimator_)
test_54_rf_new_params_2 = pd.DataFrame(rf_random.cv_results_)

# simpan hasil hyperparameter random forest
test_54_rf_new_params_2.to_csv("G:\\Universitas Indonesia\\Rancangan Paper\\Dataset CSE-CIC-IDS2018-AWS\\CIC2018\\test_54_rf_new_params_2.txt", index=False)
# Out:
# F1 skor dan parameter terbaik
# =============================
# Nilai F1 skor terbaik : 0.9967409019343265
# Parameter terbaik     : {'n_estimators': 20, 'min_samples_split': 19, 'min_samples_leaf': 15, 'max_features': 15, 'max_depth': 20}
# Estimator terbaik     : RandomForestClassifier(max_depth=20, max_features=15, min_samples_leaf=15,
#                        min_samples_split=19, n_estimators=20, n_jobs=-1,
#                        random_state=42)

# %% [markdown]
# ### 54.4. Parameter terbaik

# %%
# 5 hyperparameter terbaik #
# ======================== #

# hyperparameter terbaik
hyperparam_rf = pd.read_csv("G:\\Universitas Indonesia\\Rancangan Paper\\Dataset CSE-CIC-IDS2018-AWS\\CIC2018\\test_54_rf_new_params_2.txt")

# mengurutkan hyperparameter terbaik berdasarkan f1
hyperparam_rf = hyperparam_rf.sort_values("rank_test_score")

# menampilkan 5 hyperparameter terbaik
print ('5 hyperparameter terbaik berdasarkan f1')
print ('=======================================')
param = hyperparam_rf[['rank_test_score','params','mean_fit_time','mean_test_score']].reset_index(drop=True)
#param = param[['params']]
param.head(5)
# Out:
# 5 hyperparameter terbaik berdasarkan f1
# =======================================
#    rank_test_score  \
# 0                1
# 1                2
# 2                3
# 3                4
# 4                5
#
#                                                                                                          params  \
# 0    {'n_estimators': 20, 'min_samples_split': 19, 'min_samples_leaf': 15, 'max_features': 15, 'max_depth': 20}
# 1    {'n_estimators': 20, 'min_samples_split': 10, 'min_samples_leaf': 17, 'max_features': 18, 'max_depth': 20}
# 2    {'n_estimators': 20, 'min_samples_split': 17, 'min_samples_leaf': 10, 'max_features': 15, 'max_depth': 15}
# 3     {'n_estimators': 20, 'min_samples_split': 5, 'min_samples_leaf': 17, 'max_features': 12, 'max_depth': 30}
# 4  {'n_estimators': 20, 'min_samples_split': 14, 'min_samples_leaf': 17, 'max_features': 12, 'max_depth': None}
#
#    mean_fit_time  mean_test_score
# 0     378.876882         0.996741
# 1     440.017682         0.996730
# 2     342.646457         0.996698
# 3     320.464678         0.996517
# 4     324.552627         0.996377

# %% [markdown]
# #### 52.4.1. Latih hyperparameter terbaik berdasarkan f1

# %%
param_rf = param['params'][0]
param_terbaik = [eval(param_rf)]       

# jumlah estimator
for n in param_terbaik:
    jlh_estimator = [n['n_estimators']]

param_terbaik
# Out:
# [{'n_estimators': 20,
#   'min_samples_split': 19,
#   'min_samples_leaf': 15,
#   'max_features': 15,
#   'max_depth': 20}]

# %%
print ('|=======================================|')
print ("| Hyperparameter terbaik berdasarkan f1 |")
print ('|=======================================|')
print ('')
klf_f1, y_f1 = latih_eval_rf(param_terbaik, jlh_estimator, y_aktual_biner)
# Out:
# |=======================================|
# | Hyperparameter terbaik berdasarkan f1 |
# |=======================================|
#
# hyperparameter : {'n_estimators': 20, 'min_samples_split': 19, 'min_samples_leaf': 15, 'max_features': 15, 'max_depth': 20}
# Lama waktu latih    : 484.9132750034332
# Lama waktu prediksi : 1.4412007331848145
# hasil 'Accuracy'    : 0.9975828049846961
# hasil 'f1-score'    : 0.9967695759349524

# %% [markdown]
# #### 54.4.2. Metrik evaluasi

# %%
# metrik evaluasi lapisan 1 berdasarkan f1
metrik (None, 1, y_aktual_biner, y_f1)

# misklasifikasi lapisan 1
misklasifikasi(y_aktual_biner, y_f1)
# Out:
# Accuracy, Precision, Recall dan F1-score :
# ==========================================
# Accuracy  : 0.9975828049846961
# Precision : 0.9979339377598699
# Recall    : 0.9956186537433804
# F1-score  : 0.9967695759349524
#
# metrik evaluasi :
# =================
#               precision    recall  f1-score   support
#
#       attack   0.998631  0.991690  0.995149    548880
#       benign   0.997237  0.999547  0.998390   1646640
#
#     accuracy                       0.997583   2195520
#    macro avg   0.997934  0.995619  0.996770   2195520
# weighted avg   0.997585  0.997583  0.997580   2195520
#
#
# matriks "confusion" :
# =====================
# misklasifikasi kelas target:
# ============================
#         misklasifikasi    total  persentase_misklasifikasi(%)
# attack            4561   548880                      0.830965
# benign             746  1646640                      0.045304
